# %%
import os
import json
import torch
import spacy
from transformers import AutoTokenizer, AutoModel
from difflib import SequenceMatcher
import pandas as pd

# Setup Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}\n")

# Load Models
print("Loading models...")
nlp = spacy.load("en_core_web_sm")
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
bert_model = AutoModel.from_pretrained("bert-base-uncased").to(device)
bert_model.eval()
print("Models loaded.\n")

# Set folder path containing JSON files
folder_path = 'Your_Path_Here'  # Change this to your folder path
json_files = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith('.json')]
print(f"Found {len(json_files)} JSON files in: {folder_path}")

@torch.no_grad()
def get_bert_embeddings(text: str):
    encoded = tokenizer(text, return_tensors="pt", return_offsets_mapping=True, truncation=True).to(device)
    offsets = encoded.pop("offset_mapping")[0].tolist()
    output = bert_model(**encoded)
    embeddings = output.last_hidden_state.squeeze(0)  # convert back to CPU for later processing
    tokens = tokenizer.convert_ids_to_tokens(encoded["input_ids"][0])
    return tokens, embeddings, offsets

def align_tokens_to_bert(doc, tokens, embeddings, offsets):
    token_embeddings = []
    for token in doc:
        token_start = token.idx
        token_end = token.idx + len(token.text)
        matched = [embeddings[i] for i, (start, end) in enumerate(offsets)
                   if start >= token_start and end <= token_end]
        if matched:
            token_embeddings.append(torch.mean(torch.stack(matched), dim=0).tolist())
        else:
            token_embeddings.append(torch.zeros(embeddings.size(-1)).tolist())
    return token_embeddings

def fuzzy_match_span(entity_text, doc):
    entity_text = entity_text.lower()
    best_score = 0.0
    best_span = None
    for start in range(len(doc)):
        for end in range(start + 1, min(len(doc) + 1, start + 10)):
            span = doc[start:end]
            score = SequenceMatcher(None, entity_text, span.text.lower()).ratio()
            if score > best_score:
                best_score = score
                best_span = span
    return best_span

def process_document(doc_entry):
    doc_text = doc_entry["doc"]
    triples = doc_entry.get("triples", [])
    entity_defs = doc_entry.get("entities", [])

    doc = nlp(doc_text)
    tokens, embeddings, offsets = get_bert_embeddings(doc_text)
    features = align_tokens_to_bert(doc, tokens, embeddings, offsets)

    graph = {
        "nodes": [token.text for token in doc],
        "edges": [(token.head.i, token.i) for token in doc if token.head.i != token.i],
        "node_features": features,
        "relation_labels": [],
        "entities": []
    }

    for ent in entity_defs:
        ent_type = ent["type"]
        for mention in ent["mentions"]:
            span = fuzzy_match_span(mention, doc)
            if span:
                graph["entities"].append({
                    "text": mention,
                    "start": span.start,
                    "end": span.end,
                    "label": ent_type,
                    "root": span.root.i
                })

    seen_pairs = set()
    for triple in triples:
        head_span = fuzzy_match_span(triple["head"], doc)
        tail_span = fuzzy_match_span(triple["tail"], doc)

        if head_span and tail_span:
            head_idx = head_span.root.i
            tail_idx = tail_span.root.i
            if (head_idx, tail_idx) not in seen_pairs:
                graph["relation_labels"].append({
                    "head": head_idx,
                    "tail": tail_idx,
                    "label": triple["relation"]
                })
                seen_pairs.add((head_idx, tail_idx))

    return graph

# Process all JSON files
all_graphs = []
for file_idx, file_path in enumerate(json_files):
    with open(file_path, "r") as f:
        docs = json.load(f)

    print(f"Processing {os.path.basename(file_path)} ({len(docs)} docs)...")
    for i, doc_entry in enumerate(docs):
        if "doc" in doc_entry and "triples" in doc_entry:
            graph = process_document(doc_entry)
            all_graphs.append(graph)

print(f"\nProcessed {len(all_graphs)} graphs from {len(json_files)} files.\n")

# Display Summary Table
df_preview = pd.DataFrame([{
    "num_nodes": len(g["nodes"]),
    "num_edges": len(g["edges"]),
    "num_relations": len(g["relation_labels"]),
    "num_entities": len(g["entities"]),
    "sample_nodes": g["nodes"][:5],
    "sample_relations": g["relation_labels"][:3],
    "sample_entities": g["entities"][:3]
} for g in all_graphs[:5]])

print("Graph Summary:")
print(df_preview.to_string(index=False))
# Out:
# Using device: cuda
#
# Loading models...
# /opt/sw/spack/apps/linux-rhel8-x86_64_v2/gcc-10.3.0/python-3.9.9-jh/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: libtorch_cuda_cu.so: cannot open shared object file: No such file or directory
#   warn(f"Failed to load image Python extension: {e}")
# Models loaded.
#
# Found 7 JSON files in: /scratch/vsetpal/train/train
# Processing Communication_all_examples.json (10 docs)...
# Processing Education_all_examples.json (10 docs)...
# Processing Energy_all_examples.json (10 docs)...
# Processing Entertainment_all_examples.json (12 docs)...
# Processing Government_all_examples.json (9 docs)...
# Processing Human_behavior_all_examples.json (13 docs)...
# Processing Internet_all_examples.json (10 docs)...
#
# Processed 74 graphs from 7 files.
#
# Graph Summary:
#  num_nodes  num_edges  num_relations  num_entities                                 sample_nodes                                                                                                                                           sample_relations                                                                                                                                                                                                                                                                                   sample_entities
#        195        188              7            18            [The,  , automatic, curb, sender]                  [{'head': 35, 'tail': 41, 'label': 'LocatedIn'}, {'head': 4, 'tail': 10, 'label': 'PartOf'}, {'head': 4, 'tail': 192, 'label': 'UsedBy'}]                   [{'text': 'William Thomson, 1st Baron Kelvin', 'start': 14, 'end': 20, 'label': 'PERSON', 'root': 17}, {'text': 'William Thomson', 'start': 14, 'end': 16, 'label': 'PERSON', 'root': 15}, {'text': '1st Baron Kelvin', 'start': 17, 'end': 20, 'label': 'PERSON', 'root': 17}]
#       1427       1359              7            14                    [In, the, study, of, the]                   [{'head': 15, 'tail': 9, 'label': 'HasPart'}, {'head': 56, 'tail': 62, 'label': 'HasPart'}, {'head': 9, 'tail': 80, 'label': 'HasPart'}] [{'text': 'Biocommunication of animals', 'start': 80, 'end': 83, 'label': 'MISC', 'root': 80}, {'text': 'Biocommunication of Ciliates', 'start': 170, 'end': 173, 'label': 'MISC', 'root': 170}, {'text': 'Biocommunication of Archaea', 'start': 186, 'end': 189, 'label': 'MISC', 'root': 186}]
#        663        637              4            59 [The, China, Internet, Network, Information]            [{'head': 5, 'tail': 33, 'label': 'LocatedIn'}, {'head': 5, 'tail': 18, 'label': 'Affiliation'}, {'head': 5, 'tail': 477, 'label': 'MemberOf'}]           [{'text': 'national Network Information Center', 'start': 347, 'end': 351, 'label': 'NORP', 'root': 350}, {'text': 'China Internet Network Information Center', 'start': 1, 'end': 6, 'label': 'NORP', 'root': 5}, {'text': 'CNNIC', 'start': 7, 'end': 8, 'label': 'NORP', 'root': 7}]
#       2373       2283              7            60   [Environmental, communication, is, ", the] [{'head': 162, 'tail': 1768, 'label': 'DiplomaticRelation'}, {'head': 87, 'tail': 96, 'label': 'HasPart'}, {'head': 463, 'tail': 1, 'label': 'HasEffect'}]                            [{'text': 'Flor and colleague Ely Gomez', 'start': 380, 'end': 385, 'label': 'PERSON', 'root': 380}, {'text': 'Flor', 'start': 124, 'end': 125, 'label': 'PERSON', 'root': 124}, {'text': 'Alexander Flor', 'start': 123, 'end': 125, 'label': 'PERSON', 'root': 124}]
#        961        924              9            54        [The, Facial, Action, Coding, System]               [{'head': 6, 'tail': 654, 'label': 'NominatedFor'}, {'head': 6, 'tail': 98, 'label': 'UsedBy'}, {'head': 6, 'tail': 693, 'label': 'PartOf'}]                                                          [{'text': 'FACS coding', 'start': 685, 'end': 687, 'label': 'MISC', 'root': 686}, {'text': 'original FACS', 'start': 453, 'end': 455, 'label': 'MISC', 'root': 454}, {'text': 'FACS', 'start': 6, 'end': 7, 'label': 'MISC', 'root': 6}]

# %%
import pickle

with open("processed_graphs.pkl", "wb") as f:
    pickle.dump(all_graphs, f)
print("Saved all graphs to disk.")
# Out:
# Saved all graphs to disk.

# %%
import torch
import torch.nn as nn
import pickle

# Load preprocessed graphs from pickle
with open("processed_graphs.pkl", "rb") as f:
    all_graphs = pickle.load(f)

print(f"Loaded {len(all_graphs)} graphs from pickle.\n")

# Dynamically build entity label vocabulary from the dataset
unique_entity_types = set()
for graph in all_graphs:
    for ent in graph.get("entities", []):
        unique_entity_types.add(ent["label"])

print("Unique entity types in dataset:")
print(sorted(unique_entity_types))

ENTITY_LABELS = {label: idx + 1 for idx, label in enumerate(sorted(unique_entity_types))}
ENTITY_LABELS["O"] = 0  # non-entity/default class

NUM_ENTITY_TYPES = len(ENTITY_LABELS)
ENTITY_EMBED_DIM = 16

print(f"\nENTITY_LABELS mapping ({NUM_ENTITY_TYPES} types):")
print(ENTITY_LABELS)

# Select one graph to test
graph = all_graphs[0]
print(f"\nGraph with {len(graph['nodes'])} nodes and {len(graph['entities'])} entities")

# Create entity type tags per node
node_entity_types = ["O"] * len(graph["nodes"])
for ent in graph["entities"]:
    for i in range(ent["start"], ent["end"]):
        if i < len(node_entity_types):
            node_entity_types[i] = ent["label"]

# Map entity types to IDs
entity_type_ids = [ENTITY_LABELS.get(label, 0) for label in node_entity_types]
entity_type_ids_tensor = torch.tensor(entity_type_ids, dtype=torch.long)

print(f"\nFirst 50 entity labels:\n{node_entity_types[0:10]}")
print(f"First 50 entity type IDs:\n{entity_type_ids[0:10]}")

# Convert BERT features to tensor
bert_tensor = torch.tensor(graph["node_features"], dtype=torch.float)
print(f"\nBERT features shape: {bert_tensor.shape}")

# Embed entity type IDs
entity_embedding = nn.Embedding(num_embeddings=NUM_ENTITY_TYPES, embedding_dim=ENTITY_EMBED_DIM)
entity_vecs = entity_embedding(entity_type_ids_tensor)
print(f"Entity embeddings shape: {entity_vecs.shape}")

# Concatenate BERT + Entity embeddings
node_features = torch.cat([bert_tensor, entity_vecs], dim=1)
print(f"\nCombined node feature shape: {node_features.shape}")
print(f"Sample node feature vector (first token):\n{node_features[0]}")
# Out:
# Loaded 74 graphs from pickle.
#
# Unique entity types in dataset:
# ['CARDINAL', 'DATE', 'EVENT', 'FAC', 'GPE', 'LANGUAGE', 'LAW', 'LOC', 'MISC', 'MONEY', 'NORP', 'ORDINAL', 'ORG', 'PERCENT', 'PERSON', 'PRODUCT', 'QUANTITY', 'TIME', 'WORK_OF_ART']
#
# ENTITY_LABELS mapping (20 types):
# {'CARDINAL': 1, 'DATE': 2, 'EVENT': 3, 'FAC': 4, 'GPE': 5, 'LANGUAGE': 6, 'LAW': 7, 'LOC': 8, 'MISC': 9, 'MONEY': 10, 'NORP': 11, 'ORDINAL': 12, 'ORG': 13, 'PERCENT': 14, 'PERSON': 15, 'PRODUCT': 16, 'QUANTITY': 17, 'TIME': 18, 'WORK_OF_ART': 19, 'O': 0}
#
# Graph with 195 nodes and 18 entities
#
# First 50 entity labels:
# ['O', 'O', 'MISC', 'MISC', 'MISC', 'O', 'O', 'O', 'O', 'MISC']
# First 50 entity type IDs:
# [0, 0, 9, 9, 9, 0, 0, 0, 0, 9]
#
# BERT features shape: torch.Size([195, 768])
# Entity embeddings shape: torch.Size([195, 16])
#
# Combined node feature shape: torch.Size([195, 784])
# Sample node feature vector (first token):
# tensor([-3.9604e-01, -2.4289e-01, -1.5405e-01,  3.4880e-01,  3.2767e-03,
#          1.9410e-02,  3.4890e-01,  9.8868e-02,  1.5698e-01, -1.1653e-01,
#          6.2711e-02, -2.7307e-01, -4.6156e-01,  4.7737e-01, -7.4761e-01,
#          4.3117e-01,  4.4647e-01, -2.9511e-01,  5.7412e-02, -1.8273e-01,
#         -3.8781e-01,  2.6864e-01,  2.8891e-01,  7.3755e-01,  3.9816e-02,
#         -4.5744e-01,  1.3237e-01,  1.5472e-01,  7.0850e-02, -3.4077e-01,
#          6.2323e-01,  2.5245e-01, -7.6176e-02, -6.1029e-01, -3.3753e-01,
#         -4.1394e-01, -3.9645e-01, -3.7728e-01, -1.2444e-01,  2.2270e-01,
#         -6.7792e-01,  3.3041e-01, -7.8036e-02,  2.7603e-01, -5.4948e-01,
#          6.2465e-02, -1.3655e+00,  1.0443e-01, -9.6297e-02, -4.5999e-01,
#         -9.5220e-01,  2.6685e-01, -1.6514e-01,  1.1057e+00, -2.6203e-01,
#          6.2092e-01, -1.0631e-01, -6.4221e-02, -1.3590e-01, -3.9933e-01,
#         -4.5034e-01,  3.9893e-01, -6.2503e-02, -4.4566e-01,  3.3450e-01,
#         -7.0930e-03, -2.8346e-01,  2.8434e-01, -6.0688e-01,  7.5608e-01,
#         -2.7114e-01, -1.7608e-01, -1.9492e-01,  1.7671e-01, -6.1794e-02,
#         -2.4592e-01, -3.1306e-01,  3.4288e-01,  1.0646e-01,  2.2300e-01,
#          8.5946e-03,  1.2535e-01,  3.8912e-02,  2.6444e-01, -2.2962e-01,
#          3.9634e-01, -1.9977e-01,  4.3134e-01, -1.9172e-01,  5.1714e-01,
#         -6.9996e-01,  1.7982e-01,  1.9271e-01, -1.9217e-01, -5.9568e-02,
#         -6.6786e-01,  1.5461e-01, -2.9903e-02,  6.5214e-01, -1.7798e-01,
#         -1.8952e-03, -9.4493e-01,  1.7831e-01, -1.0592e-01,  4.6143e-01,
#         -3.8399e-01, -3.0312e-02,  9.9798e-02, -4.9680e-01, -1.9988e-01,
#          4.8724e-02, -4.6287e-01,  5.6984e-01, -5.4751e-01, -2.4974e-01,
#         -1.1839e-01,  9.7910e-02, -1.2275e-01,  2.7569e-01,  2.5744e-01,
#          7.6070e-01,  8.7374e-01,  9.2728e-02,  1.5939e-02, -8.9362e-02,
#         -3.8908e-01,  3.9977e-01,  4.2521e-01, -6.9929e-01, -1.0449e-01,
#          5.5516e-01,  9.2583e-01,  2.8636e-01, -5.5150e-02, -8.1962e-01,
#          7.6698e-01, -7.9502e-01, -4.4169e-01, -6.5634e-01,  2.7705e-01,
#          4.3796e-01, -2.7489e-01, -1.1991e+00, -1.5006e-03,  2.9747e-01,
#          1.9240e-01, -5.5359e-01, -4.1879e-01, -4.3284e-01,  3.1246e-01,
#          3.2256e-01, -1.8909e-02, -1.1072e-01, -2.3393e-01, -1.3391e-01,
#         -5.1952e-01, -3.9596e-01,  3.1934e-01, -2.0796e-01, -3.3501e-01,
#         -1.3891e-01, -9.5831e-03, -2.9516e-01,  2.6363e-01, -1.5145e-01,
#          2.6875e-01,  4.2402e-01,  5.5907e-01, -4.3053e-02,  1.7849e-01,
#          1.6697e-01, -5.3048e-01,  9.9073e-01,  3.2268e-01, -2.8918e-01,
#          2.7409e-01,  4.7961e-01,  2.1641e-02,  7.5063e-01, -2.7297e-01,
#         -1.2391e+00,  8.0773e-01,  5.3039e-01,  3.5202e-01, -2.7118e-02,
#          2.6534e-01,  6.5269e-01, -9.4424e-01, -2.3011e-01, -1.7434e-01,
#         -3.1635e-01, -1.4056e-01, -3.2938e-01, -2.0777e-01,  1.0248e+00,
#         -4.7446e-02,  1.2841e-01, -8.5199e-01, -3.8498e-01, -2.7009e-01,
#         -1.7811e-02, -3.3080e-01,  4.9458e-01,  2.2017e-01, -3.8058e-01,
#          8.9752e-01,  4.0716e-01, -2.8706e-01,  3.4200e-01, -4.7615e-01,
#         -1.6332e-01, -4.2467e-01,  2.4798e-01, -4.0680e-01, -1.0270e-01,
#          4.0180e-01, -2.9997e-01, -1.3911e-01,  9.2035e-01, -5.4985e-03,
#          2.6143e-01,  2.4785e-01, -8.9442e-01,  6.9178e-01,  4.8067e-01,
#          1.6685e+00,  2.4765e-01, -2.2595e-01,  7.3950e-01, -2.2848e-01,
#         -2.7665e-01, -5.0574e-01,  1.1840e+00, -4.0996e-01, -1.5507e-01,
#         -1.1974e-01, -2.8650e-01, -9.5068e-02, -1.8031e-01, -9.2585e-02,
#          3.8614e-01,  3.2596e-01,  2.7959e-01,  6.1598e-01, -1.2148e-01,
#          7.7136e-02, -5.3666e-02, -2.4447e-01,  9.7954e-01, -3.8680e-01,
#         -5.5164e-01,  2.1862e-01,  6.7947e-02,  2.0391e-01,  2.4640e-01,
#         -3.2151e-01, -8.1622e-02, -3.8521e-01,  3.9811e-01,  5.2775e-01,
#         -4.5860e-01,  1.6638e-01,  4.0527e-01, -3.8182e-01, -2.8212e-01,
#         -2.6903e-01,  4.1798e-02,  7.6450e-01, -1.2911e-01, -1.1800e-01,
#         -1.1708e-02,  2.2085e-01,  1.3735e-01, -4.1321e-01, -5.2156e-01,
#         -7.5205e-01,  3.4963e-01, -1.1666e-01, -1.7446e-01, -3.9925e-01,
#         -3.8708e-02,  6.1830e-01, -8.4048e-01,  1.3450e-01, -5.3261e-01,
#         -2.2185e-01,  9.3966e-02, -7.0343e-01,  7.8134e-03, -1.9235e-01,
#         -6.3697e-01, -5.1725e-02, -3.4834e-01, -1.4862e-01, -4.0980e-01,
#          1.3436e-01,  2.7749e-01, -4.1963e-01,  4.0507e-01, -5.1677e-01,
#         -5.2500e-01, -7.7523e-01,  4.7734e-01,  2.0774e-01, -2.0581e-01,
#         -2.7288e-01,  5.1130e-02, -2.0321e-01, -1.2548e+00,  1.8337e-01,
#          2.5906e-01, -4.3658e-01,  4.0072e-01,  2.5569e-01,  1.8382e-01,
#         -1.7211e-01, -4.9216e-01,  2.3575e-01, -8.3765e-02, -4.6827e-01,
#          5.6102e-01, -1.5913e-01,  6.5678e-01, -1.3670e-01, -1.4168e-01,
#         -3.6565e-02,  2.4206e-01,  3.9136e-02,  3.7597e-01, -5.7377e-01,
#          1.3597e-01, -5.1723e-01,  1.7512e-01, -9.3120e-02, -3.2700e-01,
#         -2.2662e-01, -3.7367e-01, -2.5355e-01, -1.2747e-01, -4.3970e-01,
#          9.5586e-02,  1.3415e-01,  1.1456e-01, -2.4792e-01,  3.3374e-01,
#         -7.1948e-02,  5.5244e-01, -2.1547e-01, -4.5388e-03,  4.6970e-01,
#          9.8878e-01,  5.8217e-01,  7.0923e-01,  1.1672e-01,  8.7136e-01,
#         -2.1481e-01,  3.3615e-01,  2.7887e-01,  3.5817e-01,  1.5066e-01,
#          7.7995e-02, -1.3646e-02, -9.9478e-03, -1.3156e-01, -3.0122e-01,
#         -1.2152e-01, -2.5411e-01,  3.4772e-01,  1.8857e-01, -3.1511e-01,
#         -7.7342e-01, -2.7326e-01,  2.3836e-01, -5.8082e-01, -3.6561e-02,
#          3.4920e-01,  5.9189e-01, -6.4530e-02, -5.5402e-03,  8.4516e-01,
#         -7.8743e-02, -1.4714e+00, -5.6828e-02, -5.9143e-01,  3.6881e-01,
#         -4.6286e-02,  2.8359e-01, -1.9516e-01, -6.0167e-01, -2.9061e-01,
#          1.1538e-01,  7.4203e-01,  6.9895e-02, -6.7080e-01, -5.2732e-01,
#         -4.8320e-02, -1.0924e-01, -5.1345e-01,  3.5144e-01,  7.7001e-01,
#          4.7344e-01,  1.1523e-02,  2.3035e-01, -9.9142e-02, -2.0078e-01,
#         -3.7255e-01,  5.0405e-01,  2.8118e-02, -6.5259e-01,  4.6993e-01,
#          1.6102e-01, -5.9322e-01, -8.7485e-02, -3.6718e-01, -9.9707e-01,
#         -2.9660e-01, -1.8310e-02,  2.3068e-01, -3.3068e-01, -2.5729e-01,
#          2.4930e-01, -2.8614e-01,  4.4068e-01,  3.6112e-01, -5.4800e-01,
#          6.0847e-01,  5.4019e-02, -7.1235e-01,  1.7280e-01,  6.2016e-01,
#         -2.0833e-01, -2.4538e-01,  3.3390e-02,  4.1219e-01, -2.3725e-01,
#         -1.4265e-01, -2.5257e-01,  2.4999e-01,  1.7415e-01,  3.6041e-01,
#         -4.1885e-01,  2.5765e-01, -2.5032e-01, -2.6718e-01, -5.0325e-01,
#          4.5761e-02, -3.1105e-01,  2.6153e-01, -1.7411e-01,  1.9146e-01,
#         -4.2567e-01, -5.4266e-01,  5.0125e-01,  3.9609e-01, -5.0143e-02,
#         -1.9774e-01,  5.0009e-02,  1.2923e-01, -7.1072e-02,  1.2298e-04,
#         -4.0546e-01, -5.2010e-01, -2.2837e-01, -2.2789e-01, -5.6927e-02,
#         -2.5145e-01, -8.6802e-01, -3.7180e-01,  2.9408e-01, -8.4751e-03,
#         -5.5053e-01,  4.5857e-02,  2.0525e-01,  6.3247e-01, -4.4012e-01,
#         -3.4825e-01,  4.4080e-01,  1.7870e-01,  2.5195e-01, -3.7417e-01,
#         -3.1209e-01, -4.2068e-01,  1.2328e-01,  7.4512e-01, -4.5886e-01,
#         -4.8442e-01, -2.8221e-01, -2.5490e-01,  1.6406e-01,  2.0456e-01,
#         -6.0613e-01, -2.0376e-01,  6.2727e-02, -6.0951e-01, -5.3826e-01,
#         -2.6186e-01, -3.7898e-01, -7.6309e-02,  7.7508e-01,  1.7215e-01,
#         -4.8618e-01, -3.2460e-01, -8.3939e-01, -6.5693e-01, -6.0209e-02,
#          3.2687e-02, -1.0975e-02, -3.5515e-01,  1.0990e-01,  2.6949e-01,
#         -6.1942e-01, -6.8810e-01,  2.9752e-01,  4.7802e-01,  3.1120e-01,
#         -2.9221e-01, -2.2970e-01,  4.8929e-01, -5.2204e-01, -5.4039e-01,
#         -2.4877e-02, -3.0357e-01, -2.3145e-01,  4.0302e-02,  4.3608e-02,
#         -1.8042e-01, -4.5442e-01,  2.4040e-01, -4.7116e-01, -1.2638e-01,
#         -2.3373e-01,  1.1390e-01, -3.1873e-01, -1.4309e-01, -2.9431e-01,
#         -5.4079e-01, -5.2432e-01, -2.3041e-01, -4.1609e-01, -2.0641e-01,
#          8.2422e-01, -1.8590e-01, -4.1741e-01,  1.1450e-01, -1.6514e-01,
#          7.7062e-02, -2.2093e-01, -3.5321e-02,  6.4766e-01,  6.8514e-02,
#         -1.6046e-01,  2.7328e-01,  3.8681e-01,  4.4800e-02,  5.1613e-01,
#          9.8718e-02, -1.7878e-01, -1.0060e-01, -8.0479e-02,  4.6440e-02,
#         -4.8178e-01, -4.4142e-01, -3.8812e-01,  4.2416e-02,  1.9478e-01,
#         -1.5559e-01,  5.1533e-01, -6.9651e-02, -3.2008e-02, -1.5196e-01,
#         -7.1494e-01, -2.1843e-01,  1.5429e-01,  4.0654e-01, -8.8078e-02,
#         -5.2142e-01,  6.4545e-02,  2.8621e-01,  5.4081e-01, -5.9706e-01,
#          2.8045e-01,  3.9397e-01,  7.5103e-01,  6.0999e-01,  4.0291e-02,
#         -2.9975e-01, -2.9580e-01, -7.0517e-01,  5.1173e-01,  1.4809e-01,
#          1.1685e-01,  7.0819e-02, -3.3193e-01,  3.0540e-01, -1.4137e-02,
#          6.1701e-01,  5.7842e-01, -1.0593e-01,  1.1925e-01, -4.1862e-01,
#          2.7115e-01,  7.9352e-01, -1.6119e-01, -9.4472e-02, -3.1565e-01,
#          8.7565e-01, -2.5718e-01,  6.2096e-02,  1.0886e-01,  4.2996e-01,
#          6.0729e-01,  3.4953e-02,  6.7096e-02,  7.1244e-02,  3.9020e-01,
#         -5.1300e-01, -4.7780e-01, -7.6589e-02, -4.1845e-01, -1.5463e-01,
#          4.4233e-01,  2.7896e-01, -6.5300e-01, -4.9053e-01,  3.9175e-01,
#         -3.7369e-02,  1.9427e-01,  1.1156e-03,  9.6603e-02,  3.0252e-01,
#         -8.6763e-02, -3.6161e-01,  1.5763e-01,  4.7193e-01, -5.7078e-01,
#         -7.2369e-01, -5.2822e-02,  7.6334e-01,  5.2635e-01,  9.6013e-01,
#         -1.4930e-01,  1.3674e-01,  2.4864e-01,  1.0124e-02,  1.0420e-01,
#         -1.9583e-01, -2.8945e-01,  4.3386e-02, -1.2139e-01,  5.3907e-01,
#          7.0180e-01,  5.6340e-01, -3.5851e-01,  7.4461e-01,  7.8981e-01,
#          7.9338e-01,  9.5532e-02,  2.0096e-01,  3.9959e-01,  5.5718e-01,
#          3.0770e-01,  1.9473e-01, -1.5050e-02,  1.0977e+00,  1.4970e+00,
#          3.9539e-01,  4.9093e-01,  1.6904e-01,  3.6926e-01,  4.3482e-01,
#          9.2794e-01, -8.8326e-01, -1.3286e-02,  8.6111e-01, -1.8052e-01,
#         -7.9226e-01, -2.7546e-01,  2.4533e-03,  2.2181e-01,  3.4516e-02,
#         -1.1855e-01, -1.0939e-01, -2.7911e-01,  5.0660e-01,  9.1753e-01,
#          3.5347e-01,  1.5340e-01,  6.9968e-02, -4.0417e-02,  3.7627e-01,
#         -7.8705e-01, -1.4056e+00, -8.5915e-01, -8.0583e-01, -1.1401e-01,
#         -1.7910e-01, -9.3648e-03, -6.1121e-01,  1.8330e-01, -7.0443e-01,
#          1.7513e-01, -5.3390e-01, -2.5481e-02, -7.2266e-01,  4.7789e-01,
#         -6.9172e-02, -1.0667e-01, -5.7900e-01,  3.7060e-01,  2.2893e-01,
#         -1.3952e-01, -5.4622e-01, -1.7181e-01,  1.1315e+00,  1.2730e-01,
#          9.0875e-01,  2.1911e-01,  1.0798e-01,  4.0045e-01,  3.5717e-01,
#          1.4315e-01,  5.3428e-02, -3.3539e-01,  3.2453e-01,  2.8718e-01,
#          1.1809e-01, -7.4199e-01, -2.3601e-01, -7.4138e-03, -3.2407e-02,
#         -2.2751e-01, -2.6843e-01, -1.6153e-01, -2.5322e-01,  6.0222e-01,
#         -8.7660e-02, -2.2132e-01, -4.5584e-02, -3.5673e-02,  5.7447e-01,
#          4.0630e-01, -4.1150e-01, -7.0849e-01, -1.2081e-01,  1.6209e-01,
#          3.4853e-01, -6.6006e-01, -4.1788e-01,  5.0102e-01,  7.4206e-01,
#         -3.5082e-02,  8.7363e-01, -9.0349e-01, -5.4022e-01, -2.7177e-01,
#         -5.8536e-01,  3.3314e-01, -4.9100e-01,  4.9247e-01, -7.9810e-01,
#          2.2432e-01, -8.3072e-01,  3.5330e-01,  1.5811e-01, -5.8790e-01,
#          4.1179e-01, -2.2924e-01,  4.5027e-01,  1.6742e-01, -6.4743e-01,
#         -6.8141e-03,  1.2956e+00,  2.0617e-01, -1.1386e+00,  6.7733e-02,
#         -7.9724e-01,  4.9268e-03, -1.4232e+00,  3.5571e-01,  4.2017e-01,
#          7.5015e-01, -7.3600e-01,  1.3161e+00,  1.0535e+00],
#        grad_fn=<SelectBackward0>)

# %%
def generate_entity_pairs(graph):
    """
    Generates all possible head-tail entity pairs for a graph.
    Label them based on existing relation_labels.
    """
    entities = graph["entities"]
    relation_labels = {(rel["head"], rel["tail"]): rel["label"] for rel in graph["relation_labels"]}
    print(f"\nGenerating candidate pairs from {len(entities)} entities...")
    print(f"Gold relation label count: {len(relation_labels)}")
    candidate_pairs = []
    count_pos = 0
    count_neg = 0
    for i, head in enumerate(entities):
        for j, tail in enumerate(entities):
            if i == j:
                continue

            head_root = head["root"]
            tail_root = tail["root"]
            label = relation_labels.get((head_root, tail_root), "NoRelation")

            if label != "NoRelation":
                print(f"MATCH: '{head['text']}' → '{tail['text']}' labeled as {label}")
                count_pos += 1
            else:
                count_neg += 1

            candidate_pairs.append({
                "head": head,
                "tail": tail,
                "head_idx": head_root,
                "tail_idx": tail_root,
                "label": label
            })
    print(f"\nGenerated {len(candidate_pairs)} total pairs")
    print(f"{count_pos} positive (labeled) | {count_neg} negative (NoRelation)")
    return candidate_pairs

total_pairs = 0
total_pos = 0
total_neg = 0

for i, graph in enumerate(all_graphs):
    print(f"\nProcessing Graph {i+1}/{len(all_graphs)}")
    pairs = generate_entity_pairs(graph)
    total_pairs += len(pairs)
    total_pos += sum(1 for p in pairs if p['label'] != "NoRelation")
    total_neg += sum(1 for p in pairs if p['label'] == "NoRelation")

print("\nFINAL SUMMARY:")
print(f"Total Graphs: {len(all_graphs)}")
print(f"Total Candidate Pairs: {total_pairs}")
print(f"Total Positive (Labeled): {total_pos}")
print(f"Total Negative (NoRelation): {total_neg}")
# Out:
# Processing Graph 1/74
#
# Generating candidate pairs from 18 entities...
# Gold relation label count: 7
# MATCH: 'William Thomson' → 'automatic curb sender' labeled as Creator
# MATCH: 'Wheatstone transmitter' → 'land line' labeled as LocatedIn
# MATCH: 'automatic curb sender' → 'cable' labeled as LocatedIn
# MATCH: 'automatic curb sender' → 'Eastern Telegraph Company' labeled as UsedBy
# MATCH: 'automatic curb sender' → 'telegraph key' labeled as PartOf
# MATCH: 'automatic curb sender' → 'Eastern Telegraph Company' labeled as UsedBy
#
# Generated 306 total pairs
# 6 positive (labeled) | 300 negative (NoRelation)
#
# Processing Graph 2/74
#
# Generating candidate pairs from 14 entities...
# Gold relation label count: 7
#
# Generated 182 total pairs
# 0 positive (labeled) | 182 negative (NoRelation)
#
# Processing Graph 3/74
#
# Generating candidate pairs from 59 entities...
# Gold relation label count: 4
# MATCH: 'China Internet Network Information Center' → 'Anti-Phishing Alliance of China (APAC)' labeled as MemberOf
# MATCH: 'China Internet Network Information Center' → 'Anti-Phishing Alliance of China' labeled as MemberOf
# MATCH: 'China Internet Network Information Center' → '.cn domain name' labeled as OwnerOf
# MATCH: 'China Internet Network Information Center' → 'Ministry of Industry and Information Technology' labeled as Affiliation
# MATCH: 'China Internet Network Information Center' → 'Zhongguancun' labeled as LocatedIn
# MATCH: 'China Internet Network Information Center' → 'Zhongguancun, Beijing' labeled as LocatedIn
#
# Generated 3422 total pairs
# 6 positive (labeled) | 3416 negative (NoRelation)
#
# Processing Graph 4/74
#
# Generating candidate pairs from 60 entities...
# Gold relation label count: 7
# MATCH: 'United States' → 'China' labeled as DiplomaticRelation
#
# Generated 3540 total pairs
# 1 positive (labeled) | 3539 negative (NoRelation)
#
# Processing Graph 5/74
#
# Generating candidate pairs from 54 entities...
# Gold relation label count: 9
# MATCH: 'FACS' → 'Emotional Facial Action Coding System' labeled as NominatedFor
# MATCH: 'FACS' → 'Facial Action Coding System Affect Interpretation Dictionary (FACSAID)' labeled as NominatedFor
# MATCH: 'FACS' → 'psychologists' labeled as UsedBy
# MATCH: 'FACS' → 'animators' labeled as UsedBy
# MATCH: 'FACS' → 'computer animation' labeled as PartOf
# MATCH: 'FACS' → 'judo athletes' labeled as AppliesToPeople
# MATCH: 'FACS' → 'certification tests' labeled as HasQuality
# MATCH: 'FACS' → 'Emotional Facial Action Coding System (EMFACS)' labeled as NominatedFor
#
# Generated 2862 total pairs
# 8 positive (labeled) | 2854 negative (NoRelation)
#
# Processing Graph 6/74
#
# Generating candidate pairs from 6 entities...
# Gold relation label count: 2
# MATCH: 'GIS' → 'SAP' labeled as HasPart
# MATCH: 'GIS' → 'Global Learning Objects Brokered Exchange' labeled as HasPart
#
# Generated 30 total pairs
# 2 positive (labeled) | 28 negative (NoRelation)
#
# Processing Graph 7/74
#
# Generating candidate pairs from 123 entities...
# Gold relation label count: 6
# MATCH: 'quae' → '18th-century France' labeled as Country
# MATCH: 'quae' → 'France' labeled as Country
#
# Generated 15006 total pairs
# 2 positive (labeled) | 15004 negative (NoRelation)
#
# Processing Graph 8/74
#
# Generating candidate pairs from 68 entities...
# Gold relation label count: 8
# MATCH: 'This psychological theory' → 'RFT' labeled as HasPart
# MATCH: 'Theory' → 'regulatory fit theory' labeled as InfluencedBy
# MATCH: 'Theory' → 'Regulatory fit theory' labeled as InfluencedBy
# MATCH: 'Theory' → 'Regulatory Fit Theory' labeled as InfluencedBy
# MATCH: 'Theory' → 'Higgins' labeled as HasWorksInTheCollection
# MATCH: 'Theory' → 'E. Tory Higgins' labeled as HasWorksInTheCollection
# MATCH: 'regulatory focus theory' → 'regulatory fit theory' labeled as InfluencedBy
# MATCH: 'regulatory focus theory' → 'Regulatory fit theory' labeled as InfluencedBy
# MATCH: 'regulatory focus theory' → 'Regulatory Fit Theory' labeled as InfluencedBy
# MATCH: 'regulatory focus theory' → 'Higgins' labeled as HasWorksInTheCollection
# MATCH: 'regulatory focus theory' → 'E. Tory Higgins' labeled as HasWorksInTheCollection
# MATCH: 'Regulatory focus theory' → 'regulatory fit theory' labeled as InfluencedBy
# MATCH: 'Regulatory focus theory' → 'Regulatory fit theory' labeled as InfluencedBy
# MATCH: 'Regulatory focus theory' → 'Regulatory Fit Theory' labeled as InfluencedBy
# MATCH: 'Regulatory focus theory' → 'Higgins' labeled as HasWorksInTheCollection
# MATCH: 'Regulatory focus theory' → 'E. Tory Higgins' labeled as HasWorksInTheCollection
# MATCH: 'theory' → 'regulatory fit theory' labeled as InfluencedBy
# MATCH: 'theory' → 'Regulatory fit theory' labeled as InfluencedBy
# MATCH: 'theory' → 'Regulatory Fit Theory' labeled as InfluencedBy
# MATCH: 'theory' → 'Higgins' labeled as HasWorksInTheCollection
# MATCH: 'theory' → 'E. Tory Higgins' labeled as HasWorksInTheCollection
# MATCH: 'Lee' → 'regulatory focus orientations' labeled as Studies
# MATCH: 'Higgins' → 'Theory' labeled as Creator
# MATCH: 'Higgins' → 'regulatory focus theory' labeled as Creator
# MATCH: 'Higgins' → 'Regulatory focus theory' labeled as Creator
# MATCH: 'Higgins' → 'theory' labeled as Creator
# MATCH: 'Higgins' → 'Columbia University' labeled as Affiliation
# MATCH: 'E. Tory Higgins' → 'Theory' labeled as Creator
# MATCH: 'E. Tory Higgins' → 'regulatory focus theory' labeled as Creator
# MATCH: 'E. Tory Higgins' → 'Regulatory focus theory' labeled as Creator
# MATCH: 'E. Tory Higgins' → 'theory' labeled as Creator
# MATCH: 'E. Tory Higgins' → 'Columbia University' labeled as Affiliation
# MATCH: 'Student A' → 'promotion-focus orientation' labeled as Uses
# MATCH: 'Student B' → 'prevention-focus orientation' labeled as Uses
# MATCH: 'Student A and Student B' → 'promotion-focus orientation' labeled as Uses
# MATCH: 'Lee and Aaker' → 'regulatory focus orientations' labeled as Studies
#
# Generated 4556 total pairs
# 36 positive (labeled) | 4520 negative (NoRelation)
#
# Processing Graph 9/74
#
# Generating candidate pairs from 82 entities...
# Gold relation label count: 8
# MATCH: 'United States' → 'Japan' labeled as DiplomaticRelation
# MATCH: 'United States' → 'GB' labeled as DiplomaticRelation
# MATCH: 'United States' → 'Canada' labeled as DiplomaticRelation
# MATCH: 'United States' → 'North American' labeled as Continent
# MATCH: 'Japanese Industrial Standards' → 'Japan' labeled as Country
# MATCH: 'Japan' → 'Canada' labeled as DiplomaticRelation
# MATCH: 'GB' → 'Canada' labeled as DiplomaticRelation
# MATCH: 'Canada' → 'North American' labeled as Continent
#
# Generated 6642 total pairs
# 8 positive (labeled) | 6634 negative (NoRelation)
#
# Processing Graph 10/74
#
# Generating candidate pairs from 99 entities...
# Gold relation label count: 3
# MATCH: 'New York City' → 'Manhattan' labeled as HasPart
# MATCH: 'New York City' → 'lower Manhattan' labeled as HasPart
# MATCH: 'New York City' → 'English' labeled as OfficialLanguage
# MATCH: 'San Francisco' → 'English' labeled as OfficialLanguage
#
# Generated 9702 total pairs
# 4 positive (labeled) | 9698 negative (NoRelation)
#
# Processing Graph 11/74
#
# Generating candidate pairs from 59 entities...
# Gold relation label count: 5
# MATCH: 'collective' → 'Machias' labeled as LocatedIn
# MATCH: 'collective' → 'Machias, Maine' labeled as LocatedIn
# MATCH: 'collective' → 'Station Museum of Contemporary Art' labeled as PresentedIn
# MATCH: 'collective' → 'graphical media' labeled as Uses
# MATCH: 'Beehive Design Collective' → 'Machias' labeled as LocatedIn
# MATCH: 'Beehive Design Collective' → 'Machias, Maine' labeled as LocatedIn
# MATCH: 'Beehive Design Collective' → 'Station Museum of Contemporary Art' labeled as PresentedIn
# MATCH: 'Beehive Design Collective' → 'graphical media' labeled as Uses
# MATCH: 'Collective' → 'Machias' labeled as LocatedIn
# MATCH: 'Collective' → 'Machias, Maine' labeled as LocatedIn
# MATCH: 'Collective' → 'Station Museum of Contemporary Art' labeled as PresentedIn
# MATCH: 'Collective' → 'graphical media' labeled as Uses
# MATCH: 'Machias Valley Grange Hall' → 'collective' labeled as InfluencedBy
# MATCH: 'Machias Valley Grange Hall' → 'Beehive Design Collective' labeled as InfluencedBy
# MATCH: 'Machias Valley Grange Hall' → 'Collective' labeled as InfluencedBy
# MATCH: 'Machias Valley Grange Hall' → 'National Register of Historic Places' labeled as LocatedIn
# MATCH: 'Machias Valley Grange Hall in Machias, Maine' → 'collective' labeled as InfluencedBy
# MATCH: 'Machias Valley Grange Hall in Machias, Maine' → 'Beehive Design Collective' labeled as InfluencedBy
# MATCH: 'Machias Valley Grange Hall in Machias, Maine' → 'Collective' labeled as InfluencedBy
# MATCH: 'Machias Valley Grange Hall in Machias, Maine' → 'National Register of Historic Places' labeled as LocatedIn
#
# Generated 3422 total pairs
# 20 positive (labeled) | 3402 negative (NoRelation)
#
# Processing Graph 12/74
#
# Generating candidate pairs from 46 entities...
# Gold relation label count: 2
# MATCH: 'Climate' → 'campus culture' labeled as DifferentFrom
# MATCH: 'campus climate' → 'campus culture' labeled as DifferentFrom
# MATCH: 'Campus climate' → 'campus culture' labeled as DifferentFrom
# MATCH: 'climate' → 'campus culture' labeled as DifferentFrom
#
# Generated 2070 total pairs
# 4 positive (labeled) | 2066 negative (NoRelation)
#
# Processing Graph 13/74
#
# Generating candidate pairs from 20 entities...
# Gold relation label count: 0
#
# Generated 380 total pairs
# 0 positive (labeled) | 380 negative (NoRelation)
#
# Processing Graph 14/74
#
# Generating candidate pairs from 42 entities...
# Gold relation label count: 0
#
# Generated 1722 total pairs
# 0 positive (labeled) | 1722 negative (NoRelation)
#
# Processing Graph 15/74
#
# Generating candidate pairs from 103 entities...
# Gold relation label count: 6
# MATCH: 'Field Museum' → 'Chicago' labeled as LocatedIn
# MATCH: 'Field Museum in Chicago' → 'Chicago' labeled as LocatedIn
# MATCH: 'Calgary Zoo' → 'Canada' labeled as LocatedIn
# MATCH: 'field trip' → 'site-based program' labeled as HasPart
# MATCH: 'field trip' → 'follow-up activity' labeled as HasPart
# MATCH: 'field trip' → 'Activities' labeled as HasPart
# MATCH: 'field trip' → 'activities' labeled as HasPart
#
# Generated 10506 total pairs
# 7 positive (labeled) | 10499 negative (NoRelation)
#
# Processing Graph 16/74
#
# Generating candidate pairs from 32 entities...
# Gold relation label count: 1
# MATCH: 'HEFCE' → 'higher education funding' labeled as HasPart
#
# Generated 992 total pairs
# 1 positive (labeled) | 991 negative (NoRelation)
#
# Processing Graph 17/74
#
# Generating candidate pairs from 45 entities...
# Gold relation label count: 1
# MATCH: 'Hospitality Management and Tourism' → 'hospitality industry' labeled as Studies
# MATCH: 'Hospitality Management' → 'hospitality industry' labeled as Studies
# MATCH: 'Hospitality management' → 'hospitality industry' labeled as Studies
# MATCH: 'hospitality management' → 'hospitality industry' labeled as Studies
#
# Generated 1980 total pairs
# 4 positive (labeled) | 1976 negative (NoRelation)
#
# Processing Graph 18/74
#
# Generating candidate pairs from 40 entities...
# Gold relation label count: 1
# MATCH: 'SESI Mathematics' → 'Lei de Diretrizes e Bases da Educação Nacional' labeled as BasedOn
#
# Generated 1560 total pairs
# 1 positive (labeled) | 1559 negative (NoRelation)
#
# Processing Graph 19/74
#
# Generating candidate pairs from 24 entities...
# Gold relation label count: 4
# MATCH: 'sophomore' → 'senior' labeled as DifferentFrom
# MATCH: 'sophomore' → 'freshman' labeled as DifferentFrom
# MATCH: 'sophomore' → 'college or university studies' labeled as PartOf
# MATCH: 'sophomore' → 'junior' labeled as DifferentFrom
#
# Generated 552 total pairs
# 4 positive (labeled) | 548 negative (NoRelation)
#
# Processing Graph 20/74
#
# Generating candidate pairs from 143 entities...
# Gold relation label count: 2
# MATCH: 'Mutual recognition of higher education qualifications' → 'Lisbon Recognition Convention' labeled as RegulatedBy
# MATCH: 'Mutual recognition of higher education qualifications' → 'UNESCO/Council of Europe Lisbon Recognition Convention' labeled as RegulatedBy
# MATCH: 'Mutual recognition of higher education qualifications' → 'Council of Europe Lisbon Recognition Convention' labeled as RegulatedBy
#
# Generated 20306 total pairs
# 3 positive (labeled) | 20303 negative (NoRelation)
#
# Processing Graph 21/74
#
# Generating candidate pairs from 50 entities...
# Gold relation label count: 3
# MATCH: 'Müllverwertung Rugenberger Damm WtE plant' → 'Hamburg' labeled as LocatedIn
# MATCH: 'Müllverwertung Rugenberger Damm WtE plant' → 'Hamburg, Germany' labeled as LocatedIn
# MATCH: 'Klean Power' → 'advanced thermal recycling system' labeled as OwnerOf
#
# Generated 2450 total pairs
# 3 positive (labeled) | 2447 negative (NoRelation)
#
# Processing Graph 22/74
#
# Generating candidate pairs from 22 entities...
# Gold relation label count: 2
#
# Generated 462 total pairs
# 0 positive (labeled) | 462 negative (NoRelation)
#
# Processing Graph 23/74
#
# Generating candidate pairs from 13 entities...
# Gold relation label count: 0
#
# Generated 156 total pairs
# 0 positive (labeled) | 156 negative (NoRelation)
#
# Processing Graph 24/74
#
# Generating candidate pairs from 149 entities...
# Gold relation label count: 16
# MATCH: 'Edison' → 'Pearl Street Power Station' labeled as OwnerOf
# MATCH: 'Thomas Edison' → 'Pearl Street Power Station' labeled as OwnerOf
# MATCH: 'New York City' → 'America' labeled as LocatedIn
# MATCH: 'New York City' → 'North America' labeled as LocatedIn
#
# Generated 22052 total pairs
# 4 positive (labeled) | 22048 negative (NoRelation)
#
# Processing Graph 25/74
#
# Generating candidate pairs from 32 entities...
# Gold relation label count: 11
# MATCH: 'Energy Management Software' → 'real-time energy metering' labeled as HasPart
# MATCH: 'Energy Management Software' → 'grid services' labeled as HasPart
# MATCH: 'Energy Management Software' → 'utility bill tracking' labeled as HasPart
# MATCH: 'Energy Management Software' → 'generation control' labeled as HasPart
# MATCH: 'Energy Management Software' → 'carbon and sustainability reporting' labeled as HasPart
# MATCH: 'Energy Management Software' → 'consumption control' labeled as HasPart
# MATCH: 'Energy Management Software' → 'building simulation and modeling' labeled as HasPart
# MATCH: 'Energy Management Software' → 'IT equipment management' labeled as HasPart
# MATCH: 'Energy Management Software' → 'energy audits' labeled as HasPart
# MATCH: 'Energy Management Software (EMS)' → 'real-time energy metering' labeled as HasPart
# MATCH: 'Energy Management Software (EMS)' → 'grid services' labeled as HasPart
# MATCH: 'Energy Management Software (EMS)' → 'utility bill tracking' labeled as HasPart
# MATCH: 'Energy Management Software (EMS)' → 'generation control' labeled as HasPart
# MATCH: 'Energy Management Software (EMS)' → 'carbon and sustainability reporting' labeled as HasPart
# MATCH: 'Energy Management Software (EMS)' → 'consumption control' labeled as HasPart
# MATCH: 'Energy Management Software (EMS)' → 'building simulation and modeling' labeled as HasPart
# MATCH: 'Energy Management Software (EMS)' → 'IT equipment management' labeled as HasPart
# MATCH: 'Energy Management Software (EMS)' → 'energy audits' labeled as HasPart
# MATCH: 'Energy management software' → 'real-time energy metering' labeled as HasPart
# MATCH: 'Energy management software' → 'grid services' labeled as HasPart
# MATCH: 'Energy management software' → 'utility bill tracking' labeled as HasPart
# MATCH: 'Energy management software' → 'generation control' labeled as HasPart
# MATCH: 'Energy management software' → 'carbon and sustainability reporting' labeled as HasPart
# MATCH: 'Energy management software' → 'consumption control' labeled as HasPart
# MATCH: 'Energy management software' → 'building simulation and modeling' labeled as HasPart
# MATCH: 'Energy management software' → 'IT equipment management' labeled as HasPart
# MATCH: 'Energy management software' → 'energy audits' labeled as HasPart
#
# Generated 992 total pairs
# 27 positive (labeled) | 965 negative (NoRelation)
#
# Processing Graph 26/74
#
# Generating candidate pairs from 83 entities...
# Gold relation label count: 11
# MATCH: 'ExxonMobil' → 'Standard Oil Company of New York' labeled as NamedAfter
# MATCH: 'ExxonMobil' → 'U.S.' labeled as Country
# MATCH: 'Neches River' → 'U.S.' labeled as Country
# MATCH: 'Burt Refining Company' → 'Spindletop field' labeled as OwnerOf
# MATCH: 'Spindletop' → 'U.S.' labeled as Country
# MATCH: 'Standard Oil Company of New York' → 'U.S.' labeled as Country
# MATCH: 'U.S.' → 'World War II' labeled as SignificantEvent
#
# Generated 6806 total pairs
# 7 positive (labeled) | 6799 negative (NoRelation)
#
# Processing Graph 27/74
#
# Generating candidate pairs from 32 entities...
# Gold relation label count: 7
# MATCH: 'Maksim Sonin' → 'Stanford University' labeled as WorkLocation
# MATCH: 'Maksim Sonin' → 'Stanford University Hydrogen Initiative' labeled as InterestedIn
# MATCH: 'Maksim Sonin' → 'PhD' labeled as AcademicDegree
# MATCH: 'Maksim Sonin' → 'MS in Finance' labeled as AcademicDegree
# MATCH: 'Maksim Sonin' → 'PhD in Engineering' labeled as AcademicDegree
# MATCH: 'Maksim Sonin' → 'MS in Management' labeled as AcademicDegree
#
# Generated 992 total pairs
# 6 positive (labeled) | 986 negative (NoRelation)
#
# Processing Graph 28/74
#
# Generating candidate pairs from 47 entities...
# Gold relation label count: 8
# MATCH: 'Soviet astronomer Nikolai Kardashev' → 'Soviet' labeled as CountryOfCitizenship
# MATCH: 'Nikolai Kardashev' → 'Soviet' labeled as CountryOfCitizenship
# MATCH: 'Michio Kaku' → 'Physics of the Future' labeled as Author
# MATCH: 'Type 0.73 civilization' → 'Type I civilization' labeled as DifferentFrom
# MATCH: 'Type I civilization' → 'planetary civilization' labeled as HasPart
# MATCH: 'planetary civilization' → 'stellar civilization' labeled as FollowedBy
# MATCH: 'Terrorism' → 'type one civilization' labeled as InOppositionTo
# MATCH: 'terrorism' → 'type one civilization' labeled as InOppositionTo
#
# Generated 2162 total pairs
# 8 positive (labeled) | 2154 negative (NoRelation)
#
# Processing Graph 29/74
#
# Generating candidate pairs from 101 entities...
# Gold relation label count: 11
# MATCH: 'Wälde' → 'University of Dundee' labeled as LocatedIn
# MATCH: 'Wälde' → 'University of Dundee, Scotland' labeled as LocatedIn
# MATCH: 'Wälde' → 'Dundee, Scotland' labeled as LocatedIn
# MATCH: 'Wälde' → 'Bormes-Les-Mimosas' labeled as WorkLocation
# MATCH: 'Wälde' → 'Institute for International Economic Law' labeled as WorkLocation
# MATCH: 'Wälde' → 'Harvard Law School' labeled as EducatedAt
# MATCH: 'Wälde' → 'Detlev Vagts' labeled as Follows
# MATCH: 'Wälde' → 'ICJ president Roslyn Higgins' labeled as Follows
# MATCH: 'Wälde' → 'Roslyn Higgins' labeled as Follows
# MATCH: 'Thomas W. Wälde' → 'University of Dundee' labeled as LocatedIn
# MATCH: 'Thomas W. Wälde' → 'University of Dundee, Scotland' labeled as LocatedIn
# MATCH: 'Thomas W. Wälde' → 'Dundee, Scotland' labeled as LocatedIn
# MATCH: 'Thomas W. Wälde' → 'Bormes-Les-Mimosas' labeled as WorkLocation
# MATCH: 'Thomas W. Wälde' → 'Institute for International Economic Law' labeled as WorkLocation
# MATCH: 'Thomas W. Wälde' → 'Harvard Law School' labeled as EducatedAt
# MATCH: 'Thomas W. Wälde' → 'Detlev Vagts' labeled as Follows
# MATCH: 'Thomas W. Wälde' → 'ICJ president Roslyn Higgins' labeled as Follows
# MATCH: 'Thomas W. Wälde' → 'Roslyn Higgins' labeled as Follows
# MATCH: 'Poland' → 'Sweden' labeled as DiplomaticRelation
#
# Generated 10100 total pairs
# 19 positive (labeled) | 10081 negative (NoRelation)
#
# Processing Graph 30/74
#
# Generating candidate pairs from 47 entities...
# Gold relation label count: 2
# MATCH: 'Uganda Energy Credit Capitalisation Company' → 'government of Uganda' labeled as OwnedBy
# MATCH: 'Uganda Energy Credit Capitalisation Company (UECCC)' → 'government of Uganda' labeled as OwnedBy
# MATCH: 'UECCC' → 'World Bank' labeled as Partner
# MATCH: 'UECCC' → 'World Bank' labeled as Partner
#
# Generated 2162 total pairs
# 4 positive (labeled) | 2158 negative (NoRelation)
#
# Processing Graph 31/74
#
# Generating candidate pairs from 56 entities...
# Gold relation label count: 14
# MATCH: 'Anvil firing' → 'anvil launching' labeled as SaidToBeTheSameAs
# MATCH: 'Anvil firing' → 'anvil shooting' labeled as SaidToBeTheSameAs
# MATCH: 'Anvil firing' → 'New Westminster' labeled as LocatedIn
# MATCH: 'Anvil firing' → 'Black powder' labeled as HasPart
# MATCH: 'Anvil firing' → 'black powder' labeled as HasPart
# MATCH: 'Anvil firing' → 'traditional event' labeled as PartOf
# MATCH: 'Anvil firing' → 'stone base' labeled as HasPart
# MATCH: 'anvil firing' → 'anvil launching' labeled as SaidToBeTheSameAs
# MATCH: 'anvil firing' → 'anvil shooting' labeled as SaidToBeTheSameAs
# MATCH: 'anvil firing' → 'New Westminster' labeled as LocatedIn
# MATCH: 'anvil firing' → 'Black powder' labeled as HasPart
# MATCH: 'anvil firing' → 'black powder' labeled as HasPart
# MATCH: 'anvil firing' → 'traditional event' labeled as PartOf
# MATCH: 'anvil firing' → 'stone base' labeled as HasPart
# MATCH: 'Victoria' → 'United Kingdom' labeled as OwnerOf
# MATCH: 'St. Clement's Day' → 'Pope Clement I' labeled as SignificantEvent
# MATCH: 'day' → 'Pope Clement I' labeled as SignificantEvent
# MATCH: 'anvil' → 'gunpowder' labeled as PhysicallyInteractsWith
#
# Generated 3080 total pairs
# 18 positive (labeled) | 3062 negative (NoRelation)
#
# Processing Graph 32/74
#
# Generating candidate pairs from 121 entities...
# Gold relation label count: 12
# MATCH: 'theatre' → 'Charles Dibdin' labeled as InterestedIn
# MATCH: 'theatre' → 'Dibdin, Jr.' labeled as InterestedIn
# MATCH: 'theatre' → 'Charles Dibdin, Jr.' labeled as InterestedIn
# MATCH: 'theatre' → 'Dibdin' labeled as InterestedIn
# MATCH: 'theatre' → 'aqua drama' labeled as HasPart
# MATCH: 'Sadler's Wells Theatre' → 'Charles Dibdin' labeled as InterestedIn
# MATCH: 'Sadler's Wells Theatre' → 'Dibdin, Jr.' labeled as InterestedIn
# MATCH: 'Sadler's Wells Theatre' → 'Charles Dibdin, Jr.' labeled as InterestedIn
# MATCH: 'Sadler's Wells Theatre' → 'Dibdin' labeled as InterestedIn
# MATCH: 'Sadler's Wells Theatre' → 'aqua drama' labeled as HasPart
# MATCH: 'Wells Theatre' → 'Charles Dibdin' labeled as InterestedIn
# MATCH: 'Wells Theatre' → 'Dibdin, Jr.' labeled as InterestedIn
# MATCH: 'Wells Theatre' → 'Charles Dibdin, Jr.' labeled as InterestedIn
# MATCH: 'Wells Theatre' → 'Dibdin' labeled as InterestedIn
# MATCH: 'Wells Theatre' → 'aqua drama' labeled as HasPart
# MATCH: 'theatre' → 'Charles Dibdin' labeled as InterestedIn
# MATCH: 'theatre' → 'Dibdin, Jr.' labeled as InterestedIn
# MATCH: 'theatre' → 'Charles Dibdin, Jr.' labeled as InterestedIn
# MATCH: 'theatre' → 'Dibdin' labeled as InterestedIn
# MATCH: 'theatre' → 'aqua drama' labeled as HasPart
# MATCH: 'Theatre' → 'Charles Dibdin' labeled as InterestedIn
# MATCH: 'Theatre' → 'Dibdin, Jr.' labeled as InterestedIn
# MATCH: 'Theatre' → 'Charles Dibdin, Jr.' labeled as InterestedIn
# MATCH: 'Theatre' → 'Dibdin' labeled as InterestedIn
# MATCH: 'Theatre' → 'aqua drama' labeled as HasPart
# MATCH: 'Charles Dibdin' → 'theatre' labeled as InterestedIn
# MATCH: 'Charles Dibdin' → 'Sadler's Wells Theatre' labeled as InterestedIn
# MATCH: 'Charles Dibdin' → 'Wells Theatre' labeled as InterestedIn
# MATCH: 'Charles Dibdin' → 'theatre' labeled as InterestedIn
# MATCH: 'Charles Dibdin' → 'Theatre' labeled as InterestedIn
# MATCH: 'Dibdin, Jr.' → 'theatre' labeled as InterestedIn
# MATCH: 'Dibdin, Jr.' → 'Sadler's Wells Theatre' labeled as InterestedIn
# MATCH: 'Dibdin, Jr.' → 'Wells Theatre' labeled as InterestedIn
# MATCH: 'Dibdin, Jr.' → 'theatre' labeled as InterestedIn
# MATCH: 'Dibdin, Jr.' → 'Theatre' labeled as InterestedIn
# MATCH: 'Charles Dibdin, Jr.' → 'theatre' labeled as InterestedIn
# MATCH: 'Charles Dibdin, Jr.' → 'Sadler's Wells Theatre' labeled as InterestedIn
# MATCH: 'Charles Dibdin, Jr.' → 'Wells Theatre' labeled as InterestedIn
# MATCH: 'Charles Dibdin, Jr.' → 'theatre' labeled as InterestedIn
# MATCH: 'Charles Dibdin, Jr.' → 'Theatre' labeled as InterestedIn
# MATCH: 'Dibdin' → 'theatre' labeled as InterestedIn
# MATCH: 'Dibdin' → 'Sadler's Wells Theatre' labeled as InterestedIn
# MATCH: 'Dibdin' → 'Wells Theatre' labeled as InterestedIn
# MATCH: 'Dibdin' → 'theatre' labeled as InterestedIn
# MATCH: 'Dibdin' → 'Theatre' labeled as InterestedIn
# MATCH: 'Siege of Gibraltar' → 'theatre' labeled as SignificantEvent
# MATCH: 'Siege of Gibraltar' → 'Sadler's Wells Theatre' labeled as SignificantEvent
# MATCH: 'Siege of Gibraltar' → 'Wells Theatre' labeled as SignificantEvent
# MATCH: 'Siege of Gibraltar' → 'theatre' labeled as SignificantEvent
# MATCH: 'Siege of Gibraltar' → 'Theatre' labeled as SignificantEvent
# MATCH: 'Siege of Gibraltar' → 'aqua drama' labeled as SignificantEvent
# MATCH: 'HMS Bounty' → 'Island or Christian and His Comrades' labeled as InterestedIn
# MATCH: 'HMS Bounty' → 'Island' labeled as InterestedIn
# MATCH: 'Napoleonic wars' → 'early 1800s' labeled as SignificantEvent
# MATCH: 'Napoleonic wars' → 'early 1800s' labeled as SignificantEvent
# MATCH: 'Napoleonic wars' → 'aqua drama' labeled as HasEffect
#
# Generated 14520 total pairs
# 56 positive (labeled) | 14464 negative (NoRelation)
#
# Processing Graph 33/74
#
# Generating candidate pairs from 60 entities...
# Gold relation label count: 17
# MATCH: 'Delfines Hotel & Convention Center' → 'Delfines Hotel & Casino' labeled as SaidToBeTheSameAs
# MATCH: 'Delfines Hotel & Convention Center' → 'Hotel Los Delfines' labeled as SaidToBeTheSameAs
# MATCH: 'Delfines Hotel & Convention Center' → 'San Isidro District, Lima, Peru' labeled as LocatedIn
# MATCH: 'Delfines Hotel & Convention Center' → 'San Isidro District' labeled as LocatedIn
# MATCH: 'Delfines Hotel & Convention Center' → 'Jacques Levy Calvo' labeled as OwnerOf
# MATCH: 'Delfines Hotel & Convention Center' → 'Salón Mediterráneo' labeled as HasPart
# MATCH: 'Yaku' → 'Delfines Hotel & Convention Center' labeled as HasEffect
# MATCH: 'Yaku' → 'Mexico' labeled as LocatedIn
# MATCH: 'Yaku' → 'Jamaica' labeled as LocatedIn
# MATCH: 'Yaku' → 'c. 1988' labeled as Founded
# MATCH: 'Yaku' → 'Dolphin Cove Jamaica' labeled as LocatedIn
# MATCH: 'Yaku' → 'calf' labeled as PartOf
# MATCH: 'Yaku' → 'cardiac issues' labeled as HasEffect
# MATCH: 'Yaku' → 'Yaku's cardiac issues' labeled as HasEffect
# MATCH: 'Wayra' → 'Delfines Hotel & Convention Center' labeled as InterestedIn
# MATCH: 'Wayra' → 'Mexico' labeled as LocatedIn
# MATCH: 'Wayra' → 'Jamaica' labeled as LocatedIn
# MATCH: 'Wayra' → 'c. 1992' labeled as Founded
# MATCH: 'Wayra' → 'Dolphin Cove Jamaica' labeled as LocatedIn
# MATCH: 'Judiciary of Peru' → 'Delfines Hotel & Convention Center' labeled as HasEffect
#
# Generated 3540 total pairs
# 20 positive (labeled) | 3520 negative (NoRelation)
#
# Processing Graph 34/74
#
# Generating candidate pairs from 195 entities...
# Gold relation label count: 35
# MATCH: 'Metro Trains' → 'Dumb Ways to Die' labeled as HasEffect
# MATCH: 'Metro Trains' → 'Dumb Ways to Die' labeled as HasEffect
# MATCH: 'Metro Trains' → 'dumb ways to die' labeled as HasEffect
# MATCH: 'Dumb Ways to Die 3: World Tour' → 'Dumb Ways to Die 2: The Games' labeled as Follows
# MATCH: 'a Dumb Ways to Die' → 'Patrick Baron' labeled as Creator
# MATCH: 'a Dumb Ways to Die' → 'Julian Frost' labeled as Creator
# MATCH: 'a Dumb Ways to Die' → 'Samuel Baird' labeled as Creator
# MATCH: 'Dumb Ways to Die 3:' → 'Dumb Ways to Die 2: The Games' labeled as Follows
# MATCH: 'Dumb Ways to Dash' → 'Dumb Ways to Die' labeled as InspiredBy
# MATCH: 'Dumb Ways to Dash' → 'Dumb Ways to Die' labeled as InspiredBy
# MATCH: 'Dumb Ways to Dash' → 'dumb ways to die' labeled as InspiredBy
# MATCH: 'Dumb Ways to Die 4' → 'Dumb Ways to Die 3: World Tour' labeled as Follows
# MATCH: 'Dumb Ways to Die 4' → 'Dumb Ways to Die 3:' labeled as Follows
# MATCH: 'Dumb Ways to Die 4' → 'Dumb Ways to Die 3' labeled as Follows
# MATCH: 'Dumb Ways to Die 2: The Games' → '18 November 2014' labeled as Founded
# MATCH: 'Dumb Ways to Die 2: The Games' → 'a Dumb Ways to Die' labeled as Follows
# MATCH: 'Dumb Ways to Die 2: The Games' → 'Dumb Ways to Die game' labeled as Follows
# MATCH: 'Dumb Ways to Die' → 'Metro Trains' labeled as InterestedIn
# MATCH: 'Dumb Ways to Die' → 'advertising agency McCann Melbourne' labeled as Creator
# MATCH: 'Dumb Ways to Die' → 'McGill' labeled as OwnerOf
# MATCH: 'Dumb Ways to Die' → 'YouTube' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'PlaySide Studios' labeled as InspiredBy
# MATCH: 'Dumb Ways to Die' → 'a Dumb Ways to Die' labeled as HasWorksInTheCollection
# MATCH: 'Dumb Ways to Die' → 'song "Dumb Ways to Die"' labeled as HasPart
# MATCH: 'Dumb Ways to Die' → 'Dumb Ways to Die game' labeled as HasWorksInTheCollection
# MATCH: 'Dumb Ways to Die' → 'song' labeled as HasPart
# MATCH: 'Dumb Ways to Die' → 'at least $50 million worth of global media value' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Ollie McGill' labeled as OwnerOf
# MATCH: 'Dumb Ways to Die' → 'Safety' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'railway safety' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'safety' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Susie O'Brien' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Webby Awards' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Gold Lions' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'two Bronze Lions' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Siren Awards' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Bronze Lions' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'three Silver Lions' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Silver Lions' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Grand Trophy' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Grand Trophy in the 2013 New York Festivals International Advertising Awards' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Grand Prix awards' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Grand Prix' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Integrated Grand Prix' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'five Grand Prix awards' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'app' labeled as PartOf
# MATCH: 'Dumb Ways to Die' → 'mobile app' labeled as PartOf
# MATCH: 'Dumb Ways to Die' → 'seven Webby Awards' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → '18 Gold Lions' labeled as HasEffect
# MATCH: 'Dumb Ways to Die 3' → 'Dumb Ways to Die 2: The Games' labeled as Follows
# MATCH: 'Dumb Ways to Draw' → '5 May 2019' labeled as Founded
# MATCH: 'Dumb Ways to Draw' → 'Dumb Ways to Die' labeled as Follows
# MATCH: 'Dumb Ways to Draw' → 'Dumb Ways to Die' labeled as Follows
# MATCH: 'Dumb Ways to Draw' → 'dumb ways to die' labeled as Follows
# MATCH: 'Dumb Ways to Die game' → 'Patrick Baron' labeled as Creator
# MATCH: 'Dumb Ways to Die game' → 'Julian Frost' labeled as Creator
# MATCH: 'Dumb Ways to Die game' → 'Samuel Baird' labeled as Creator
# MATCH: 'Tumblr' → 'English' labeled as Uses
# MATCH: 'John Mescall' → 'song "Dumb Ways to Die"' labeled as Creator
# MATCH: 'John Mescall' → 'song' labeled as Creator
# MATCH: 'Dumb Ways to Die' → 'Metro Trains' labeled as InterestedIn
# MATCH: 'Dumb Ways to Die' → 'advertising agency McCann Melbourne' labeled as Creator
# MATCH: 'Dumb Ways to Die' → 'McGill' labeled as OwnerOf
# MATCH: 'Dumb Ways to Die' → 'YouTube' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'PlaySide Studios' labeled as InspiredBy
# MATCH: 'Dumb Ways to Die' → 'a Dumb Ways to Die' labeled as HasWorksInTheCollection
# MATCH: 'Dumb Ways to Die' → 'song "Dumb Ways to Die"' labeled as HasPart
# MATCH: 'Dumb Ways to Die' → 'Dumb Ways to Die game' labeled as HasWorksInTheCollection
# MATCH: 'Dumb Ways to Die' → 'song' labeled as HasPart
# MATCH: 'Dumb Ways to Die' → 'at least $50 million worth of global media value' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Ollie McGill' labeled as OwnerOf
# MATCH: 'Dumb Ways to Die' → 'Safety' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'railway safety' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'safety' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Susie O'Brien' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Webby Awards' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Gold Lions' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'two Bronze Lions' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Siren Awards' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Bronze Lions' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'three Silver Lions' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Silver Lions' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Grand Trophy' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Grand Trophy in the 2013 New York Festivals International Advertising Awards' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Grand Prix awards' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Grand Prix' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'Integrated Grand Prix' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'five Grand Prix awards' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → 'app' labeled as PartOf
# MATCH: 'Dumb Ways to Die' → 'mobile app' labeled as PartOf
# MATCH: 'Dumb Ways to Die' → 'seven Webby Awards' labeled as HasEffect
# MATCH: 'Dumb Ways to Die' → '18 Gold Lions' labeled as HasEffect
# MATCH: 'dumb ways to die' → 'Metro Trains' labeled as InterestedIn
# MATCH: 'dumb ways to die' → 'advertising agency McCann Melbourne' labeled as Creator
# MATCH: 'dumb ways to die' → 'McGill' labeled as OwnerOf
# MATCH: 'dumb ways to die' → 'YouTube' labeled as HasEffect
# MATCH: 'dumb ways to die' → 'PlaySide Studios' labeled as InspiredBy
# MATCH: 'dumb ways to die' → 'a Dumb Ways to Die' labeled as HasWorksInTheCollection
# MATCH: 'dumb ways to die' → 'song "Dumb Ways to Die"' labeled as HasPart
# MATCH: 'dumb ways to die' → 'Dumb Ways to Die game' labeled as HasWorksInTheCollection
# MATCH: 'dumb ways to die' → 'song' labeled as HasPart
# MATCH: 'dumb ways to die' → 'at least $50 million worth of global media value' labeled as HasEffect
# MATCH: 'dumb ways to die' → 'Ollie McGill' labeled as OwnerOf
# MATCH: 'dumb ways to die' → 'Safety' labeled as HasEffect
# MATCH: 'dumb ways to die' → 'railway safety' labeled as HasEffect
# MATCH: 'dumb ways to die' → 'safety' labeled as HasEffect
# MATCH: 'dumb ways to die' → 'Susie O'Brien' labeled as HasEffect
# MATCH: 'dumb ways to die' → 'Webby Awards' labeled as HasEffect
# MATCH: 'dumb ways to die' → 'Gold Lions' labeled as HasEffect
# MATCH: 'dumb ways to die' → 'two Bronze Lions' labeled as HasEffect
# MATCH: 'dumb ways to die' → 'Siren Awards' labeled as HasEffect
# MATCH: 'dumb ways to die' → 'Bronze Lions' labeled as HasEffect
# MATCH: 'dumb ways to die' → 'three Silver Lions' labeled as HasEffect
# MATCH: 'dumb ways to die' → 'Silver Lions' labeled as HasEffect
# MATCH: 'dumb ways to die' → 'Grand Trophy' labeled as HasEffect
# MATCH: 'dumb ways to die' → 'Grand Trophy in the 2013 New York Festivals International Advertising Awards' labeled as HasEffect
# MATCH: 'dumb ways to die' → 'Grand Prix awards' labeled as HasEffect
# MATCH: 'dumb ways to die' → 'Grand Prix' labeled as HasEffect
# MATCH: 'dumb ways to die' → 'Integrated Grand Prix' labeled as HasEffect
# MATCH: 'dumb ways to die' → 'five Grand Prix awards' labeled as HasEffect
# MATCH: 'dumb ways to die' → 'app' labeled as PartOf
# MATCH: 'dumb ways to die' → 'mobile app' labeled as PartOf
# MATCH: 'dumb ways to die' → 'seven Webby Awards' labeled as HasEffect
# MATCH: 'dumb ways to die' → '18 Gold Lions' labeled as HasEffect
#
# Generated 37830 total pairs
# 124 positive (labeled) | 37706 negative (NoRelation)
#
# Processing Graph 35/74
#
# Generating candidate pairs from 52 entities...
# Gold relation label count: 8
# MATCH: 'elegiac comedies' → 'vernacular language' labeled as Uses
# MATCH: 'vernacular writers' → 'Boccaccio' labeled as HasPart
# MATCH: 'vernacular writers' → 'Chaucer' labeled as HasPart
# MATCH: 'vernacular writers' → 'Gower' labeled as HasPart
# MATCH: 'Thompson' → 'elegiac comedies' labeled as HasEffect
#
# Generated 2652 total pairs
# 5 positive (labeled) | 2647 negative (NoRelation)
#
# Processing Graph 36/74
#
# Generating candidate pairs from 63 entities...
# Gold relation label count: 7
# MATCH: 'Russell Lincoln Ackoff' → '1967' labeled as SignificantEvent
# MATCH: 'Howard' → 'Metagame Analysis in Political Problems' labeled as Author
# MATCH: 'Howard' → 'Metagame Analysis' labeled as Author
# MATCH: 'Nigel Howard' → 'Metagame Analysis in Political Problems' labeled as Author
# MATCH: 'Nigel Howard' → 'Metagame Analysis' labeled as Author
# MATCH: 'Nigel Howard's book' → '1971' labeled as Founded
# MATCH: 'Garfield' → '1995' labeled as SignificantEvent
# MATCH: 'Garfield' → 'Magic: The Gathering' labeled as Creator
# MATCH: 'Richard Garfield' → '1995' labeled as SignificantEvent
# MATCH: 'Richard Garfield' → 'Magic: The Gathering' labeled as Creator
# MATCH: 'Aron Nimzowitsch' → 'hypermodern openings' labeled as HasEffect
#
# Generated 3906 total pairs
# 11 positive (labeled) | 3895 negative (NoRelation)
#
# Processing Graph 37/74
#
# Generating candidate pairs from 49 entities...
# Gold relation label count: 18
# MATCH: 'Canada' → 'UK' labeled as Follows
# MATCH: 'Heelwork to music' → 'Kennel club' labeled as InterestedIn
# MATCH: 'Heelwork to Music' → 'Kennel club' labeled as InterestedIn
# MATCH: 'heelwork to music' → 'Kennel club' labeled as InterestedIn
# MATCH: 'musical canine freestyle' → 'Musical Freestyle' labeled as HasPart
# MATCH: 'musical canine freestyle' → 'Musical freestyle' labeled as HasPart
# MATCH: 'musical canine freestyle' → 'musical freestyle' labeled as HasPart
# MATCH: 'canine freestyle' → 'Musical Freestyle' labeled as HasPart
# MATCH: 'canine freestyle' → 'Musical freestyle' labeled as HasPart
# MATCH: 'canine freestyle' → 'musical freestyle' labeled as HasPart
# MATCH: 'Musical Canine Sports International' → '1991' labeled as Founded
# MATCH: 'Musical Canine Sports International' → 'British Columbia' labeled as Founded
# MATCH: 'Musical Canine Sports International' → 'British Columbia, Canada' labeled as Founded
# MATCH: 'Musical Freestyle' → 'Canada' labeled as LocatedIn
# MATCH: 'Musical Freestyle' → 'England' labeled as LocatedIn
# MATCH: 'Musical Freestyle' → 'United States' labeled as LocatedIn
# MATCH: 'Musical Freestyle' → 'Netherlands' labeled as LocatedIn
# MATCH: 'Musical Freestyle' → 'musical canine freestyle' labeled as SaidToBeTheSameAs
# MATCH: 'Musical Freestyle' → 'canine freestyle' labeled as SaidToBeTheSameAs
# MATCH: 'Musical Freestyle' → 'Musical Canine Sports International' labeled as OwnerOf
# MATCH: 'Musical Freestyle' → 'Musical freestyle' labeled as SaidToBeTheSameAs
# MATCH: 'Musical Freestyle' → 'musical freestyle' labeled as SaidToBeTheSameAs
# MATCH: 'Musical Freestyle' → 'freestyle dance' labeled as SaidToBeTheSameAs
# MATCH: 'Musical freestyle' → 'Canada' labeled as LocatedIn
# MATCH: 'Musical freestyle' → 'England' labeled as LocatedIn
# MATCH: 'Musical freestyle' → 'United States' labeled as LocatedIn
# MATCH: 'Musical freestyle' → 'Netherlands' labeled as LocatedIn
# MATCH: 'Musical freestyle' → 'musical canine freestyle' labeled as SaidToBeTheSameAs
# MATCH: 'Musical freestyle' → 'canine freestyle' labeled as SaidToBeTheSameAs
# MATCH: 'Musical freestyle' → 'Musical Canine Sports International' labeled as OwnerOf
# MATCH: 'Musical freestyle' → 'Musical Freestyle' labeled as SaidToBeTheSameAs
# MATCH: 'Musical freestyle' → 'musical freestyle' labeled as SaidToBeTheSameAs
# MATCH: 'Musical freestyle' → 'freestyle dance' labeled as SaidToBeTheSameAs
# MATCH: 'musical freestyle' → 'Canada' labeled as LocatedIn
# MATCH: 'musical freestyle' → 'England' labeled as LocatedIn
# MATCH: 'musical freestyle' → 'United States' labeled as LocatedIn
# MATCH: 'musical freestyle' → 'Netherlands' labeled as LocatedIn
# MATCH: 'musical freestyle' → 'musical canine freestyle' labeled as SaidToBeTheSameAs
# MATCH: 'musical freestyle' → 'canine freestyle' labeled as SaidToBeTheSameAs
# MATCH: 'musical freestyle' → 'Musical Canine Sports International' labeled as OwnerOf
# MATCH: 'musical freestyle' → 'Musical Freestyle' labeled as SaidToBeTheSameAs
# MATCH: 'musical freestyle' → 'Musical freestyle' labeled as SaidToBeTheSameAs
# MATCH: 'musical freestyle' → 'freestyle dance' labeled as SaidToBeTheSameAs
#
# Generated 2352 total pairs
# 43 positive (labeled) | 2309 negative (NoRelation)
#
# Processing Graph 38/74
#
# Generating candidate pairs from 46 entities...
# Gold relation label count: 11
# MATCH: 'Jeff Hull' → 'Nonchalance' labeled as HasEffect
# MATCH: 'Jejune Institute' → 'San Francisco' labeled as LocatedIn
# MATCH: 'Jejune Institute' → 'San Francisco, California' labeled as LocatedIn
# MATCH: 'Jejune Institute' → 'Best World' labeled as NominatedFor
# MATCH: 'Jejune Institute' → '"Best Alternate Reality"' labeled as HasEffect
# MATCH: 'Jejune Institute' → 'Best Alternate Reality' labeled as HasEffect
# MATCH: 'Jejune Institute' → '"Best World"' labeled as NominatedFor
# MATCH: 'Jejune Institute' → '"Best Story"' labeled as HasEffect
# MATCH: 'Jejune Institute' → 'Best Story' labeled as HasEffect
# MATCH: 'Latitude Society' → 'Nonchalance' labeled as Creator
# MATCH: 'SYGNYL' → 'Nonchalance' labeled as HasWorksInTheCollection
# MATCH: 'Nonchalance' → 'Oakland, California' labeled as LocatedIn
# MATCH: 'Nonchalance' → 'Oakland' labeled as LocatedIn
# MATCH: 'Nonchalance' → 'San Francisco' labeled as LocatedIn
# MATCH: 'Nonchalance' → 'San Francisco, California' labeled as LocatedIn
# MATCH: 'Nonchalance' → 'Jejune Institute' labeled as InterestedIn
# MATCH: 'Nonchalance' → 'Latitude Society' labeled as HasPart
#
# Generated 2070 total pairs
# 17 positive (labeled) | 2053 negative (NoRelation)
#
# Processing Graph 39/74
#
# Generating candidate pairs from 30 entities...
# Gold relation label count: 22
# MATCH: 'Rene Peter Onno Rubiono van Helsdingen' → 'Komter Loeber' labeled as HasEffect
# MATCH: 'Rene Peter Onno Rubiono van Helsdingen' → 'Netherlands' labeled as LocatedIn
# MATCH: 'Rene Peter Onno Rubiono van Helsdingen' → 'Jakarta' labeled as HasEffect
# MATCH: 'Rene Peter Onno Rubiono van Helsdingen' → '1962:72' labeled as SignificantEvent
# MATCH: 'Rene Peter Onno Rubiono van Helsdingen' → 'Lazlo Cser' labeled as HasEffect
# MATCH: 'Rene Peter Onno Rubiono van Helsdingen' → '1979' labeled as SignificantEvent
# MATCH: 'Rene Peter Onno Rubiono van Helsdingen' → 'Oscar Peterson' labeled as HasEffect
# MATCH: 'Rene Peter Onno Rubiono van Helsdingen' → 'Virgin' labeled as HasEffect
# MATCH: 'Rene Peter Onno Rubiono van Helsdingen' → 'WEA' labeled as HasEffect
# MATCH: 'Rene Peter Onno Rubiono van Helsdingen' → 'successful tours, projects and festivals' labeled as Creator
# MATCH: 'Rene Peter Onno Rubiono van Helsdingen' → 'Lazlo Cser' labeled as HasEffect
# MATCH: 'Rene Peter Onno Rubiono van Helsdingen' → 'Timeless' labeled as HasEffect
# MATCH: 'Rene Peter Onno Rubiono van Helsdingen' → 'Dureco' labeled as HasEffect
# MATCH: 'Rene Peter Onno Rubiono van Helsdingen' → 'Pacific Music' labeled as HasEffect
# MATCH: 'Rene Peter Onno Rubiono van Helsdingen' → 'demajors Independent Music Industry Jakarta' labeled as HasEffect
# MATCH: 'Dutch' → 'Netherlands' labeled as NominatedFor
#
# Generated 870 total pairs
# 16 positive (labeled) | 854 negative (NoRelation)
#
# Processing Graph 40/74
#
# Generating candidate pairs from 94 entities...
# Gold relation label count: 17
# MATCH: 'Rule 63' → 'gender flipping' labeled as HasEffect
# MATCH: 'Demitri Maximoff' → 'Midnight Bliss' labeled as HasPart
# MATCH: 'Demitri Maximoff' → 'SNK vs. Capcom' labeled as PartOf
# MATCH: 'Demitri Maximoff' → 'gender flipping' labeled as PracticedBy
# MATCH: 'Maximoff' → 'Midnight Bliss' labeled as HasPart
# MATCH: 'Maximoff' → 'SNK vs. Capcom' labeled as PartOf
# MATCH: 'Maximoff' → 'gender flipping' labeled as PracticedBy
# MATCH: 'Midnight Bliss' → 'Demitri Maximoff' labeled as SaidToBeTheSameAs
# MATCH: 'Midnight Bliss' → 'Maximoff' labeled as SaidToBeTheSameAs
# MATCH: 'Bowsette' → 'Bowser' labeled as DifferentFrom
# MATCH: 'Bowsette' → 'Princess Peach' labeled as InspiredBy
# MATCH: 'Loud House' → 'One of the Boys' labeled as SaidToBeTheSameAs
# MATCH: 'Shovel Knight' → 'Body Swap Mode' labeled as HasPart
# MATCH: 'Sheik' → 'female-to-male gender-swapping' labeled as PartOf
# MATCH: 'character Sheik' → 'female-to-male gender-swapping' labeled as PartOf
# MATCH: 'fanworks' → 'cosplay' labeled as HasPart
# MATCH: 'fanworks' → 'fan art' labeled as HasPart
# MATCH: 'fanworks' → 'fan fiction' labeled as HasPart
#
# Generated 8742 total pairs
# 18 positive (labeled) | 8724 negative (NoRelation)
#
# Processing Graph 41/74
#
# Generating candidate pairs from 189 entities...
# Gold relation label count: 60
# MATCH: 'Varsity Brands' → 'Herff Jones' labeled as HasEffect
# MATCH: 'Varsity Brands' → 'American Cheerleader magazine' labeled as OwnerOf
# MATCH: 'Universal Cheerleaders Association' → '1974' labeled as Founded
# MATCH: 'UCA' → 'Jeff Webb' labeled as Creator
# MATCH: 'Varsity Spirit, LLC' → 'Varsity Brands' labeled as OwnerOf
# MATCH: 'Varsity Spirit, LLC' → 'Universal Cheerleaders Association' labeled as InterestedIn
# MATCH: 'Varsity Spirit, LLC' → 'Varsity Spirit' labeled as SaidToBeTheSameAs
# MATCH: 'Varsity Spirit, LLC' → 'American Cheerleader magazine' labeled as InterestedIn
# MATCH: 'Varsity Spirit, LLC' → 'American Cheerleader' labeled as HasWorksInTheCollection
# MATCH: 'Varsity Spirit, LLC' → 'U.S. All Star Federation' labeled as InterestedIn
# MATCH: 'Varsity Spirit, LLC' → 'Jeff Webb' labeled as Creator
# MATCH: 'Varsity Spirit, LLC' → 'USA Cheer' labeled as OwnerOf
# MATCH: 'Varsity Spirit, LLC' → '$82.5 million' labeled as InterestedIn
# MATCH: 'Varsity Spirit, LLC' → '$43.5 million' labeled as InterestedIn
# MATCH: 'Varsity Spirit, LLC' → 'National Spirit Group' labeled as InspiredBy
# MATCH: 'Varsity Spirit, LLC' → 'Athletic Championships LLC' labeled as InterestedIn
# MATCH: 'Varsity Spirit, LLC' → 'Premier Athletics LLC' labeled as InterestedIn
# MATCH: 'Varsity Spirit, LLC' → 'Memphis Grizzlies' labeled as InterestedIn
# MATCH: 'Varsity Spirit, LLC' → 'JAM Brands' labeled as OwnerOf
# MATCH: 'Varsity Spirit, LLC' → 'Star Athletica' labeled as InterestedIn
# MATCH: 'Varsity Spirit, LLC' → 'NBA's Memphis Grizzlies' labeled as InterestedIn
# MATCH: 'Varsity Spirit, LLC' → 'SA Feather Co.' labeled as InspiredBy
# MATCH: 'Varsity Spirit, LLC' → 'Stanbury Uniforms' labeled as InterestedIn
# MATCH: 'Varsity Spirit, LLC' → 'International Cheer Union' labeled as InterestedIn
# MATCH: 'Varsity Spirit' → 'Varsity Brands' labeled as OwnerOf
# MATCH: 'Varsity Spirit' → 'Universal Cheerleaders Association' labeled as InterestedIn
# MATCH: 'Varsity Spirit' → 'Varsity Spirit, LLC' labeled as SaidToBeTheSameAs
# MATCH: 'Varsity Spirit' → 'American Cheerleader magazine' labeled as InterestedIn
# MATCH: 'Varsity Spirit' → 'American Cheerleader' labeled as HasWorksInTheCollection
# MATCH: 'Varsity Spirit' → 'U.S. All Star Federation' labeled as InterestedIn
# MATCH: 'Varsity Spirit' → 'Jeff Webb' labeled as Creator
# MATCH: 'Varsity Spirit' → 'USA Cheer' labeled as OwnerOf
# MATCH: 'Varsity Spirit' → '$82.5 million' labeled as InterestedIn
# MATCH: 'Varsity Spirit' → '$43.5 million' labeled as InterestedIn
# MATCH: 'Varsity Spirit' → 'National Spirit Group' labeled as InspiredBy
# MATCH: 'Varsity Spirit' → 'Athletic Championships LLC' labeled as InterestedIn
# MATCH: 'Varsity Spirit' → 'Premier Athletics LLC' labeled as InterestedIn
# MATCH: 'Varsity Spirit' → 'Memphis Grizzlies' labeled as InterestedIn
# MATCH: 'Varsity Spirit' → 'JAM Brands' labeled as OwnerOf
# MATCH: 'Varsity Spirit' → 'Star Athletica' labeled as InterestedIn
# MATCH: 'Varsity Spirit' → 'NBA's Memphis Grizzlies' labeled as InterestedIn
# MATCH: 'Varsity Spirit' → 'SA Feather Co.' labeled as InspiredBy
# MATCH: 'Varsity Spirit' → 'Stanbury Uniforms' labeled as InterestedIn
# MATCH: 'Varsity Spirit' → 'International Cheer Union' labeled as InterestedIn
# MATCH: 'American' → 'U.S.' labeled as SaidToBeTheSameAs
# MATCH: 'American' → 'U.S.' labeled as SaidToBeTheSameAs
# MATCH: 'American Cheerleader magazine' → '1995' labeled as Founded
# MATCH: 'American Cheerleader magazine' → 'Lifestyle Ventures' labeled as OwnerOf
# MATCH: 'American Cheerleader magazine' → 'Lifestyle Ventures, LLC' labeled as OwnerOf
# MATCH: 'U.S.' → 'New York' labeled as NominatedFor
# MATCH: 'U.S.' → 'U.S.' labeled as SaidToBeTheSameAs
# MATCH: 'U.S.' → 'California' labeled as NominatedFor
# MATCH: 'U.S.' → 'Texas' labeled as NominatedFor
# MATCH: 'USASF' → 'Varsity Spirit, LLC' labeled as Follows
# MATCH: 'USASF' → 'Varsity Spirit' labeled as Follows
# MATCH: 'Jeff Webb' → 'Varsity Brands' labeled as Creator
# MATCH: 'Jeff Webb' → 'Varsity Spirit, LLC' labeled as Creator
# MATCH: 'Jeff Webb' → 'Varsity Spirit' labeled as Creator
# ...
# MATCH: 'Burçak Ertimur' → 'FDU' labeled as Affiliation
# MATCH: 'US' → 'Colorado' labeled as HasPart
#
# Generated 2256 total pairs
# 13 positive (labeled) | 2243 negative (NoRelation)
#
# Processing Graph 62/74
#
# Generating candidate pairs from 107 entities...
# Gold relation label count: 13
# MATCH: 'Swedish' → 'Stockholm syndrome' labeled as ContributedToCreativeWork
# MATCH: 'Swedish' → 'Stockholm Syndrome' labeled as ContributedToCreativeWork
# MATCH: 'Allan Wade' → 'Stockholm syndrome' labeled as ContributedToCreativeWork
# MATCH: 'Allan Wade' → 'Stockholm Syndrome' labeled as ContributedToCreativeWork
# MATCH: 'Dr. Allan Wade' → 'Stockholm syndrome' labeled as ContributedToCreativeWork
# MATCH: 'Dr. Allan Wade' → 'Stockholm Syndrome' labeled as ContributedToCreativeWork
# MATCH: 'Stockholm syndrome' → 'a psychological bond' labeled as Causes
# MATCH: 'Stockholm syndrome' → 'psychological bond with their captors' labeled as Causes
# MATCH: 'Stockholm syndrome' → 'psychological bond' labeled as Causes
# MATCH: 'Stockholm Syndrome' → 'a psychological bond' labeled as Causes
# MATCH: 'Stockholm Syndrome' → 'psychological bond with their captors' labeled as Causes
# MATCH: 'Stockholm Syndrome' → 'psychological bond' labeled as Causes
# MATCH: 'Norrmalmstorgssyndromet' → 'Stockholm syndrome' labeled as SaidToBeTheSameAs
# MATCH: 'Norrmalmstorgssyndromet' → 'Norrmalmstorg syndrome' labeled as ContributedToCreativeWork
# MATCH: 'Norrmalmstorgssyndromet' → 'Stockholm Syndrome' labeled as SaidToBeTheSameAs
# MATCH: 'London Syndrome' → 'Stockholm syndrome' labeled as DifferentFrom
# MATCH: 'London Syndrome' → 'Stockholm Syndrome' labeled as DifferentFrom
# MATCH: 'London Syndrome' → 'Iranian Embassy' labeled as NamedBy
# MATCH: 'Namnyak' → 'Stockholm syndrome' labeled as ContributedToCreativeWork
# MATCH: 'Namnyak' → 'Stockholm Syndrome' labeled as ContributedToCreativeWork
#
# Generated 11342 total pairs
# 20 positive (labeled) | 11322 negative (NoRelation)
#
# Processing Graph 63/74
#
# Generating candidate pairs from 91 entities...
# Gold relation label count: 15
# MATCH: 'Bogorad's syndrome' → 'crocodile tears syndrome' labeled as SaidToBeTheSameAs
# MATCH: 'Bogorad's syndrome' → 'Crocodile Tears Syndrome' labeled as SaidToBeTheSameAs
# MATCH: 'Pseudobulbar affect' → 'uncontrollable laughter' labeled as HasPart
# MATCH: 'Pseudobulbar affect' → 'episodic uncontrollable laughter or crying' labeled as HasPart
# MATCH: 'Pseudobulbar affect' → 'uncontrollable laughter or crying' labeled as HasPart
# MATCH: 'Pseudobulbar affect' → 'neurological injuries' labeled as InfluencedBy
# MATCH: 'Pseudobulbar affect (PBA)' → 'uncontrollable laughter' labeled as HasPart
# MATCH: 'Pseudobulbar affect (PBA)' → 'episodic uncontrollable laughter or crying' labeled as HasPart
# MATCH: 'Pseudobulbar affect (PBA)' → 'uncontrollable laughter or crying' labeled as HasPart
# MATCH: 'Pseudobulbar affect (PBA)' → 'neurological injuries' labeled as InfluencedBy
# MATCH: 'emotional tears' → 'stress-inducing hormones' labeled as InfluencedBy
# MATCH: 'crying' → 'frustration' labeled as InfluencedBy
# MATCH: 'Tears' → 'emotional tears' labeled as HasPart
# MATCH: 'Tears' → 'basal tears' labeled as HasPart
# MATCH: 'Tears' → 'reflex tears' labeled as HasPart
# MATCH: 'Tears' → 'Emotional tears' labeled as HasPart
# MATCH: 'Tears' → 'electrolytes' labeled as HasPart
# MATCH: 'Tears' → 'water' labeled as HasPart
# MATCH: 'Tears' → 'proteins' labeled as HasPart
# MATCH: 'Tears' → 'lipids' labeled as HasPart
# MATCH: 'Tears' → 'mucins' labeled as HasPart
# MATCH: 'tears' → 'emotional tears' labeled as HasPart
# MATCH: 'tears' → 'basal tears' labeled as HasPart
# MATCH: 'tears' → 'reflex tears' labeled as HasPart
# MATCH: 'tears' → 'Emotional tears' labeled as HasPart
# MATCH: 'tears' → 'electrolytes' labeled as HasPart
# MATCH: 'tears' → 'water' labeled as HasPart
# MATCH: 'tears' → 'proteins' labeled as HasPart
# MATCH: 'tears' → 'lipids' labeled as HasPart
# MATCH: 'tears' → 'mucins' labeled as HasPart
# MATCH: 'Crying' → 'frustration' labeled as InfluencedBy
# MATCH: 'Emotional tears' → 'stress-inducing hormones' labeled as InfluencedBy
# MATCH: 'Familial dysautonomia' → 'lack of overflow tears' labeled as HasEffect
# MATCH: 'Obstruction of the punctum' → 'Epiphora' labeled as Causes
#
# Generated 8190 total pairs
# 34 positive (labeled) | 8156 negative (NoRelation)
#
# Processing Graph 64/74
#
# Generating candidate pairs from 91 entities...
# Gold relation label count: 18
# MATCH: 'workaholism' → 'close friendships' labeled as HasEffect
# MATCH: 'workaholism' → 'family commitments' labeled as HasEffect
# MATCH: 'workaholism' → 'intimate relationships' labeled as HasEffect
# MATCH: 'work-family conflict' → 'occupational burnout' labeled as HasEffect
# MATCH: 'work-family conflict' → 'burnout' labeled as HasEffect
# MATCH: 'work-family conflict' → 'job stress' labeled as HasEffect
# MATCH: 'work-family conflict' → 'increased occupational burnout' labeled as HasEffect
# MATCH: 'work-family conflict' → 'decreased health' labeled as HasEffect
# MATCH: 'work-family conflict' → 'stress' labeled as HasEffect
# MATCH: 'work-family conflict' → 'job performance' labeled as HasEffect
# MATCH: 'work-family conflict' → 'commitment' labeled as HasEffect
# MATCH: 'work-family conflict' → 'organizational commitment' labeled as HasEffect
# MATCH: 'Work:family conflict' → 'family-friendly policies' labeled as ApprovedBy
# MATCH: 'family-to-work conflict' → 'work productivity' labeled as HasEffect
# MATCH: 'work:family conflict' → 'family-friendly policies' labeled as ApprovedBy
# MATCH: 'Workaholism' → 'close friendships' labeled as HasEffect
# MATCH: 'Workaholism' → 'family commitments' labeled as HasEffect
# MATCH: 'Workaholism' → 'intimate relationships' labeled as HasEffect
# MATCH: 'Family-to-work conflict' → 'work productivity' labeled as HasEffect
# MATCH: 'work-to-family conflict' → 'family life' labeled as HasEffect
# MATCH: 'motherhood penalty' → 'pay gap' labeled as HasEffect
# MATCH: 'Work-to-family conflict' → 'family life' labeled as HasEffect
# MATCH: 'Loehr and Schwartz' → 'WIF' labeled as ContributedToCreativeWork
# MATCH: 'Loehr' → 'WIF' labeled as ContributedToCreativeWork
#
# Generated 8190 total pairs
# 24 positive (labeled) | 8166 negative (NoRelation)
#
# Processing Graph 65/74
#
# Generating candidate pairs from 71 entities...
# Gold relation label count: 5
# MATCH: 'Mohammed Sani Musa' → 'Bill' labeled as OwnerOf
# MATCH: 'Mohammed Sani Musa' → 'Anti-social Media Bill' labeled as OwnerOf
# MATCH: 'Senator Mohammed Sani Musa' → 'Bill' labeled as OwnerOf
# MATCH: 'Senator Mohammed Sani Musa' → 'Anti-social Media Bill' labeled as OwnerOf
# MATCH: 'Bill' → 'Protection from Internet Falsehood and Manipulations Bill 2019' labeled as HasPart
# MATCH: 'Akon Eyakenyi' → 'Akwa Ibom State' labeled as Affiliation
# MATCH: 'Anti-social Media Bill' → 'Protection from Internet Falsehood and Manipulations Bill 2019' labeled as HasPart
#
# Generated 4970 total pairs
# 7 positive (labeled) | 4963 negative (NoRelation)
#
# Processing Graph 66/74
#
# Generating candidate pairs from 28 entities...
# Gold relation label count: 6
# MATCH: 'Cem Korkmaz' → 'State Theatre of Bursa' labeled as HasPart
# MATCH: 'Cem Korkmaz' → 'Kiraz Mevsimi' labeled as HasWorksInTheCollection
# MATCH: 'Cem Korkmaz' → 'Diğer Yarım' labeled as HasWorksInTheCollection
# MATCH: 'Cem Korkmaz' → 'Husband Factor' labeled as HasWorksInTheCollection
# MATCH: 'Cem Korkmaz' → 'Recep İvedik 4' labeled as HasWorksInTheCollection
# MATCH: 'Cem Korkmaz' → 'Mediakraft' labeled as NominatedFor
# MATCH: 'Korkmaz' → 'State Theatre of Bursa' labeled as HasPart
# MATCH: 'Korkmaz' → 'Kiraz Mevsimi' labeled as HasWorksInTheCollection
# MATCH: 'Korkmaz' → 'Diğer Yarım' labeled as HasWorksInTheCollection
# MATCH: 'Korkmaz' → 'Husband Factor' labeled as HasWorksInTheCollection
# MATCH: 'Korkmaz' → 'Recep İvedik 4' labeled as HasWorksInTheCollection
# MATCH: 'Korkmaz' → 'Mediakraft' labeled as NominatedFor
#
# Generated 756 total pairs
# 12 positive (labeled) | 744 negative (NoRelation)
#
# Processing Graph 67/74
#
# Generating candidate pairs from 14 entities...
# Gold relation label count: 4
# MATCH: 'Semantic Web' → 'RDF' labeled as Uses
# MATCH: 'Eiffel Tower' → 'Champ de Mars' labeled as LocatedIn
# MATCH: 'Gustave Eiffel' → 'Eiffel Tower' labeled as Creator
#
# Generated 182 total pairs
# 3 positive (labeled) | 179 negative (NoRelation)
#
# Processing Graph 68/74
#
# Generating candidate pairs from 42 entities...
# Gold relation label count: 14
# MATCH: 'GIS' → 'distributed GIS' labeled as PartOf
# MATCH: 'GIS' → 'Internet' labeled as Uses
# MATCH: 'GIS' → 'Distributed GIS' labeled as PartOf
# MATCH: 'GIS' → 'World Wide Web' labeled as BasedOn
# MATCH: 'GIS' → 'internet' labeled as Uses
# MATCH: 'GIS' → 'Web' labeled as BasedOn
# MATCH: 'Internet GIS' → 'distributed GIS' labeled as PartOf
# MATCH: 'Internet GIS' → 'Internet' labeled as Uses
# MATCH: 'Internet GIS' → 'Distributed GIS' labeled as PartOf
# MATCH: 'Internet GIS' → 'World Wide Web' labeled as BasedOn
# MATCH: 'Internet GIS' → 'internet' labeled as Uses
# MATCH: 'Internet GIS' → 'Web' labeled as BasedOn
# MATCH: 'internet GIS' → 'distributed GIS' labeled as PartOf
# MATCH: 'internet GIS' → 'Internet' labeled as Uses
# MATCH: 'internet GIS' → 'Distributed GIS' labeled as PartOf
# MATCH: 'internet GIS' → 'World Wide Web' labeled as BasedOn
# MATCH: 'internet GIS' → 'internet' labeled as Uses
# MATCH: 'internet GIS' → 'Web' labeled as BasedOn
# MATCH: 'Web GIS' → 'GIS' labeled as HasPart
# MATCH: 'Web GIS' → 'Internet GIS' labeled as HasPart
# MATCH: 'Web GIS' → 'internet GIS' labeled as HasPart
# MATCH: 'Roger Tomlinson' → 'Canadian Government' labeled as Affiliation
#
# Generated 1722 total pairs
# 22 positive (labeled) | 1700 negative (NoRelation)
#
# Processing Graph 69/74
#
# Generating candidate pairs from 37 entities...
# Gold relation label count: 2
# MATCH: 'PlaNet Computers and GlobeNet' → 'ISP services' labeled as HasPart
# MATCH: 'GlobeNet' → 'ISP services' labeled as HasPart
# MATCH: 'PlaNet Computers' → 'ISP services' labeled as HasPart
#
# Generated 1332 total pairs
# 3 positive (labeled) | 1329 negative (NoRelation)
#
# Processing Graph 70/74
#
# Generating candidate pairs from 60 entities...
# Gold relation label count: 11
# MATCH: '2000' → '2001' labeled as FollowedBy
# MATCH: 'Encyclopædia Britannica Eleventh Edition' → '2001' labeled as PublishedIn
#
# Generated 3540 total pairs
# 2 positive (labeled) | 3538 negative (NoRelation)
#
# Processing Graph 71/74
#
# Generating candidate pairs from 5 entities...
# Gold relation label count: 3
#
# Generated 20 total pairs
# 0 positive (labeled) | 20 negative (NoRelation)
#
# Processing Graph 72/74
#
# Generating candidate pairs from 74 entities...
# Gold relation label count: 18
# MATCH: 'OrionVM Wholesale Pty Limited' → 'white-label cloud platform' labeled as SaidToBeTheSameAs
# MATCH: 'OrionVM Wholesale Pty Limited' → 'platform' labeled as SaidToBeTheSameAs
# MATCH: 'OrionVM Wholesale Pty Limited' → 'cloud platform' labeled as SaidToBeTheSameAs
# MATCH: 'OrionVM Wholesale Pty Limited' → 'OrionVM Cloud Platform' labeled as OwnerOf
# MATCH: 'OrionVM Wholesale Pty Limited' → 'Cloud Platform' labeled as SaidToBeTheSameAs
# MATCH: 'OrionVM Wholesale Pty Limited' → 'Sheng Yeo' labeled as FoundedBy
# MATCH: 'OrionVM Wholesale Pty Limited' → 'Yeo' labeled as FoundedBy
# MATCH: 'OrionVM Wholesale Pty Limited' → 'Australian Startup Awards' labeled as NominatedFor
# MATCH: 'OrionVM Wholesale Pty Limited' → 'Cloud Platform' labeled as SaidToBeTheSameAs
# MATCH: 'OrionVM Wholesale Pty Limited' → 'OrionVM Cloud Platform' labeled as OwnerOf
# MATCH: 'OrionVM Wholesale Pty Limited' → 'Alex Sharp' labeled as FoundedBy
# MATCH: 'OrionVM Wholesale Pty Limited' → 'Sharp' labeled as FoundedBy
# MATCH: 'OrionVM Wholesale Pty Limited' → 'Joseph Glanville' labeled as FoundedBy
# MATCH: 'OrionVM Wholesale Pty Limited' → '2014 iAwards' labeled as NominatedFor
# MATCH: 'OrionVM Wholesale Pty Limited' → '2012 Australian Entrepreneur of the Year' labeled as NominatedFor
# MATCH: 'OrionVM Wholesale Pty Limited' → '2013 Ernst & Young Entrepreneur of the Year' labeled as NominatedFor
# MATCH: 'OrionVM Wholesale Pty Limited' → '2014 iAwards' labeled as NominatedFor
# MATCH: 'OrionVM Wholesale Pty Limited' → 'Stevie Award for New Product or Service of the Year' labeled as NominatedFor
# MATCH: 'OrionVM Wholesale Pty Limited' → 'Xen hypervisor' labeled as Uses
# MATCH: 'OrionVM Wholesale Pty Limited' → 'web panel' labeled as HasPart
# MATCH: 'OrionVM' → 'white-label cloud platform' labeled as SaidToBeTheSameAs
# MATCH: 'OrionVM' → 'platform' labeled as SaidToBeTheSameAs
# MATCH: 'OrionVM' → 'cloud platform' labeled as SaidToBeTheSameAs
# MATCH: 'OrionVM' → 'OrionVM Cloud Platform' labeled as OwnerOf
# MATCH: 'OrionVM' → 'Cloud Platform' labeled as SaidToBeTheSameAs
# MATCH: 'OrionVM' → 'Sheng Yeo' labeled as FoundedBy
# MATCH: 'OrionVM' → 'Yeo' labeled as FoundedBy
# MATCH: 'OrionVM' → 'Australian Startup Awards' labeled as NominatedFor
# MATCH: 'OrionVM' → 'Cloud Platform' labeled as SaidToBeTheSameAs
# MATCH: 'OrionVM' → 'OrionVM Cloud Platform' labeled as OwnerOf
# MATCH: 'OrionVM' → 'Alex Sharp' labeled as FoundedBy
# MATCH: 'OrionVM' → 'Sharp' labeled as FoundedBy
# MATCH: 'OrionVM' → 'Joseph Glanville' labeled as FoundedBy
# MATCH: 'OrionVM' → '2014 iAwards' labeled as NominatedFor
# MATCH: 'OrionVM' → '2012 Australian Entrepreneur of the Year' labeled as NominatedFor
# MATCH: 'OrionVM' → '2013 Ernst & Young Entrepreneur of the Year' labeled as NominatedFor
# MATCH: 'OrionVM' → '2014 iAwards' labeled as NominatedFor
# MATCH: 'OrionVM' → 'Stevie Award for New Product or Service of the Year' labeled as NominatedFor
# MATCH: 'OrionVM' → 'Xen hypervisor' labeled as Uses
# MATCH: 'OrionVM' → 'web panel' labeled as HasPart
# MATCH: 'Sheng Yeo' → '2012 Australian Entrepreneur of the Year' labeled as NominatedFor
# MATCH: 'Sheng Yeo' → '2013 Ernst & Young Entrepreneur of the Year' labeled as NominatedFor
# MATCH: 'Yeo' → '2012 Australian Entrepreneur of the Year' labeled as NominatedFor
# MATCH: 'Yeo' → '2013 Ernst & Young Entrepreneur of the Year' labeled as NominatedFor
# MATCH: 'San Francisco' → 'California' labeled as LocatedIn
# MATCH: 'Alex Sharp' → 'Hills YIA Cloud award' labeled as NominatedFor
# MATCH: 'Sharp' → 'Hills YIA Cloud award' labeled as NominatedFor
#
# Generated 5402 total pairs
# 47 positive (labeled) | 5355 negative (NoRelation)
#
# Processing Graph 73/74
#
# Generating candidate pairs from 5 entities...
# Gold relation label count: 3
# MATCH: 'Zheng' → 'Route panorama' labeled as Creator
# MATCH: 'Zheng' → 'route panorama' labeled as Creator
# MATCH: 'Tsuji' → 'Route panorama' labeled as Creator
# MATCH: 'Tsuji' → 'route panorama' labeled as Creator
#
# Generated 20 total pairs
# 4 positive (labeled) | 16 negative (NoRelation)
#
# Processing Graph 74/74
#
# Generating candidate pairs from 44 entities...
# Gold relation label count: 13
# MATCH: 'ZA Central Registry' → 'ZA Domain Name Authority' labeled as Partner
# MATCH: 'ZA Central Registry' → 'accredited ICANN registry' labeled as AwardReceived
# MATCH: 'ZA Central Registry' → '1988' labeled as Founded
# MATCH: 'ZA Central Registry' → 'Midrand' labeled as LocatedIn
# MATCH: 'ZA Central Registry' → 'Africa Union Commission' labeled as Partner
# MATCH: 'ZA Central Registry' → 'co.za' labeled as HasPart
# MATCH: 'ZA Central Registry' → 'Web.za' labeled as HasPart
# MATCH: 'ZA Central Registry' → 'web.za' labeled as HasPart
# MATCH: 'ZA Central Registry' → 'Web.Za' labeled as HasPart
# MATCH: 'ZA Central Registry' → 'Midrand, South Africa' labeled as LocatedIn
# MATCH: 'ZA Central Registry' → 'dotAfrica domain' labeled as NominatedFor
# MATCH: 'ZA Central Registry' → '.capetown' labeled as HasPart
# MATCH: 'ZA Central Registry' → '.durban' labeled as HasPart
# MATCH: 'ZA Central Registry' → '.joburg' labeled as HasPart
# MATCH: 'ZACR' → 'South Africa' labeled as Country
# MATCH: 'ZACR' → 'Africa Union Commission' labeled as Partner
# MATCH: 'ZACR' → 'Africa' labeled as Country
#
# Generated 1892 total pairs
# 17 positive (labeled) | 1875 negative (NoRelation)
#
# FINAL SUMMARY:
# Total Graphs: 74
# Total Candidate Pairs: 686920
# Total Positive (Labeled): 1323
# Total Negative (NoRelation): 685597

# %%
import torch
import numpy as np
from collections import defaultdict
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Label-to-ID map
relation_label_map = defaultdict(lambda: len(relation_label_map))
relation_label_map["NoRelation"] = 0  # reserve 0 for negatives

def average_span_embedding(bert_tensor, start, end):
    """Average BERT embedding over a span of tokens."""
    if start >= end or end > bert_tensor.shape[0]:
        return torch.zeros(bert_tensor.shape[1], device=bert_tensor.device)
    span_vecs = bert_tensor[start:end]
    return span_vecs.mean(dim=0)

def extract_relation_dataset(graphs, use_debug=True):
    X, y = [], []

    print(f"\nStarting feature extraction on {len(graphs)} graphs...")

    for g_idx, graph in enumerate(graphs):
        if use_debug:
            print(f"\nGraph {g_idx+1}/{len(graphs)}: {len(graph['entities'])} entities")

        # Convert BERT features to tensor
        bert_tensor = torch.tensor(graph["node_features"], dtype=torch.float).to(device)

        # Build lookup for gold relations using root indices
        gold_relations = {(rel["head"], rel["tail"]): rel["label"] for rel in graph["relation_labels"]}

        for i, head in enumerate(graph["entities"]):
            for j, tail in enumerate(graph["entities"]):
                if i == j:
                    continue

                head_idx = head["root"]
                tail_idx = tail["root"]
                label = gold_relations.get((head_idx, tail_idx), "NoRelation")
                label_id = relation_label_map[label]

                # Get span embeddings
                head_vec = average_span_embedding(bert_tensor, head["start"], head["end"])
                tail_vec = average_span_embedding(bert_tensor, tail["start"], tail["end"])

                # Combine features
                pair_vec = torch.cat([head_vec, tail_vec], dim=0).cpu().numpy()
                X.append(pair_vec)
                y.append(label_id)

                if use_debug and label != "NoRelation":
                    print(f"{head['text']} → {tail['text']} | Label: {label} (ID: {label_id})")
    print(f"\nTotal relation examples: {len(X)}")
    print(f"Class distribution:")
    for lbl, idx in sorted(relation_label_map.items(), key=lambda x: x[1]):
        count = sum(1 for yy in y if yy == idx)
        print(f"  {lbl:<35}: {count}")

    return np.array(X), np.array(y), dict(relation_label_map)

# Run the feature extraction
X, y, label_map = extract_relation_dataset(all_graphs, use_debug=True)

print(f"\nFeature shape: {X.shape}")
print(f"Labels shape:  {y.shape}")
print(f"Label map:     {label_map}")
# Out:
# Starting feature extraction on 74 graphs...
#
# Graph 1/74: 18 entities
# William Thomson → automatic curb sender | Label: Creator (ID: 1)
# Wheatstone transmitter → land line | Label: LocatedIn (ID: 2)
# automatic curb sender → cable | Label: LocatedIn (ID: 2)
# automatic curb sender → Eastern Telegraph Company | Label: UsedBy (ID: 3)
# automatic curb sender → telegraph key | Label: PartOf (ID: 4)
# automatic curb sender → Eastern Telegraph Company | Label: UsedBy (ID: 3)
#
# Graph 2/74: 14 entities
#
# Graph 3/74: 59 entities
# China Internet Network Information Center → Anti-Phishing Alliance of China (APAC) | Label: MemberOf (ID: 5)
# China Internet Network Information Center → Anti-Phishing Alliance of China | Label: MemberOf (ID: 5)
# China Internet Network Information Center → .cn domain name | Label: OwnerOf (ID: 6)
# China Internet Network Information Center → Ministry of Industry and Information Technology | Label: Affiliation (ID: 7)
# China Internet Network Information Center → Zhongguancun | Label: LocatedIn (ID: 2)
# China Internet Network Information Center → Zhongguancun, Beijing | Label: LocatedIn (ID: 2)
#
# Graph 4/74: 60 entities
# United States → China | Label: DiplomaticRelation (ID: 8)
#
# Graph 5/74: 54 entities
# FACS → Emotional Facial Action Coding System | Label: NominatedFor (ID: 9)
# FACS → Facial Action Coding System Affect Interpretation Dictionary (FACSAID) | Label: NominatedFor (ID: 9)
# FACS → psychologists | Label: UsedBy (ID: 3)
# FACS → animators | Label: UsedBy (ID: 3)
# FACS → computer animation | Label: PartOf (ID: 4)
# FACS → judo athletes | Label: AppliesToPeople (ID: 10)
# FACS → certification tests | Label: HasQuality (ID: 11)
# FACS → Emotional Facial Action Coding System (EMFACS) | Label: NominatedFor (ID: 9)
#
# Graph 6/74: 6 entities
# GIS → SAP | Label: HasPart (ID: 12)
# GIS → Global Learning Objects Brokered Exchange | Label: HasPart (ID: 12)
#
# Graph 7/74: 123 entities
# quae → 18th-century France | Label: Country (ID: 13)
# quae → France | Label: Country (ID: 13)
#
# Graph 8/74: 68 entities
# This psychological theory → RFT | Label: HasPart (ID: 12)
# Theory → regulatory fit theory | Label: InfluencedBy (ID: 14)
# Theory → Regulatory fit theory | Label: InfluencedBy (ID: 14)
# Theory → Regulatory Fit Theory | Label: InfluencedBy (ID: 14)
# Theory → Higgins | Label: HasWorksInTheCollection (ID: 15)
# Theory → E. Tory Higgins | Label: HasWorksInTheCollection (ID: 15)
# regulatory focus theory → regulatory fit theory | Label: InfluencedBy (ID: 14)
# regulatory focus theory → Regulatory fit theory | Label: InfluencedBy (ID: 14)
# regulatory focus theory → Regulatory Fit Theory | Label: InfluencedBy (ID: 14)
# regulatory focus theory → Higgins | Label: HasWorksInTheCollection (ID: 15)
# regulatory focus theory → E. Tory Higgins | Label: HasWorksInTheCollection (ID: 15)
# Regulatory focus theory → regulatory fit theory | Label: InfluencedBy (ID: 14)
# Regulatory focus theory → Regulatory fit theory | Label: InfluencedBy (ID: 14)
# Regulatory focus theory → Regulatory Fit Theory | Label: InfluencedBy (ID: 14)
# Regulatory focus theory → Higgins | Label: HasWorksInTheCollection (ID: 15)
# Regulatory focus theory → E. Tory Higgins | Label: HasWorksInTheCollection (ID: 15)
# theory → regulatory fit theory | Label: InfluencedBy (ID: 14)
# theory → Regulatory fit theory | Label: InfluencedBy (ID: 14)
# theory → Regulatory Fit Theory | Label: InfluencedBy (ID: 14)
# theory → Higgins | Label: HasWorksInTheCollection (ID: 15)
# theory → E. Tory Higgins | Label: HasWorksInTheCollection (ID: 15)
# Lee → regulatory focus orientations | Label: Studies (ID: 16)
# Higgins → Theory | Label: Creator (ID: 1)
# Higgins → regulatory focus theory | Label: Creator (ID: 1)
# Higgins → Regulatory focus theory | Label: Creator (ID: 1)
# Higgins → theory | Label: Creator (ID: 1)
# Higgins → Columbia University | Label: Affiliation (ID: 7)
# E. Tory Higgins → Theory | Label: Creator (ID: 1)
# E. Tory Higgins → regulatory focus theory | Label: Creator (ID: 1)
# E. Tory Higgins → Regulatory focus theory | Label: Creator (ID: 1)
# E. Tory Higgins → theory | Label: Creator (ID: 1)
# E. Tory Higgins → Columbia University | Label: Affiliation (ID: 7)
# Student A → promotion-focus orientation | Label: Uses (ID: 17)
# Student B → prevention-focus orientation | Label: Uses (ID: 17)
# Student A and Student B → promotion-focus orientation | Label: Uses (ID: 17)
# Lee and Aaker → regulatory focus orientations | Label: Studies (ID: 16)
#
# Graph 9/74: 82 entities
# United States → Japan | Label: DiplomaticRelation (ID: 8)
# United States → GB | Label: DiplomaticRelation (ID: 8)
# United States → Canada | Label: DiplomaticRelation (ID: 8)
# United States → North American | Label: Continent (ID: 18)
# Japanese Industrial Standards → Japan | Label: Country (ID: 13)
# Japan → Canada | Label: DiplomaticRelation (ID: 8)
# GB → Canada | Label: DiplomaticRelation (ID: 8)
# Canada → North American | Label: Continent (ID: 18)
#
# Graph 10/74: 99 entities
# New York City → Manhattan | Label: HasPart (ID: 12)
# New York City → lower Manhattan | Label: HasPart (ID: 12)
# New York City → English | Label: OfficialLanguage (ID: 19)
# San Francisco → English | Label: OfficialLanguage (ID: 19)
#
# Graph 11/74: 59 entities
# collective → Machias | Label: LocatedIn (ID: 2)
# collective → Machias, Maine | Label: LocatedIn (ID: 2)
# collective → Station Museum of Contemporary Art | Label: PresentedIn (ID: 20)
# collective → graphical media | Label: Uses (ID: 17)
# Beehive Design Collective → Machias | Label: LocatedIn (ID: 2)
# Beehive Design Collective → Machias, Maine | Label: LocatedIn (ID: 2)
# Beehive Design Collective → Station Museum of Contemporary Art | Label: PresentedIn (ID: 20)
# Beehive Design Collective → graphical media | Label: Uses (ID: 17)
# Collective → Machias | Label: LocatedIn (ID: 2)
# Collective → Machias, Maine | Label: LocatedIn (ID: 2)
# Collective → Station Museum of Contemporary Art | Label: PresentedIn (ID: 20)
# Collective → graphical media | Label: Uses (ID: 17)
# Machias Valley Grange Hall → collective | Label: InfluencedBy (ID: 14)
# Machias Valley Grange Hall → Beehive Design Collective | Label: InfluencedBy (ID: 14)
# Machias Valley Grange Hall → Collective | Label: InfluencedBy (ID: 14)
# Machias Valley Grange Hall → National Register of Historic Places | Label: LocatedIn (ID: 2)
# Machias Valley Grange Hall in Machias, Maine → collective | Label: InfluencedBy (ID: 14)
# Machias Valley Grange Hall in Machias, Maine → Beehive Design Collective | Label: InfluencedBy (ID: 14)
# Machias Valley Grange Hall in Machias, Maine → Collective | Label: InfluencedBy (ID: 14)
# Machias Valley Grange Hall in Machias, Maine → National Register of Historic Places | Label: LocatedIn (ID: 2)
#
# Graph 12/74: 46 entities
# Climate → campus culture | Label: DifferentFrom (ID: 21)
# campus climate → campus culture | Label: DifferentFrom (ID: 21)
# Campus climate → campus culture | Label: DifferentFrom (ID: 21)
# climate → campus culture | Label: DifferentFrom (ID: 21)
#
# Graph 13/74: 20 entities
#
# Graph 14/74: 42 entities
#
# Graph 15/74: 103 entities
# Field Museum → Chicago | Label: LocatedIn (ID: 2)
# Field Museum in Chicago → Chicago | Label: LocatedIn (ID: 2)
# Calgary Zoo → Canada | Label: LocatedIn (ID: 2)
# field trip → site-based program | Label: HasPart (ID: 12)
# field trip → follow-up activity | Label: HasPart (ID: 12)
# field trip → Activities | Label: HasPart (ID: 12)
# field trip → activities | Label: HasPart (ID: 12)
#
# Graph 16/74: 32 entities
# HEFCE → higher education funding | Label: HasPart (ID: 12)
#
# Graph 17/74: 45 entities
# Hospitality Management and Tourism → hospitality industry | Label: Studies (ID: 16)
# Hospitality Management → hospitality industry | Label: Studies (ID: 16)
# Hospitality management → hospitality industry | Label: Studies (ID: 16)
# hospitality management → hospitality industry | Label: Studies (ID: 16)
#
# Graph 18/74: 40 entities
# SESI Mathematics → Lei de Diretrizes e Bases da Educação Nacional | Label: BasedOn (ID: 22)
#
# Graph 19/74: 24 entities
# sophomore → senior | Label: DifferentFrom (ID: 21)
# sophomore → freshman | Label: DifferentFrom (ID: 21)
# sophomore → college or university studies | Label: PartOf (ID: 4)
# sophomore → junior | Label: DifferentFrom (ID: 21)
#
# Graph 20/74: 143 entities
# Mutual recognition of higher education qualifications → Lisbon Recognition Convention | Label: RegulatedBy (ID: 23)
# Mutual recognition of higher education qualifications → UNESCO/Council of Europe Lisbon Recognition Convention | Label: RegulatedBy (ID: 23)
# Mutual recognition of higher education qualifications → Council of Europe Lisbon Recognition Convention | Label: RegulatedBy (ID: 23)
# Graph 21/74: 50 entities
# Müllverwertung Rugenberger Damm WtE plant → Hamburg | Label: LocatedIn (ID: 2)
# Müllverwertung Rugenberger Damm WtE plant → Hamburg, Germany | Label: LocatedIn (ID: 2)
# Klean Power → advanced thermal recycling system | Label: OwnerOf (ID: 6)
#
# Graph 22/74: 22 entities
#
# Graph 23/74: 13 entities
#
# Graph 24/74: 149 entities
# Edison → Pearl Street Power Station | Label: OwnerOf (ID: 6)
# Thomas Edison → Pearl Street Power Station | Label: OwnerOf (ID: 6)
# New York City → America | Label: LocatedIn (ID: 2)
# New York City → North America | Label: LocatedIn (ID: 2)
#
# Graph 25/74: 32 entities
# Energy Management Software → real-time energy metering | Label: HasPart (ID: 12)
# Energy Management Software → grid services | Label: HasPart (ID: 12)
# Energy Management Software → utility bill tracking | Label: HasPart (ID: 12)
# Energy Management Software → generation control | Label: HasPart (ID: 12)
# Energy Management Software → carbon and sustainability reporting | Label: HasPart (ID: 12)
# Energy Management Software → consumption control | Label: HasPart (ID: 12)
# Energy Management Software → building simulation and modeling | Label: HasPart (ID: 12)
# Energy Management Software → IT equipment management | Label: HasPart (ID: 12)
# Energy Management Software → energy audits | Label: HasPart (ID: 12)
# Energy Management Software (EMS) → real-time energy metering | Label: HasPart (ID: 12)
# Energy Management Software (EMS) → grid services | Label: HasPart (ID: 12)
# Energy Management Software (EMS) → utility bill tracking | Label: HasPart (ID: 12)
# Energy Management Software (EMS) → generation control | Label: HasPart (ID: 12)
# Energy Management Software (EMS) → carbon and sustainability reporting | Label: HasPart (ID: 12)
# Energy Management Software (EMS) → consumption control | Label: HasPart (ID: 12)
# Energy Management Software (EMS) → building simulation and modeling | Label: HasPart (ID: 12)
# Energy Management Software (EMS) → IT equipment management | Label: HasPart (ID: 12)
# Energy Management Software (EMS) → energy audits | Label: HasPart (ID: 12)
# Energy management software → real-time energy metering | Label: HasPart (ID: 12)
# Energy management software → grid services | Label: HasPart (ID: 12)
# Energy management software → utility bill tracking | Label: HasPart (ID: 12)
# Energy management software → generation control | Label: HasPart (ID: 12)
# Energy management software → carbon and sustainability reporting | Label: HasPart (ID: 12)
# Energy management software → consumption control | Label: HasPart (ID: 12)
# Energy management software → building simulation and modeling | Label: HasPart (ID: 12)
# Energy management software → IT equipment management | Label: HasPart (ID: 12)
# Energy management software → energy audits | Label: HasPart (ID: 12)
#
# Graph 26/74: 83 entities
# ExxonMobil → Standard Oil Company of New York | Label: NamedAfter (ID: 24)
# ExxonMobil → U.S. | Label: Country (ID: 13)
# Neches River → U.S. | Label: Country (ID: 13)
# Burt Refining Company → Spindletop field | Label: OwnerOf (ID: 6)
# Spindletop → U.S. | Label: Country (ID: 13)
# Standard Oil Company of New York → U.S. | Label: Country (ID: 13)
# U.S. → World War II | Label: SignificantEvent (ID: 25)
#
# Graph 27/74: 32 entities
# Maksim Sonin → Stanford University | Label: WorkLocation (ID: 26)
# Maksim Sonin → Stanford University Hydrogen Initiative | Label: InterestedIn (ID: 27)
# Maksim Sonin → PhD | Label: AcademicDegree (ID: 28)
# Maksim Sonin → MS in Finance | Label: AcademicDegree (ID: 28)
# Maksim Sonin → PhD in Engineering | Label: AcademicDegree (ID: 28)
# Maksim Sonin → MS in Management | Label: AcademicDegree (ID: 28)
#
# Graph 28/74: 47 entities
# Soviet astronomer Nikolai Kardashev → Soviet | Label: CountryOfCitizenship (ID: 29)
# Nikolai Kardashev → Soviet | Label: CountryOfCitizenship (ID: 29)
# Michio Kaku → Physics of the Future | Label: Author (ID: 30)
# Type 0.73 civilization → Type I civilization | Label: DifferentFrom (ID: 21)
# Type I civilization → planetary civilization | Label: HasPart (ID: 12)
# planetary civilization → stellar civilization | Label: FollowedBy (ID: 31)
# Terrorism → type one civilization | Label: InOppositionTo (ID: 32)
# terrorism → type one civilization | Label: InOppositionTo (ID: 32)
#
# Graph 29/74: 101 entities
# Wälde → University of Dundee | Label: LocatedIn (ID: 2)
# Wälde → University of Dundee, Scotland | Label: LocatedIn (ID: 2)
# Wälde → Dundee, Scotland | Label: LocatedIn (ID: 2)
# Wälde → Bormes-Les-Mimosas | Label: WorkLocation (ID: 26)
# Wälde → Institute for International Economic Law | Label: WorkLocation (ID: 26)
# Wälde → Harvard Law School | Label: EducatedAt (ID: 33)
# Wälde → Detlev Vagts | Label: Follows (ID: 34)
# Wälde → ICJ president Roslyn Higgins | Label: Follows (ID: 34)
# Wälde → Roslyn Higgins | Label: Follows (ID: 34)
# Thomas W. Wälde → University of Dundee | Label: LocatedIn (ID: 2)
# Thomas W. Wälde → University of Dundee, Scotland | Label: LocatedIn (ID: 2)
# Thomas W. Wälde → Dundee, Scotland | Label: LocatedIn (ID: 2)
# Thomas W. Wälde → Bormes-Les-Mimosas | Label: WorkLocation (ID: 26)
# Thomas W. Wälde → Institute for International Economic Law | Label: WorkLocation (ID: 26)
# Thomas W. Wälde → Harvard Law School | Label: EducatedAt (ID: 33)
# Thomas W. Wälde → Detlev Vagts | Label: Follows (ID: 34)
# Thomas W. Wälde → ICJ president Roslyn Higgins | Label: Follows (ID: 34)
# Thomas W. Wälde → Roslyn Higgins | Label: Follows (ID: 34)
# Poland → Sweden | Label: DiplomaticRelation (ID: 8)
#
# Graph 30/74: 47 entities
# Uganda Energy Credit Capitalisation Company → government of Uganda | Label: OwnedBy (ID: 35)
# Uganda Energy Credit Capitalisation Company (UECCC) → government of Uganda | Label: OwnedBy (ID: 35)
# UECCC → World Bank | Label: Partner (ID: 36)
# UECCC → World Bank | Label: Partner (ID: 36)
#
# Graph 31/74: 56 entities
# Anvil firing → anvil launching | Label: SaidToBeTheSameAs (ID: 37)
# Anvil firing → anvil shooting | Label: SaidToBeTheSameAs (ID: 37)
# Anvil firing → New Westminster | Label: LocatedIn (ID: 2)
# Anvil firing → Black powder | Label: HasPart (ID: 12)
# Anvil firing → black powder | Label: HasPart (ID: 12)
# Anvil firing → traditional event | Label: PartOf (ID: 4)
# Anvil firing → stone base | Label: HasPart (ID: 12)
# anvil firing → anvil launching | Label: SaidToBeTheSameAs (ID: 37)
# anvil firing → anvil shooting | Label: SaidToBeTheSameAs (ID: 37)
# anvil firing → New Westminster | Label: LocatedIn (ID: 2)
# anvil firing → Black powder | Label: HasPart (ID: 12)
# anvil firing → black powder | Label: HasPart (ID: 12)
# anvil firing → traditional event | Label: PartOf (ID: 4)
# anvil firing → stone base | Label: HasPart (ID: 12)
# Victoria → United Kingdom | Label: OwnerOf (ID: 6)
# St. Clement's Day → Pope Clement I | Label: SignificantEvent (ID: 25)
# day → Pope Clement I | Label: SignificantEvent (ID: 25)
# anvil → gunpowder | Label: PhysicallyInteractsWith (ID: 38)
#
# Graph 32/74: 121 entities
# theatre → Charles Dibdin | Label: InterestedIn (ID: 27)
# theatre → Dibdin, Jr. | Label: InterestedIn (ID: 27)
# theatre → Charles Dibdin, Jr. | Label: InterestedIn (ID: 27)
# theatre → Dibdin | Label: InterestedIn (ID: 27)
# theatre → aqua drama | Label: HasPart (ID: 12)
# Sadler's Wells Theatre → Charles Dibdin | Label: InterestedIn (ID: 27)
# Sadler's Wells Theatre → Dibdin, Jr. | Label: InterestedIn (ID: 27)
# Sadler's Wells Theatre → Charles Dibdin, Jr. | Label: InterestedIn (ID: 27)
# Sadler's Wells Theatre → Dibdin | Label: InterestedIn (ID: 27)
# Sadler's Wells Theatre → aqua drama | Label: HasPart (ID: 12)
# Wells Theatre → Charles Dibdin | Label: InterestedIn (ID: 27)
# Wells Theatre → Dibdin, Jr. | Label: InterestedIn (ID: 27)
# Wells Theatre → Charles Dibdin, Jr. | Label: InterestedIn (ID: 27)
# Wells Theatre → Dibdin | Label: InterestedIn (ID: 27)
# Wells Theatre → aqua drama | Label: HasPart (ID: 12)
# theatre → Charles Dibdin | Label: InterestedIn (ID: 27)
# theatre → Dibdin, Jr. | Label: InterestedIn (ID: 27)
# theatre → Charles Dibdin, Jr. | Label: InterestedIn (ID: 27)
# theatre → Dibdin | Label: InterestedIn (ID: 27)
# theatre → aqua drama | Label: HasPart (ID: 12)
# Theatre → Charles Dibdin | Label: InterestedIn (ID: 27)
# Theatre → Dibdin, Jr. | Label: InterestedIn (ID: 27)
# Theatre → Charles Dibdin, Jr. | Label: InterestedIn (ID: 27)
# Theatre → Dibdin | Label: InterestedIn (ID: 27)
# Theatre → aqua drama | Label: HasPart (ID: 12)
# Charles Dibdin → theatre | Label: InterestedIn (ID: 27)
# Charles Dibdin → Sadler's Wells Theatre | Label: InterestedIn (ID: 27)
# Charles Dibdin → Wells Theatre | Label: InterestedIn (ID: 27)
# Charles Dibdin → theatre | Label: InterestedIn (ID: 27)
# Charles Dibdin → Theatre | Label: InterestedIn (ID: 27)
# Dibdin, Jr. → theatre | Label: InterestedIn (ID: 27)
# Dibdin, Jr. → Sadler's Wells Theatre | Label: InterestedIn (ID: 27)
# Dibdin, Jr. → Wells Theatre | Label: InterestedIn (ID: 27)
# Dibdin, Jr. → theatre | Label: InterestedIn (ID: 27)
# Dibdin, Jr. → Theatre | Label: InterestedIn (ID: 27)
# Charles Dibdin, Jr. → theatre | Label: InterestedIn (ID: 27)
# Charles Dibdin, Jr. → Sadler's Wells Theatre | Label: InterestedIn (ID: 27)
# Charles Dibdin, Jr. → Wells Theatre | Label: InterestedIn (ID: 27)
# Charles Dibdin, Jr. → theatre | Label: InterestedIn (ID: 27)
# Charles Dibdin, Jr. → Theatre | Label: InterestedIn (ID: 27)
# Dibdin → theatre | Label: InterestedIn (ID: 27)
# Dibdin → Sadler's Wells Theatre | Label: InterestedIn (ID: 27)
# Dibdin → Wells Theatre | Label: InterestedIn (ID: 27)
# Dibdin → theatre | Label: InterestedIn (ID: 27)
# Dibdin → Theatre | Label: InterestedIn (ID: 27)
# Siege of Gibraltar → theatre | Label: SignificantEvent (ID: 25)
# Siege of Gibraltar → Sadler's Wells Theatre | Label: SignificantEvent (ID: 25)
# Siege of Gibraltar → Wells Theatre | Label: SignificantEvent (ID: 25)
# Siege of Gibraltar → theatre | Label: SignificantEvent (ID: 25)
# Siege of Gibraltar → Theatre | Label: SignificantEvent (ID: 25)
# Siege of Gibraltar → aqua drama | Label: SignificantEvent (ID: 25)
# HMS Bounty → Island or Christian and His Comrades | Label: InterestedIn (ID: 27)
# HMS Bounty → Island | Label: InterestedIn (ID: 27)
# Napoleonic wars → early 1800s | Label: SignificantEvent (ID: 25)
# Napoleonic wars → early 1800s | Label: SignificantEvent (ID: 25)
# Napoleonic wars → aqua drama | Label: HasEffect (ID: 39)
#
# Graph 33/74: 60 entities
# Delfines Hotel & Convention Center → Delfines Hotel & Casino | Label: SaidToBeTheSameAs (ID: 37)
# Delfines Hotel & Convention Center → Hotel Los Delfines | Label: SaidToBeTheSameAs (ID: 37)
# Delfines Hotel & Convention Center → San Isidro District, Lima, Peru | Label: LocatedIn (ID: 2)
# Delfines Hotel & Convention Center → San Isidro District | Label: LocatedIn (ID: 2)
# Delfines Hotel & Convention Center → Jacques Levy Calvo | Label: OwnerOf (ID: 6)
# Delfines Hotel & Convention Center → Salón Mediterráneo | Label: HasPart (ID: 12)
# Yaku → Delfines Hotel & Convention Center | Label: HasEffect (ID: 39)
# Yaku → Mexico | Label: LocatedIn (ID: 2)
# Yaku → Jamaica | Label: LocatedIn (ID: 2)
# Yaku → c. 1988 | Label: Founded (ID: 40)
# Yaku → Dolphin Cove Jamaica | Label: LocatedIn (ID: 2)
# Yaku → calf | Label: PartOf (ID: 4)
# Yaku → cardiac issues | Label: HasEffect (ID: 39)
# Yaku → Yaku's cardiac issues | Label: HasEffect (ID: 39)
# Wayra → Delfines Hotel & Convention Center | Label: InterestedIn (ID: 27)
# Wayra → Mexico | Label: LocatedIn (ID: 2)
# Wayra → Jamaica | Label: LocatedIn (ID: 2)
# Wayra → c. 1992 | Label: Founded (ID: 40)
# Wayra → Dolphin Cove Jamaica | Label: LocatedIn (ID: 2)
# Judiciary of Peru → Delfines Hotel & Convention Center | Label: HasEffect (ID: 39)
#
# Graph 34/74: 195 entities
# Metro Trains → Dumb Ways to Die | Label: HasEffect (ID: 39)
# Metro Trains → Dumb Ways to Die | Label: HasEffect (ID: 39)
# Metro Trains → dumb ways to die | Label: HasEffect (ID: 39)
# Dumb Ways to Die 3: World Tour → Dumb Ways to Die 2: The Games | Label: Follows (ID: 34)
# a Dumb Ways to Die → Patrick Baron | Label: Creator (ID: 1)
# a Dumb Ways to Die → Julian Frost | Label: Creator (ID: 1)
# a Dumb Ways to Die → Samuel Baird | Label: Creator (ID: 1)
# Dumb Ways to Die 3: → Dumb Ways to Die 2: The Games | Label: Follows (ID: 34)
# Dumb Ways to Dash → Dumb Ways to Die | Label: InspiredBy (ID: 41)
# Dumb Ways to Dash → Dumb Ways to Die | Label: InspiredBy (ID: 41)
# Dumb Ways to Dash → dumb ways to die | Label: InspiredBy (ID: 41)
# Dumb Ways to Die 4 → Dumb Ways to Die 3: World Tour | Label: Follows (ID: 34)
# Dumb Ways to Die 4 → Dumb Ways to Die 3: | Label: Follows (ID: 34)
# Dumb Ways to Die 4 → Dumb Ways to Die 3 | Label: Follows (ID: 34)
# Dumb Ways to Die 2: The Games → 18 November 2014 | Label: Founded (ID: 40)
# Dumb Ways to Die 2: The Games → a Dumb Ways to Die | Label: Follows (ID: 34)
# Dumb Ways to Die 2: The Games → Dumb Ways to Die game | Label: Follows (ID: 34)
# Dumb Ways to Die → Metro Trains | Label: InterestedIn (ID: 27)
# Dumb Ways to Die → advertising agency McCann Melbourne | Label: Creator (ID: 1)
# Dumb Ways to Die → McGill | Label: OwnerOf (ID: 6)
# Dumb Ways to Die → YouTube | Label: HasEffect (ID: 39)
# Dumb Ways to Die → PlaySide Studios | Label: InspiredBy (ID: 41)
# Dumb Ways to Die → a Dumb Ways to Die | Label: HasWorksInTheCollection (ID: 15)
# Dumb Ways to Die → song "Dumb Ways to Die" | Label: HasPart (ID: 12)
# Dumb Ways to Die → Dumb Ways to Die game | Label: HasWorksInTheCollection (ID: 15)
# Dumb Ways to Die → song | Label: HasPart (ID: 12)
# Dumb Ways to Die → at least $50 million worth of global media value | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Ollie McGill | Label: OwnerOf (ID: 6)
# Dumb Ways to Die → Safety | Label: HasEffect (ID: 39)
# Dumb Ways to Die → railway safety | Label: HasEffect (ID: 39)
# Dumb Ways to Die → safety | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Susie O'Brien | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Webby Awards | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Gold Lions | Label: HasEffect (ID: 39)
# Dumb Ways to Die → two Bronze Lions | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Siren Awards | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Bronze Lions | Label: HasEffect (ID: 39)
# Dumb Ways to Die → three Silver Lions | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Silver Lions | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Grand Trophy | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Grand Trophy in the 2013 New York Festivals International Advertising Awards | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Grand Prix awards | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Grand Prix | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Integrated Grand Prix | Label: HasEffect (ID: 39)
# Dumb Ways to Die → five Grand Prix awards | Label: HasEffect (ID: 39)
# Dumb Ways to Die → app | Label: PartOf (ID: 4)
# Dumb Ways to Die → mobile app | Label: PartOf (ID: 4)
# Dumb Ways to Die → seven Webby Awards | Label: HasEffect (ID: 39)
# Dumb Ways to Die → 18 Gold Lions | Label: HasEffect (ID: 39)
# Dumb Ways to Die 3 → Dumb Ways to Die 2: The Games | Label: Follows (ID: 34)
# Dumb Ways to Draw → 5 May 2019 | Label: Founded (ID: 40)
# Dumb Ways to Draw → Dumb Ways to Die | Label: Follows (ID: 34)
# Dumb Ways to Draw → Dumb Ways to Die | Label: Follows (ID: 34)
# Dumb Ways to Draw → dumb ways to die | Label: Follows (ID: 34)
# Dumb Ways to Die game → Patrick Baron | Label: Creator (ID: 1)
# Dumb Ways to Die game → Julian Frost | Label: Creator (ID: 1)
# Dumb Ways to Die game → Samuel Baird | Label: Creator (ID: 1)
# Tumblr → English | Label: Uses (ID: 17)
# John Mescall → song "Dumb Ways to Die" | Label: Creator (ID: 1)
# John Mescall → song | Label: Creator (ID: 1)
# Dumb Ways to Die → Metro Trains | Label: InterestedIn (ID: 27)
# Dumb Ways to Die → advertising agency McCann Melbourne | Label: Creator (ID: 1)
# Dumb Ways to Die → McGill | Label: OwnerOf (ID: 6)
# Dumb Ways to Die → YouTube | Label: HasEffect (ID: 39)
# Dumb Ways to Die → PlaySide Studios | Label: InspiredBy (ID: 41)
# Dumb Ways to Die → a Dumb Ways to Die | Label: HasWorksInTheCollection (ID: 15)
# Dumb Ways to Die → song "Dumb Ways to Die" | Label: HasPart (ID: 12)
# Dumb Ways to Die → Dumb Ways to Die game | Label: HasWorksInTheCollection (ID: 15)
# Dumb Ways to Die → song | Label: HasPart (ID: 12)
# Dumb Ways to Die → at least $50 million worth of global media value | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Ollie McGill | Label: OwnerOf (ID: 6)
# Dumb Ways to Die → Safety | Label: HasEffect (ID: 39)
# Dumb Ways to Die → railway safety | Label: HasEffect (ID: 39)
# Dumb Ways to Die → safety | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Susie O'Brien | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Webby Awards | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Gold Lions | Label: HasEffect (ID: 39)
# Dumb Ways to Die → two Bronze Lions | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Siren Awards | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Bronze Lions | Label: HasEffect (ID: 39)
# Dumb Ways to Die → three Silver Lions | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Silver Lions | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Grand Trophy | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Grand Trophy in the 2013 New York Festivals International Advertising Awards | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Grand Prix awards | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Grand Prix | Label: HasEffect (ID: 39)
# Dumb Ways to Die → Integrated Grand Prix | Label: HasEffect (ID: 39)
# Dumb Ways to Die → five Grand Prix awards | Label: HasEffect (ID: 39)
# Dumb Ways to Die → app | Label: PartOf (ID: 4)
# Dumb Ways to Die → mobile app | Label: PartOf (ID: 4)
# Dumb Ways to Die → seven Webby Awards | Label: HasEffect (ID: 39)
# Dumb Ways to Die → 18 Gold Lions | Label: HasEffect (ID: 39)
# dumb ways to die → Metro Trains | Label: InterestedIn (ID: 27)
# dumb ways to die → advertising agency McCann Melbourne | Label: Creator (ID: 1)
# dumb ways to die → McGill | Label: OwnerOf (ID: 6)
# dumb ways to die → YouTube | Label: HasEffect (ID: 39)
# dumb ways to die → PlaySide Studios | Label: InspiredBy (ID: 41)
# dumb ways to die → a Dumb Ways to Die | Label: HasWorksInTheCollection (ID: 15)
# dumb ways to die → song "Dumb Ways to Die" | Label: HasPart (ID: 12)
# dumb ways to die → Dumb Ways to Die game | Label: HasWorksInTheCollection (ID: 15)
# dumb ways to die → song | Label: HasPart (ID: 12)
# dumb ways to die → at least $50 million worth of global media value | Label: HasEffect (ID: 39)
# dumb ways to die → Ollie McGill | Label: OwnerOf (ID: 6)
# dumb ways to die → Safety | Label: HasEffect (ID: 39)
# dumb ways to die → railway safety | Label: HasEffect (ID: 39)
# dumb ways to die → safety | Label: HasEffect (ID: 39)
# dumb ways to die → Susie O'Brien | Label: HasEffect (ID: 39)
# dumb ways to die → Webby Awards | Label: HasEffect (ID: 39)
# dumb ways to die → Gold Lions | Label: HasEffect (ID: 39)
# dumb ways to die → two Bronze Lions | Label: HasEffect (ID: 39)
# dumb ways to die → Siren Awards | Label: HasEffect (ID: 39)
# dumb ways to die → Bronze Lions | Label: HasEffect (ID: 39)
# dumb ways to die → three Silver Lions | Label: HasEffect (ID: 39)
# dumb ways to die → Silver Lions | Label: HasEffect (ID: 39)
# dumb ways to die → Grand Trophy | Label: HasEffect (ID: 39)
# dumb ways to die → Grand Trophy in the 2013 New York Festivals International Advertising Awards | Label: HasEffect (ID: 39)
# dumb ways to die → Grand Prix awards | Label: HasEffect (ID: 39)
# dumb ways to die → Grand Prix | Label: HasEffect (ID: 39)
# dumb ways to die → Integrated Grand Prix | Label: HasEffect (ID: 39)
# dumb ways to die → five Grand Prix awards | Label: HasEffect (ID: 39)
# dumb ways to die → app | Label: PartOf (ID: 4)
# dumb ways to die → mobile app | Label: PartOf (ID: 4)
# dumb ways to die → seven Webby Awards | Label: HasEffect (ID: 39)
# dumb ways to die → 18 Gold Lions | Label: HasEffect (ID: 39)
# Graph 35/74: 52 entities
# elegiac comedies → vernacular language | Label: Uses (ID: 17)
# vernacular writers → Boccaccio | Label: HasPart (ID: 12)
# vernacular writers → Chaucer | Label: HasPart (ID: 12)
# vernacular writers → Gower | Label: HasPart (ID: 12)
# Thompson → elegiac comedies | Label: HasEffect (ID: 39)
#
# Graph 36/74: 63 entities
# Russell Lincoln Ackoff → 1967 | Label: SignificantEvent (ID: 25)
# Howard → Metagame Analysis in Political Problems | Label: Author (ID: 30)
# Howard → Metagame Analysis | Label: Author (ID: 30)
# Nigel Howard → Metagame Analysis in Political Problems | Label: Author (ID: 30)
# Nigel Howard → Metagame Analysis | Label: Author (ID: 30)
# Nigel Howard's book → 1971 | Label: Founded (ID: 40)
# Garfield → 1995 | Label: SignificantEvent (ID: 25)
# Garfield → Magic: The Gathering | Label: Creator (ID: 1)
# Richard Garfield → 1995 | Label: SignificantEvent (ID: 25)
# Richard Garfield → Magic: The Gathering | Label: Creator (ID: 1)
# Aron Nimzowitsch → hypermodern openings | Label: HasEffect (ID: 39)
#
# Graph 37/74: 49 entities
# Canada → UK | Label: Follows (ID: 34)
# Heelwork to music → Kennel club | Label: InterestedIn (ID: 27)
# Heelwork to Music → Kennel club | Label: InterestedIn (ID: 27)
# heelwork to music → Kennel club | Label: InterestedIn (ID: 27)
# musical canine freestyle → Musical Freestyle | Label: HasPart (ID: 12)
# musical canine freestyle → Musical freestyle | Label: HasPart (ID: 12)
# musical canine freestyle → musical freestyle | Label: HasPart (ID: 12)
# canine freestyle → Musical Freestyle | Label: HasPart (ID: 12)
# canine freestyle → Musical freestyle | Label: HasPart (ID: 12)
# canine freestyle → musical freestyle | Label: HasPart (ID: 12)
# Musical Canine Sports International → 1991 | Label: Founded (ID: 40)
# Musical Canine Sports International → British Columbia | Label: Founded (ID: 40)
# Musical Canine Sports International → British Columbia, Canada | Label: Founded (ID: 40)
# Musical Freestyle → Canada | Label: LocatedIn (ID: 2)
# Musical Freestyle → England | Label: LocatedIn (ID: 2)
# Musical Freestyle → United States | Label: LocatedIn (ID: 2)
# Musical Freestyle → Netherlands | Label: LocatedIn (ID: 2)
# Musical Freestyle → musical canine freestyle | Label: SaidToBeTheSameAs (ID: 37)
# Musical Freestyle → canine freestyle | Label: SaidToBeTheSameAs (ID: 37)
# Musical Freestyle → Musical Canine Sports International | Label: OwnerOf (ID: 6)
# Musical Freestyle → Musical freestyle | Label: SaidToBeTheSameAs (ID: 37)
# Musical Freestyle → musical freestyle | Label: SaidToBeTheSameAs (ID: 37)
# Musical Freestyle → freestyle dance | Label: SaidToBeTheSameAs (ID: 37)
# Musical freestyle → Canada | Label: LocatedIn (ID: 2)
# Musical freestyle → England | Label: LocatedIn (ID: 2)
# Musical freestyle → United States | Label: LocatedIn (ID: 2)
# Musical freestyle → Netherlands | Label: LocatedIn (ID: 2)
# Musical freestyle → musical canine freestyle | Label: SaidToBeTheSameAs (ID: 37)
# Musical freestyle → canine freestyle | Label: SaidToBeTheSameAs (ID: 37)
# Musical freestyle → Musical Canine Sports International | Label: OwnerOf (ID: 6)
# Musical freestyle → Musical Freestyle | Label: SaidToBeTheSameAs (ID: 37)
# Musical freestyle → musical freestyle | Label: SaidToBeTheSameAs (ID: 37)
# Musical freestyle → freestyle dance | Label: SaidToBeTheSameAs (ID: 37)
# musical freestyle → Canada | Label: LocatedIn (ID: 2)
# musical freestyle → England | Label: LocatedIn (ID: 2)
# musical freestyle → United States | Label: LocatedIn (ID: 2)
# musical freestyle → Netherlands | Label: LocatedIn (ID: 2)
# musical freestyle → musical canine freestyle | Label: SaidToBeTheSameAs (ID: 37)
# musical freestyle → canine freestyle | Label: SaidToBeTheSameAs (ID: 37)
# musical freestyle → Musical Canine Sports International | Label: OwnerOf (ID: 6)
# musical freestyle → Musical Freestyle | Label: SaidToBeTheSameAs (ID: 37)
# musical freestyle → Musical freestyle | Label: SaidToBeTheSameAs (ID: 37)
# musical freestyle → freestyle dance | Label: SaidToBeTheSameAs (ID: 37)
#
# Graph 38/74: 46 entities
# Jeff Hull → Nonchalance | Label: HasEffect (ID: 39)
# Jejune Institute → San Francisco | Label: LocatedIn (ID: 2)
# Jejune Institute → San Francisco, California | Label: LocatedIn (ID: 2)
# Jejune Institute → Best World | Label: NominatedFor (ID: 9)
# Jejune Institute → "Best Alternate Reality" | Label: HasEffect (ID: 39)
# Jejune Institute → Best Alternate Reality | Label: HasEffect (ID: 39)
# Jejune Institute → "Best World" | Label: NominatedFor (ID: 9)
# Jejune Institute → "Best Story" | Label: HasEffect (ID: 39)
# Jejune Institute → Best Story | Label: HasEffect (ID: 39)
# Latitude Society → Nonchalance | Label: Creator (ID: 1)
# SYGNYL → Nonchalance | Label: HasWorksInTheCollection (ID: 15)
# Nonchalance → Oakland, California | Label: LocatedIn (ID: 2)
# Nonchalance → Oakland | Label: LocatedIn (ID: 2)
# Nonchalance → San Francisco | Label: LocatedIn (ID: 2)
# Nonchalance → San Francisco, California | Label: LocatedIn (ID: 2)
# Nonchalance → Jejune Institute | Label: InterestedIn (ID: 27)
# Nonchalance → Latitude Society | Label: HasPart (ID: 12)
#
# Graph 39/74: 30 entities
# Rene Peter Onno Rubiono van Helsdingen → Komter Loeber | Label: HasEffect (ID: 39)
# Rene Peter Onno Rubiono van Helsdingen → Netherlands | Label: LocatedIn (ID: 2)
# Rene Peter Onno Rubiono van Helsdingen → Jakarta | Label: HasEffect (ID: 39)
# Rene Peter Onno Rubiono van Helsdingen → 1962:72 | Label: SignificantEvent (ID: 25)
# Rene Peter Onno Rubiono van Helsdingen → Lazlo Cser | Label: HasEffect (ID: 39)
# Rene Peter Onno Rubiono van Helsdingen → 1979 | Label: SignificantEvent (ID: 25)
# Rene Peter Onno Rubiono van Helsdingen → Oscar Peterson | Label: HasEffect (ID: 39)
# Rene Peter Onno Rubiono van Helsdingen → Virgin | Label: HasEffect (ID: 39)
# Rene Peter Onno Rubiono van Helsdingen → WEA | Label: HasEffect (ID: 39)
# Rene Peter Onno Rubiono van Helsdingen → successful tours, projects and festivals | Label: Creator (ID: 1)
# Rene Peter Onno Rubiono van Helsdingen → Lazlo Cser | Label: HasEffect (ID: 39)
# Rene Peter Onno Rubiono van Helsdingen → Timeless | Label: HasEffect (ID: 39)
# Rene Peter Onno Rubiono van Helsdingen → Dureco | Label: HasEffect (ID: 39)
# Rene Peter Onno Rubiono van Helsdingen → Pacific Music | Label: HasEffect (ID: 39)
# Rene Peter Onno Rubiono van Helsdingen → demajors Independent Music Industry Jakarta | Label: HasEffect (ID: 39)
# Dutch → Netherlands | Label: NominatedFor (ID: 9)
#
# Graph 40/74: 94 entities
# Rule 63 → gender flipping | Label: HasEffect (ID: 39)
# Demitri Maximoff → Midnight Bliss | Label: HasPart (ID: 12)
# Demitri Maximoff → SNK vs. Capcom | Label: PartOf (ID: 4)
# Demitri Maximoff → gender flipping | Label: PracticedBy (ID: 42)
# Maximoff → Midnight Bliss | Label: HasPart (ID: 12)
# Maximoff → SNK vs. Capcom | Label: PartOf (ID: 4)
# Maximoff → gender flipping | Label: PracticedBy (ID: 42)
# Midnight Bliss → Demitri Maximoff | Label: SaidToBeTheSameAs (ID: 37)
# Midnight Bliss → Maximoff | Label: SaidToBeTheSameAs (ID: 37)
# Bowsette → Bowser | Label: DifferentFrom (ID: 21)
# Bowsette → Princess Peach | Label: InspiredBy (ID: 41)
# Loud House → One of the Boys | Label: SaidToBeTheSameAs (ID: 37)
# Shovel Knight → Body Swap Mode | Label: HasPart (ID: 12)
# Sheik → female-to-male gender-swapping | Label: PartOf (ID: 4)
# character Sheik → female-to-male gender-swapping | Label: PartOf (ID: 4)
# fanworks → cosplay | Label: HasPart (ID: 12)
# fanworks → fan art | Label: HasPart (ID: 12)
# fanworks → fan fiction | Label: HasPart (ID: 12)
#
# Graph 41/74: 189 entities
# Varsity Brands → Herff Jones | Label: HasEffect (ID: 39)
# Varsity Brands → American Cheerleader magazine | Label: OwnerOf (ID: 6)
# Universal Cheerleaders Association → 1974 | Label: Founded (ID: 40)
# UCA → Jeff Webb | Label: Creator (ID: 1)
# Varsity Spirit, LLC → Varsity Brands | Label: OwnerOf (ID: 6)
# Varsity Spirit, LLC → Universal Cheerleaders Association | Label: InterestedIn (ID: 27)
# Varsity Spirit, LLC → Varsity Spirit | Label: SaidToBeTheSameAs (ID: 37)
# Varsity Spirit, LLC → American Cheerleader magazine | Label: InterestedIn (ID: 27)
# Varsity Spirit, LLC → American Cheerleader | Label: HasWorksInTheCollection (ID: 15)
# Varsity Spirit, LLC → U.S. All Star Federation | Label: InterestedIn (ID: 27)
# Varsity Spirit, LLC → Jeff Webb | Label: Creator (ID: 1)
# Varsity Spirit, LLC → USA Cheer | Label: OwnerOf (ID: 6)
# Varsity Spirit, LLC → $82.5 million | Label: InterestedIn (ID: 27)
# Varsity Spirit, LLC → $43.5 million | Label: InterestedIn (ID: 27)
# Varsity Spirit, LLC → National Spirit Group | Label: InspiredBy (ID: 41)
# Varsity Spirit, LLC → Athletic Championships LLC | Label: InterestedIn (ID: 27)
# Varsity Spirit, LLC → Premier Athletics LLC | Label: InterestedIn (ID: 27)
# Varsity Spirit, LLC → Memphis Grizzlies | Label: InterestedIn (ID: 27)
# Varsity Spirit, LLC → JAM Brands | Label: OwnerOf (ID: 6)
# Varsity Spirit, LLC → Star Athletica | Label: InterestedIn (ID: 27)
# Varsity Spirit, LLC → NBA's Memphis Grizzlies | Label: InterestedIn (ID: 27)
# Varsity Spirit, LLC → SA Feather Co. | Label: InspiredBy (ID: 41)
# Varsity Spirit, LLC → Stanbury Uniforms | Label: InterestedIn (ID: 27)
# Varsity Spirit, LLC → International Cheer Union | Label: InterestedIn (ID: 27)
# Varsity Spirit → Varsity Brands | Label: OwnerOf (ID: 6)
# Varsity Spirit → Universal Cheerleaders Association | Label: InterestedIn (ID: 27)
# Varsity Spirit → Varsity Spirit, LLC | Label: SaidToBeTheSameAs (ID: 37)
# Varsity Spirit → American Cheerleader magazine | Label: InterestedIn (ID: 27)
# Varsity Spirit → American Cheerleader | Label: HasWorksInTheCollection (ID: 15)
# Varsity Spirit → U.S. All Star Federation | Label: InterestedIn (ID: 27)
# Varsity Spirit → Jeff Webb | Label: Creator (ID: 1)
# Varsity Spirit → USA Cheer | Label: OwnerOf (ID: 6)
# Varsity Spirit → $82.5 million | Label: InterestedIn (ID: 27)
# Varsity Spirit → $43.5 million | Label: InterestedIn (ID: 27)
# Varsity Spirit → National Spirit Group | Label: InspiredBy (ID: 41)
# Varsity Spirit → Athletic Championships LLC | Label: InterestedIn (ID: 27)
# Varsity Spirit → Premier Athletics LLC | Label: InterestedIn (ID: 27)
# Varsity Spirit → Memphis Grizzlies | Label: InterestedIn (ID: 27)
# Varsity Spirit → JAM Brands | Label: OwnerOf (ID: 6)
# Varsity Spirit → Star Athletica | Label: InterestedIn (ID: 27)
# Varsity Spirit → NBA's Memphis Grizzlies | Label: InterestedIn (ID: 27)
# Varsity Spirit → SA Feather Co. | Label: InspiredBy (ID: 41)
# Varsity Spirit → Stanbury Uniforms | Label: InterestedIn (ID: 27)
# Varsity Spirit → International Cheer Union | Label: InterestedIn (ID: 27)
# American → U.S. | Label: SaidToBeTheSameAs (ID: 37)
# American → U.S. | Label: SaidToBeTheSameAs (ID: 37)
# American Cheerleader magazine → 1995 | Label: Founded (ID: 40)
# American Cheerleader magazine → Lifestyle Ventures | Label: OwnerOf (ID: 6)
# American Cheerleader magazine → Lifestyle Ventures, LLC | Label: OwnerOf (ID: 6)
# U.S. → New York | Label: NominatedFor (ID: 9)
# U.S. → U.S. | Label: SaidToBeTheSameAs (ID: 37)
# U.S. → California | Label: NominatedFor (ID: 9)
# U.S. → Texas | Label: NominatedFor (ID: 9)
# USASF → Varsity Spirit, LLC | Label: Follows (ID: 34)
# USASF → Varsity Spirit | Label: Follows (ID: 34)
# Jeff Webb → Varsity Brands | Label: Creator (ID: 1)
# Jeff Webb → Varsity Spirit, LLC | Label: Creator (ID: 1)
# Jeff Webb → Varsity Spirit | Label: Creator (ID: 1)
# Jeff Webb → National Cheerleaders Association | Label: InterestedIn (ID: 27)
# National Cheerleaders Association → U.S. | Label: NominatedFor (ID: 9)
# National Cheerleaders Association → U.S. | Label: NominatedFor (ID: 9)
# National College Cheerleading Championship → 1978 | Label: Founded (ID: 40)
# National Spirit Group → NCA | Label: OwnerOf (ID: 6)
# Knoxville → U.S. | Label: NominatedFor (ID: 9)
# Knoxville → U.S. | Label: NominatedFor (ID: 9)
# Star Athletica → U.S. | Label: LocatedIn (ID: 2)
# Star Athletica → U.S. | Label: LocatedIn (ID: 2)
# Kim Conley → U.S. | Label: LocatedIn (ID: 2)
# Kim Conley → U.S. | Label: LocatedIn (ID: 2)
# Managing Editor Kim Conley → U.S. | Label: LocatedIn (ID: 2)
# Managing Editor Kim Conley → U.S. | Label: LocatedIn (ID: 2)
# New York → U.S. | Label: NominatedFor (ID: 9)
# New York → U.S. | Label: NominatedFor (ID: 9)
# Lifestyle Media, Inc. → Macfadden Performing Arts Media, LLC | Label: InterestedIn (ID: 27)
# Lifestyle Media, Inc. → Macfadden Performing Arts Media | Label: InterestedIn (ID: 27)
# CBS → U.S. | Label: LocatedIn (ID: 2)
# CBS → U.S. | Label: LocatedIn (ID: 2)
# Debby Ryan → U.S. | Label: InterestedIn (ID: 27)
# Debby Ryan → U.S. | Label: InterestedIn (ID: 27)
# Kendall Jenner → U.S. | Label: InterestedIn (ID: 27)
# Kendall Jenner → U.S. | Label: InterestedIn (ID: 27)
# Heather Morris → U.S. | Label: InterestedIn (ID: 27)
# Heather Morris → U.S. | Label: InterestedIn (ID: 27)
# Christina Milian → U.S. | Label: InterestedIn (ID: 27)
# Christina Milian → U.S. | Label: InterestedIn (ID: 27)
# Kirsten Dunst → U.S. | Label: InterestedIn (ID: 27)
# Kirsten Dunst → U.S. | Label: InterestedIn (ID: 27)
# Hilarie Burton → U.S. | Label: InterestedIn (ID: 27)
# Hilarie Burton → U.S. | Label: InterestedIn (ID: 27)
# Ashley Tisdale → U.S. | Label: InterestedIn (ID: 27)
# Ashley Tisdale → U.S. | Label: InterestedIn (ID: 27)
# Olivia Holt → U.S. | Label: LocatedIn (ID: 2)
# Olivia Holt → U.S. | Label: LocatedIn (ID: 2)
# U.S. → U.S. | Label: SaidToBeTheSameAs (ID: 37)
# U.S. → New York | Label: NominatedFor (ID: 9)
# U.S. → California | Label: NominatedFor (ID: 9)
# U.S. → Texas | Label: NominatedFor (ID: 9)
#
# Graph 42/74: 44 entities
# white label promo → white label | Label: HasPart (ID: 12)
# white label promo → White label | Label: HasPart (ID: 12)
# Steve Beckett → Warp Records | Label: OwnerOf (ID: 6)
# Steve Beckett of Warp Records → Warp Records | Label: OwnerOf (ID: 6)
# white labels → small amounts | Label: HasEffect (ID: 39)
# white labels → unauthorized remixes | Label: HasPart (ID: 12)
# white label record → Test pressings | Label: HasPart (ID: 12)
# white label record → test pressings | Label: HasPart (ID: 12)
# White labels → small amounts | Label: HasEffect (ID: 39)
# White labels → unauthorized remixes | Label: HasPart (ID: 12)
# Test pressings → very small quantities | Label: HasEffect (ID: 39)
# test pressings → very small quantities | Label: HasEffect (ID: 39)
# unauthorized remixes → bootlegs | Label: SaidToBeTheSameAs (ID: 37)
#
# Graph 43/74: 412 entities
# COG → PRC | Label: DiplomaticRelation (ID: 8)
# COG → French | Label: LanguageUsed (ID: 43)
# continuity of government → defined procedures | Label: HasPart (ID: 12)
# Continuity of government → defined procedures | Label: HasPart (ID: 12)
# World War II → United States | Label: HasEffect (ID: 39)
# World War II → Soviet Union | Label: HasEffect (ID: 39)
# World War II → PRC | Label: Location (ID: 44)
# World War II → Russia | Label: Location (ID: 44)
# United States → Soviet Union | Label: DiplomaticRelation (ID: 8)
# United States → Canada | Label: SharesBorderWith (ID: 45)
# United States → PRC | Label: DiplomaticRelation (ID: 8)
# United States → Denmark | Label: DiplomaticRelation (ID: 8)
# United States → Ireland | Label: DiplomaticRelation (ID: 8)
# United States → Russia | Label: DiplomaticRelation (ID: 8)
# United States → Sweden | Label: DiplomaticRelation (ID: 8)
# United States → Turkey | Label: DiplomaticRelation (ID: 8)
# years → French | Label: LanguageOfWorkOrName (ID: 46)
# years following the federation of Australia in 1901 → French | Label: LanguageOfWorkOrName (ID: 46)
# Australian Government → Plan Marcator | Label: HasPart (ID: 12)
# Australian Government → continuity of government plans | Label: HasPart (ID: 12)
# Australian Government → 'Plan Mercator' | Label: HasPart (ID: 12)
# Australian Government → Plan Mercator | Label: HasPart (ID: 12)
# modern Australian Government → Plan Marcator | Label: HasPart (ID: 12)
# modern Australian Government → continuity of government plans | Label: HasPart (ID: 12)
# modern Australian Government → 'Plan Mercator' | Label: HasPart (ID: 12)
# modern Australian Government → Plan Mercator | Label: HasPart (ID: 12)
# One → two | Label: FollowedBy (ID: 31)
# One → Two | Label: FollowedBy (ID: 31)
# Soviet Union → Canada | Label: DiplomaticRelation (ID: 8)
# Soviet Union → PRC | Label: SharesBorderWith (ID: 45)
# Soviet Union → Denmark | Label: DiplomaticRelation (ID: 8)
# Soviet Union → Turkey | Label: SharesBorderWith (ID: 45)
# Canada → PRC | Label: DiplomaticRelation (ID: 8)
# Canada → Denmark | Label: DiplomaticRelation (ID: 8)
# Canada → French | Label: OfficialLanguage (ID: 19)
# Canada → Ireland | Label: DiplomaticRelation (ID: 8)
# Canada → Russia | Label: DiplomaticRelation (ID: 8)
# Canada → Sweden | Label: DiplomaticRelation (ID: 8)
# Canada → Turkey | Label: DiplomaticRelation (ID: 8)
# two → Two | Label: PrimeFactor (ID: 47)
# PRC → Hubei | Label: ContainsTheAdministrativeTerritorialEntity (ID: 48)
# PRC → Denmark | Label: DiplomaticRelation (ID: 8)
# PRC → Ireland | Label: DiplomaticRelation (ID: 8)
# PRC → Russia | Label: SharesBorderWith (ID: 45)
# PRC → Sweden | Label: DiplomaticRelation (ID: 8)
# PRC → Turkey | Label: DiplomaticRelation (ID: 8)
# Denmark → Ireland | Label: DiplomaticRelation (ID: 8)
# Denmark → Russia | Label: DiplomaticRelation (ID: 8)
# Denmark → Sweden | Label: SharesBorderWith (ID: 45)
# Denmark → Turkey | Label: DiplomaticRelation (ID: 8)
# one → two | Label: FollowedBy (ID: 31)
# one → Two | Label: FollowedBy (ID: 31)
# Ireland → Russia | Label: DiplomaticRelation (ID: 8)
# Smolensk → Russia | Label: Country (ID: 13)
# Russia → Sweden | Label: SharesBorderWith (ID: 45)
# Russia → Turkey | Label: DiplomaticRelation (ID: 8)
# Two → two | Label: PrimeFactor (ID: 47)
# Klara skyddsrum → Sweden | Label: Country (ID: 13)
# Sweden → Turkey | Label: DiplomaticRelation (ID: 8)
#
# Graph 44/74: 251 entities
# Derg → People's Democratic Republic of Ethiopia | Label: OwnerOf (ID: 6)
# Derg → Ethiopian People's Revolutionary Democratic Front | Label: HasPart (ID: 12)
# Derg → Eritrean People's Liberation Front | Label: DifferentFrom (ID: 21)
# Derg → Eritrean People's Liberation Front (EPLF) | Label: DifferentFrom (ID: 21)
# Derg → Amharic language | Label: OfficialLanguage (ID: 19)
# Derg → Ethiopian People's Revolutionary Democratic Front (EPRDF) | Label: HasPart (ID: 12)
# Tigray People's Liberation Front → Ethiopian People's Revolutionary Democratic Front | Label: HasPart (ID: 12)
# Tigray People's Liberation Front → Ethiopian People's Revolutionary Democratic Front (EPRDF) | Label: HasPart (ID: 12)
# Eritrean Liberation Movement → Eritrean Liberation Front | Label: HasPart (ID: 12)
# Eritrean Liberation Movement → Eritrean Liberation Front | Label: HasPart (ID: 12)
# Eritrean Liberation Movement → Eritrean Liberation Front (ELF) | Label: HasPart (ID: 12)
# Eritrean Liberation Movement (ELM) → Eritrean Liberation Front | Label: HasPart (ID: 12)
# Eritrean Liberation Movement (ELM) → Eritrean Liberation Front | Label: HasPart (ID: 12)
# Eritrean Liberation Movement (ELM) → Eritrean Liberation Front (ELF) | Label: HasPart (ID: 12)
# Emperor Haile Selassie → Derg | Label: ParentOrganization (ID: 49)
# Haile Selassie → Derg | Label: ParentOrganization (ID: 49)
# 1270 → two | Label: PrimeFactor (ID: 47)
# Tigray People's Liberation Front → Ethiopian People's Revolutionary Democratic Front | Label: HasPart (ID: 12)
# Tigray People's Liberation Front → Ethiopian People's Revolutionary Democratic Front (EPRDF) | Label: HasPart (ID: 12)
# Tigray People's Liberation Front (TPLF) → Ethiopian People's Revolutionary Democratic Front | Label: HasPart (ID: 12)
# Tigray People's Liberation Front (TPLF) → Ethiopian People's Revolutionary Democratic Front (EPRDF) | Label: HasPart (ID: 12)
# EPLF → Eritrean Liberation Front Army | Label: HasPart (ID: 12)
# EPLF → Eritrean Liberation Front Army (EPLA) | Label: HasPart (ID: 12)
# Eritrean People's Liberation Front → Derg | Label: Follows (ID: 34)
# Eritrean People's Liberation Front (EPLF) → Derg | Label: Follows (ID: 34)
# Tigray People's Liberation Front (TPLF) → Ethiopian People's Revolutionary Democratic Front | Label: HasPart (ID: 12)
# ...
# Namnyak → Stockholm Syndrome | Label: ContributedToCreativeWork (ID: 65)
#
# Graph 63/74: 91 entities
# Bogorad's syndrome → crocodile tears syndrome | Label: SaidToBeTheSameAs (ID: 37)
# Bogorad's syndrome → Crocodile Tears Syndrome | Label: SaidToBeTheSameAs (ID: 37)
# Pseudobulbar affect → uncontrollable laughter | Label: HasPart (ID: 12)
# Pseudobulbar affect → episodic uncontrollable laughter or crying | Label: HasPart (ID: 12)
# Pseudobulbar affect → uncontrollable laughter or crying | Label: HasPart (ID: 12)
# Pseudobulbar affect → neurological injuries | Label: InfluencedBy (ID: 14)
# Pseudobulbar affect (PBA) → uncontrollable laughter | Label: HasPart (ID: 12)
# Pseudobulbar affect (PBA) → episodic uncontrollable laughter or crying | Label: HasPart (ID: 12)
# Pseudobulbar affect (PBA) → uncontrollable laughter or crying | Label: HasPart (ID: 12)
# Pseudobulbar affect (PBA) → neurological injuries | Label: InfluencedBy (ID: 14)
# emotional tears → stress-inducing hormones | Label: InfluencedBy (ID: 14)
# crying → frustration | Label: InfluencedBy (ID: 14)
# Tears → emotional tears | Label: HasPart (ID: 12)
# Tears → basal tears | Label: HasPart (ID: 12)
# Tears → reflex tears | Label: HasPart (ID: 12)
# Tears → Emotional tears | Label: HasPart (ID: 12)
# Tears → electrolytes | Label: HasPart (ID: 12)
# Tears → water | Label: HasPart (ID: 12)
# Tears → proteins | Label: HasPart (ID: 12)
# Tears → lipids | Label: HasPart (ID: 12)
# Tears → mucins | Label: HasPart (ID: 12)
# tears → emotional tears | Label: HasPart (ID: 12)
# tears → basal tears | Label: HasPart (ID: 12)
# tears → reflex tears | Label: HasPart (ID: 12)
# tears → Emotional tears | Label: HasPart (ID: 12)
# tears → electrolytes | Label: HasPart (ID: 12)
# tears → water | Label: HasPart (ID: 12)
# tears → proteins | Label: HasPart (ID: 12)
# tears → lipids | Label: HasPart (ID: 12)
# tears → mucins | Label: HasPart (ID: 12)
# Crying → frustration | Label: InfluencedBy (ID: 14)
# Emotional tears → stress-inducing hormones | Label: InfluencedBy (ID: 14)
# Familial dysautonomia → lack of overflow tears | Label: HasEffect (ID: 39)
# Obstruction of the punctum → Epiphora | Label: Causes (ID: 68)
#
# Graph 64/74: 91 entities
# workaholism → close friendships | Label: HasEffect (ID: 39)
# workaholism → family commitments | Label: HasEffect (ID: 39)
# workaholism → intimate relationships | Label: HasEffect (ID: 39)
# work-family conflict → occupational burnout | Label: HasEffect (ID: 39)
# work-family conflict → burnout | Label: HasEffect (ID: 39)
# work-family conflict → job stress | Label: HasEffect (ID: 39)
# work-family conflict → increased occupational burnout | Label: HasEffect (ID: 39)
# work-family conflict → decreased health | Label: HasEffect (ID: 39)
# work-family conflict → stress | Label: HasEffect (ID: 39)
# work-family conflict → job performance | Label: HasEffect (ID: 39)
# work-family conflict → commitment | Label: HasEffect (ID: 39)
# work-family conflict → organizational commitment | Label: HasEffect (ID: 39)
# Work:family conflict → family-friendly policies | Label: ApprovedBy (ID: 67)
# family-to-work conflict → work productivity | Label: HasEffect (ID: 39)
# work:family conflict → family-friendly policies | Label: ApprovedBy (ID: 67)
# Workaholism → close friendships | Label: HasEffect (ID: 39)
# Workaholism → family commitments | Label: HasEffect (ID: 39)
# Workaholism → intimate relationships | Label: HasEffect (ID: 39)
# Family-to-work conflict → work productivity | Label: HasEffect (ID: 39)
# work-to-family conflict → family life | Label: HasEffect (ID: 39)
# motherhood penalty → pay gap | Label: HasEffect (ID: 39)
# Work-to-family conflict → family life | Label: HasEffect (ID: 39)
# Loehr and Schwartz → WIF | Label: ContributedToCreativeWork (ID: 65)
# Loehr → WIF | Label: ContributedToCreativeWork (ID: 65)
#
# Graph 65/74: 71 entities
# Mohammed Sani Musa → Bill | Label: OwnerOf (ID: 6)
# Mohammed Sani Musa → Anti-social Media Bill | Label: OwnerOf (ID: 6)
# Senator Mohammed Sani Musa → Bill | Label: OwnerOf (ID: 6)
# Senator Mohammed Sani Musa → Anti-social Media Bill | Label: OwnerOf (ID: 6)
# Bill → Protection from Internet Falsehood and Manipulations Bill 2019 | Label: HasPart (ID: 12)
# Akon Eyakenyi → Akwa Ibom State | Label: Affiliation (ID: 7)
# Anti-social Media Bill → Protection from Internet Falsehood and Manipulations Bill 2019 | Label: HasPart (ID: 12)
#
# Graph 66/74: 28 entities
# Cem Korkmaz → State Theatre of Bursa | Label: HasPart (ID: 12)
# Cem Korkmaz → Kiraz Mevsimi | Label: HasWorksInTheCollection (ID: 15)
# Cem Korkmaz → Diğer Yarım | Label: HasWorksInTheCollection (ID: 15)
# Cem Korkmaz → Husband Factor | Label: HasWorksInTheCollection (ID: 15)
# Cem Korkmaz → Recep İvedik 4 | Label: HasWorksInTheCollection (ID: 15)
# Cem Korkmaz → Mediakraft | Label: NominatedFor (ID: 9)
# Korkmaz → State Theatre of Bursa | Label: HasPart (ID: 12)
# Korkmaz → Kiraz Mevsimi | Label: HasWorksInTheCollection (ID: 15)
# Korkmaz → Diğer Yarım | Label: HasWorksInTheCollection (ID: 15)
# Korkmaz → Husband Factor | Label: HasWorksInTheCollection (ID: 15)
# Korkmaz → Recep İvedik 4 | Label: HasWorksInTheCollection (ID: 15)
# Korkmaz → Mediakraft | Label: NominatedFor (ID: 9)
#
# Graph 67/74: 14 entities
# Semantic Web → RDF | Label: Uses (ID: 17)
# Eiffel Tower → Champ de Mars | Label: LocatedIn (ID: 2)
# Gustave Eiffel → Eiffel Tower | Label: Creator (ID: 1)
#
# Graph 68/74: 42 entities
# GIS → distributed GIS | Label: PartOf (ID: 4)
# GIS → Internet | Label: Uses (ID: 17)
# GIS → Distributed GIS | Label: PartOf (ID: 4)
# GIS → World Wide Web | Label: BasedOn (ID: 22)
# GIS → internet | Label: Uses (ID: 17)
# GIS → Web | Label: BasedOn (ID: 22)
# Internet GIS → distributed GIS | Label: PartOf (ID: 4)
# Internet GIS → Internet | Label: Uses (ID: 17)
# Internet GIS → Distributed GIS | Label: PartOf (ID: 4)
# Internet GIS → World Wide Web | Label: BasedOn (ID: 22)
# Internet GIS → internet | Label: Uses (ID: 17)
# Internet GIS → Web | Label: BasedOn (ID: 22)
# internet GIS → distributed GIS | Label: PartOf (ID: 4)
# internet GIS → Internet | Label: Uses (ID: 17)
# internet GIS → Distributed GIS | Label: PartOf (ID: 4)
# internet GIS → World Wide Web | Label: BasedOn (ID: 22)
# internet GIS → internet | Label: Uses (ID: 17)
# internet GIS → Web | Label: BasedOn (ID: 22)
# Web GIS → GIS | Label: HasPart (ID: 12)
# Web GIS → Internet GIS | Label: HasPart (ID: 12)
# Web GIS → internet GIS | Label: HasPart (ID: 12)
# Roger Tomlinson → Canadian Government | Label: Affiliation (ID: 7)
#
# Graph 69/74: 37 entities
# PlaNet Computers and GlobeNet → ISP services | Label: HasPart (ID: 12)
# GlobeNet → ISP services | Label: HasPart (ID: 12)
# PlaNet Computers → ISP services | Label: HasPart (ID: 12)
#
# Graph 70/74: 60 entities
# 2000 → 2001 | Label: FollowedBy (ID: 31)
# Encyclopædia Britannica Eleventh Edition → 2001 | Label: PublishedIn (ID: 61)
#
# Graph 71/74: 5 entities
#
# Graph 72/74: 74 entities
# OrionVM Wholesale Pty Limited → white-label cloud platform | Label: SaidToBeTheSameAs (ID: 37)
# OrionVM Wholesale Pty Limited → platform | Label: SaidToBeTheSameAs (ID: 37)
# OrionVM Wholesale Pty Limited → cloud platform | Label: SaidToBeTheSameAs (ID: 37)
# OrionVM Wholesale Pty Limited → OrionVM Cloud Platform | Label: OwnerOf (ID: 6)
# OrionVM Wholesale Pty Limited → Cloud Platform | Label: SaidToBeTheSameAs (ID: 37)
# OrionVM Wholesale Pty Limited → Sheng Yeo | Label: FoundedBy (ID: 71)
# OrionVM Wholesale Pty Limited → Yeo | Label: FoundedBy (ID: 71)
# OrionVM Wholesale Pty Limited → Australian Startup Awards | Label: NominatedFor (ID: 9)
# OrionVM Wholesale Pty Limited → Cloud Platform | Label: SaidToBeTheSameAs (ID: 37)
# OrionVM Wholesale Pty Limited → OrionVM Cloud Platform | Label: OwnerOf (ID: 6)
# OrionVM Wholesale Pty Limited → Alex Sharp | Label: FoundedBy (ID: 71)
# OrionVM Wholesale Pty Limited → Sharp | Label: FoundedBy (ID: 71)
# OrionVM Wholesale Pty Limited → Joseph Glanville | Label: FoundedBy (ID: 71)
# OrionVM Wholesale Pty Limited → 2014 iAwards | Label: NominatedFor (ID: 9)
# OrionVM Wholesale Pty Limited → 2012 Australian Entrepreneur of the Year | Label: NominatedFor (ID: 9)
# OrionVM Wholesale Pty Limited → 2013 Ernst & Young Entrepreneur of the Year | Label: NominatedFor (ID: 9)
# OrionVM Wholesale Pty Limited → 2014 iAwards | Label: NominatedFor (ID: 9)
# OrionVM Wholesale Pty Limited → Stevie Award for New Product or Service of the Year | Label: NominatedFor (ID: 9)
# OrionVM Wholesale Pty Limited → Xen hypervisor | Label: Uses (ID: 17)
# OrionVM Wholesale Pty Limited → web panel | Label: HasPart (ID: 12)
# OrionVM → white-label cloud platform | Label: SaidToBeTheSameAs (ID: 37)
# OrionVM → platform | Label: SaidToBeTheSameAs (ID: 37)
# OrionVM → cloud platform | Label: SaidToBeTheSameAs (ID: 37)
# OrionVM → OrionVM Cloud Platform | Label: OwnerOf (ID: 6)
# OrionVM → Cloud Platform | Label: SaidToBeTheSameAs (ID: 37)
# OrionVM → Sheng Yeo | Label: FoundedBy (ID: 71)
# OrionVM → Yeo | Label: FoundedBy (ID: 71)
# OrionVM → Australian Startup Awards | Label: NominatedFor (ID: 9)
# OrionVM → Cloud Platform | Label: SaidToBeTheSameAs (ID: 37)
# OrionVM → OrionVM Cloud Platform | Label: OwnerOf (ID: 6)
# OrionVM → Alex Sharp | Label: FoundedBy (ID: 71)
# OrionVM → Sharp | Label: FoundedBy (ID: 71)
# OrionVM → Joseph Glanville | Label: FoundedBy (ID: 71)
# OrionVM → 2014 iAwards | Label: NominatedFor (ID: 9)
# OrionVM → 2012 Australian Entrepreneur of the Year | Label: NominatedFor (ID: 9)
# OrionVM → 2013 Ernst & Young Entrepreneur of the Year | Label: NominatedFor (ID: 9)
# OrionVM → 2014 iAwards | Label: NominatedFor (ID: 9)
# OrionVM → Stevie Award for New Product or Service of the Year | Label: NominatedFor (ID: 9)
# OrionVM → Xen hypervisor | Label: Uses (ID: 17)
# OrionVM → web panel | Label: HasPart (ID: 12)
# Sheng Yeo → 2012 Australian Entrepreneur of the Year | Label: NominatedFor (ID: 9)
# Sheng Yeo → 2013 Ernst & Young Entrepreneur of the Year | Label: NominatedFor (ID: 9)
# Yeo → 2012 Australian Entrepreneur of the Year | Label: NominatedFor (ID: 9)
# Yeo → 2013 Ernst & Young Entrepreneur of the Year | Label: NominatedFor (ID: 9)
# San Francisco → California | Label: LocatedIn (ID: 2)
# Alex Sharp → Hills YIA Cloud award | Label: NominatedFor (ID: 9)
# Sharp → Hills YIA Cloud award | Label: NominatedFor (ID: 9)
#
# Graph 73/74: 5 entities
# Zheng → Route panorama | Label: Creator (ID: 1)
# Zheng → route panorama | Label: Creator (ID: 1)
# Tsuji → Route panorama | Label: Creator (ID: 1)
# Tsuji → route panorama | Label: Creator (ID: 1)
#
# Graph 74/74: 44 entities
# ZA Central Registry → ZA Domain Name Authority | Label: Partner (ID: 36)
# ZA Central Registry → accredited ICANN registry | Label: AwardReceived (ID: 72)
# ZA Central Registry → 1988 | Label: Founded (ID: 40)
# ZA Central Registry → Midrand | Label: LocatedIn (ID: 2)
# ZA Central Registry → Africa Union Commission | Label: Partner (ID: 36)
# ZA Central Registry → co.za | Label: HasPart (ID: 12)
# ZA Central Registry → Web.za | Label: HasPart (ID: 12)
# ZA Central Registry → web.za | Label: HasPart (ID: 12)
# ZA Central Registry → Web.Za | Label: HasPart (ID: 12)
# ZA Central Registry → Midrand, South Africa | Label: LocatedIn (ID: 2)
# ZA Central Registry → dotAfrica domain | Label: NominatedFor (ID: 9)
# ZA Central Registry → .capetown | Label: HasPart (ID: 12)
# ZA Central Registry → .durban | Label: HasPart (ID: 12)
# ZA Central Registry → .joburg | Label: HasPart (ID: 12)
# ZACR → South Africa | Label: Country (ID: 13)
# ZACR → Africa Union Commission | Label: Partner (ID: 36)
# ZACR → Africa | Label: Country (ID: 13)
#
# Total relation examples: 686920
# Class distribution:
#   NoRelation                         : 685597
#   Creator                            : 35
#   LocatedIn                          : 70
#   UsedBy                             : 36
#   PartOf                             : 30
#   MemberOf                           : 2
#   OwnerOf                            : 52
#   Affiliation                        : 21
#   DiplomaticRelation                 : 40
#   NominatedFor                       : 48
#   AppliesToPeople                    : 1
#   HasQuality                         : 1
#   HasPart                            : 201
#   Country                            : 14
#   InfluencedBy                       : 37
#   HasWorksInTheCollection            : 25
#   Studies                            : 11
#   Uses                               : 21
#   Continent                          : 2
#   OfficialLanguage                   : 5
#   PresentedIn                        : 3
#   DifferentFrom                      : 13
#   BasedOn                            : 30
#   RegulatedBy                        : 3
#   NamedAfter                         : 1
#   SignificantEvent                   : 17
#   WorkLocation                       : 5
#   InterestedIn                       : 92
#   AcademicDegree                     : 4
#   CountryOfCitizenship               : 5
#   Author                             : 5
#   FollowedBy                         : 9
#   InOppositionTo                     : 2
#   EducatedAt                         : 5
#   Follows                            : 22
#   OwnedBy                            : 2
#   Partner                            : 5
#   SaidToBeTheSameAs                  : 61
#   PhysicallyInteractsWith            : 1
#   HasEffect                          : 145
#   Founded                            : 12
#   InspiredBy                         : 11
#   PracticedBy                        : 2
#   LanguageUsed                       : 1
#   Location                           : 2
#   SharesBorderWith                   : 8
#   LanguageOfWorkOrName               : 4
#   PrimeFactor                        : 14
#   ContainsTheAdministrativeTerritorialEntity: 1
#   ParentOrganization                 : 2
#   NativeLanguage                     : 2
#   PartyChiefRepresentative           : 2
#   Capital                            : 1
#   TwinnedAdministrativeBody          : 1
#   OriginalLanguageOfFilmOrTvShow     : 4
#   Director                           : 4
#   PositionHeld                       : 8
#   PlaceOfBirth                       : 1
#   OperatingSystem                    : 1
#   IssuedBy                           : 15
#   CitesWork                          : 3
#   PublishedIn                        : 13
#   Employer                           : 1
#   Developer                          : 1
#   AdjacentStation                    : 7
#   ContributedToCreativeWork          : 37
#   FieldOfWork                        : 4
#   ApprovedBy                         : 49
#   Causes                             : 17
#   HasCause                           : 1
#   NamedBy                            : 1
#   FoundedBy                          : 10
#   AwardReceived                      : 1
#
# Feature shape: (686920, 1536)
# Labels shape:  (686920,)
# Label map:     {'NoRelation': 0, 'Creator': 1, 'LocatedIn': 2, 'UsedBy': 3, 'PartOf': 4, 'MemberOf': 5, 'OwnerOf': 6, 'Affiliation': 7, 'DiplomaticRelation': 8, 'NominatedFor': 9, 'AppliesToPeople': 10, 'HasQuality': 11, 'HasPart': 12, 'Country': 13, 'InfluencedBy': 14, 'HasWorksInTheCollection': 15, 'Studies': 16, 'Uses': 17, 'Continent': 18, 'OfficialLanguage': 19, 'PresentedIn': 20, 'DifferentFrom': 21, 'BasedOn': 22, 'RegulatedBy': 23, 'NamedAfter': 24, 'SignificantEvent': 25, 'WorkLocation': 26, 'InterestedIn': 27, 'AcademicDegree': 28, 'CountryOfCitizenship': 29, 'Author': 30, 'FollowedBy': 31, 'InOppositionTo': 32, 'EducatedAt': 33, 'Follows': 34, 'OwnedBy': 35, 'Partner': 36, 'SaidToBeTheSameAs': 37, 'PhysicallyInteractsWith': 38, 'HasEffect': 39, 'Founded': 40, 'InspiredBy': 41, 'PracticedBy': 42, 'LanguageUsed': 43, 'Location': 44, 'SharesBorderWith': 45, 'LanguageOfWorkOrName': 46, 'PrimeFactor': 47, 'ContainsTheAdministrativeTerritorialEntity': 48, 'ParentOrganization': 49, 'NativeLanguage': 50, 'PartyChiefRepresentative': 51, 'Capital': 52, 'TwinnedAdministrativeBody': 53, 'OriginalLanguageOfFilmOrTvShow': 54, 'Director': 55, 'PositionHeld': 56, 'PlaceOfBirth': 57, 'OperatingSystem': 58, 'IssuedBy': 59, 'CitesWork': 60, 'PublishedIn': 61, 'Employer': 62, 'Developer': 63, 'AdjacentStation': 64, 'ContributedToCreativeWork': 65, 'FieldOfWork': 66, 'ApprovedBy': 67, 'Causes': 68, 'HasCause': 69, 'NamedBy': 70, 'FoundedBy': 71, 'AwardReceived': 72}

# %%
import torch
import torch.nn as nn
from torch_geometric.nn import GCNConv
from collections import defaultdict

# GNN Model
class GNN_RE_NER(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_ner_classes, num_re_classes):
        super().__init__()
        self.gcn1 = GCNConv(input_dim, hidden_dim)
        self.gcn2 = GCNConv(hidden_dim, hidden_dim)

        self.ner_classifier = nn.Linear(hidden_dim, num_ner_classes)
        self.re_classifier = nn.Sequential(
            nn.Linear(hidden_dim * 2, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, num_re_classes)
        )

    def forward(self, x, edge_index, entity_pairs):
        x = self.gcn1(x, edge_index).relu()
        x = self.gcn2(x, edge_index).relu()

        # NER: predict tag for each token
        ner_logits = self.ner_classifier(x)

        # RE: predict relation between each candidate pair
        pair_reprs = []
        for head_idx, tail_idx in entity_pairs:
            h = x[head_idx]
            t = x[tail_idx]
            pair_reprs.append(torch.cat([h, t], dim=0))

        if pair_reprs:
            re_input = torch.stack(pair_reprs)
            re_logits = self.re_classifier(re_input)
        else:
            re_logits = torch.empty(0, self.re_classifier[-1].out_features).to(x.device)

        return ner_logits, re_logits


# Training Loop
def train_gnn_re_ner(graphs, ner_label_map, re_label_map, output_path,
                     entity_embed_dim=16, hidden_dim=128, 
                     max_epochs=100, patience=5, min_delta=1e-3):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    model = GNN_RE_NER(
        input_dim=768 + entity_embed_dim,
        hidden_dim=hidden_dim,
        num_ner_classes=len(ner_label_map),
        num_re_classes=len(re_label_map)
    ).to(device)

    entity_embedder = nn.Embedding(len(ner_label_map), entity_embed_dim).to(device)

    ner_criterion = nn.CrossEntropyLoss()
    re_criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

    best_loss = float('inf')
    epochs_no_improve = 0

    for epoch in range(1, max_epochs + 1):
        model.train()
        total_loss = 0.0
        total_re_pairs = 0

        for graph in graphs:
            node_feats = torch.tensor(graph["node_features"], dtype=torch.float).to(device)
            edge_index = torch.tensor(graph["edges"], dtype=torch.long).t().contiguous().to(device)

            # Create NER input tensor
            node_ner_tags = ["O"] * len(graph["nodes"])
            for ent in graph.get("entities", []):
                for i in range(ent["start"], ent["end"]):
                    if i < len(node_ner_tags):
                        node_ner_tags[i] = ent["label"]

            ner_ids = [ner_label_map.get(tag, 0) for tag in node_ner_tags]
            ner_tensor = torch.tensor(ner_ids, dtype=torch.long).to(device)
            ner_embeds = entity_embedder(ner_tensor)

            # Final GCN input
            x = torch.cat([node_feats, ner_embeds], dim=1)

            # Relation extraction setup
            entity_pairs = [(rel["head"], rel["tail"]) for rel in graph["relation_labels"]]
            re_labels = [re_label_map.get(rel["label"], 0) for rel in graph["relation_labels"]]
            re_labels_tensor = torch.tensor(re_labels, dtype=torch.long).to(device)

            # Forward pass
            ner_logits, re_logits = model(x, edge_index, entity_pairs)

            loss_ner = ner_criterion(ner_logits, ner_tensor)
            loss_re = re_criterion(re_logits, re_labels_tensor) if re_logits.size(0) > 0 else torch.tensor(0., device=device)

            loss = loss_ner + loss_re
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            total_re_pairs += re_logits.size(0)

        avg_loss = total_loss / len(graphs)
        print(f"Epoch {epoch} | Avg Loss: {avg_loss:.4f}")

        # Early stopping
        if best_loss - avg_loss > min_delta:
            best_loss = avg_loss
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                print(f"No improvement in {patience} epochs. Stopping at epoch {epoch}.")
                break

    # Convert label maps
    if isinstance(ner_label_map, defaultdict):
        ner_label_map = dict(ner_label_map)
    if isinstance(re_label_map, defaultdict):
        re_label_map = dict(re_label_map)

    # Save model
    torch.save({
        "model_state_dict": model.state_dict(),
        "entity_embedder_state_dict": entity_embedder.state_dict(),
        "ner_label_map": ner_label_map,
        "relation_label_map": re_label_map
    }, output_path)

    print(f"\nModel saved to: {output_path}")
    return model, entity_embedder


# === Train and Save ===
model, entity_embedder = train_gnn_re_ner(
    graphs=all_graphs,
    ner_label_map=ENTITY_LABELS,
    re_label_map=relation_label_map,
    output_path="Your_Model_Path_Here.pth",  # Change this to your model save path
    max_epochs=100
)
# Out:
# Epoch 1 | Avg Loss: 4.7544
# Epoch 2 | Avg Loss: 3.6105
# Epoch 3 | Avg Loss: 3.2641
# Epoch 4 | Avg Loss: 2.8901
# Epoch 5 | Avg Loss: 2.5316
# Epoch 6 | Avg Loss: 2.2491
# Epoch 7 | Avg Loss: 1.9981
# Epoch 8 | Avg Loss: 1.7069
# Epoch 9 | Avg Loss: 1.4419
# Epoch 10 | Avg Loss: 1.2352
# Epoch 11 | Avg Loss: 1.0558
# Epoch 12 | Avg Loss: 0.9538
# Epoch 13 | Avg Loss: 0.8716
# Epoch 14 | Avg Loss: 0.7949
# Epoch 15 | Avg Loss: 0.7516
# Epoch 16 | Avg Loss: 0.7381
# Epoch 17 | Avg Loss: 0.6700
# Epoch 18 | Avg Loss: 0.5707
# Epoch 19 | Avg Loss: 0.5383
# Epoch 20 | Avg Loss: 0.4928
# Epoch 21 | Avg Loss: 0.5105
# Epoch 22 | Avg Loss: 0.4860
# Epoch 23 | Avg Loss: 0.4635
# Epoch 24 | Avg Loss: 0.4350
# Epoch 25 | Avg Loss: 0.3836
# Epoch 26 | Avg Loss: 0.3862
# Epoch 27 | Avg Loss: 0.3415
# Epoch 28 | Avg Loss: 0.3249
# Epoch 29 | Avg Loss: 0.3121
# Epoch 30 | Avg Loss: 0.3001
# Epoch 31 | Avg Loss: 0.3110
# Epoch 32 | Avg Loss: 0.3058
# Epoch 33 | Avg Loss: 0.2838
# Epoch 34 | Avg Loss: 0.3180
# Epoch 35 | Avg Loss: 0.3267
# Epoch 36 | Avg Loss: 0.4057
# Epoch 37 | Avg Loss: 0.4039
# Epoch 38 | Avg Loss: 0.5421
# No improvement in 5 epochs. Stopping at epoch 38.
#
# Model saved to: /scratch/vsetpal/results/trained_gnn_checkpoint.pt

# %%
import os
import json
import torch
import spacy
import torch.nn.functional as F
from transformers import AutoTokenizer, AutoModel
from torch_geometric.nn import GCNConv
import torch.nn as nn

# Load base models
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

nlp = spacy.load("en_core_web_sm")
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
bert_model = AutoModel.from_pretrained("bert-base-uncased").to(device)
bert_model.eval()

# Define model architecture
class GNN_RE_NER(nn.Module):
    def __init__(self, input_dim, hidden_dim, num_ner_classes, num_re_classes):
        super().__init__()
        self.gcn1 = GCNConv(input_dim, hidden_dim)
        self.gcn2 = GCNConv(hidden_dim, hidden_dim)
        self.ner_classifier = nn.Linear(hidden_dim, num_ner_classes)
        self.re_classifier = nn.Sequential(
            nn.Linear(hidden_dim * 2, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, num_re_classes)
        )

    def forward(self, x, edge_index, entity_pairs):
        x = self.gcn1(x, edge_index).relu()
        x = self.gcn2(x, edge_index).relu()
        ner_logits = self.ner_classifier(x)
        pair_reprs = [torch.cat([x[head], x[tail]], dim=0) for head, tail in entity_pairs]
        if pair_reprs:
            re_input = torch.stack(pair_reprs)
            re_logits = self.re_classifier(re_input)
        else:
            re_logits = torch.empty(0, self.re_classifier[-1].out_features).to(x.device)
        return ner_logits, re_logits

# Load trained model and mappings
checkpoint_path = "Your_Model_Path_Here.pth"  # Change this to your model load path
checkpoint = torch.load(checkpoint_path, map_location=device)

ner_label_map = checkpoint["ner_label_map"]
relation_label_map = checkpoint["relation_label_map"]
id_to_ner_label = {v: k for k, v in ner_label_map.items()}
relation_id_to_label = {v: k for k, v in relation_label_map.items()}

model = GNN_RE_NER(
    input_dim=768 + 16,
    hidden_dim=128,
    num_ner_classes=len(ner_label_map),
    num_re_classes=len(relation_label_map)
).to(device)

entity_embedder = nn.Embedding(len(ner_label_map), 16).to(device)
model.load_state_dict(checkpoint["model_state_dict"])
entity_embedder.load_state_dict(checkpoint["entity_embedder_state_dict"])
model.eval()

# Utilities
def get_bert_embeddings(text):
    encoded = tokenizer(text, return_tensors="pt", return_offsets_mapping=True, truncation=True).to(device)
    offsets = encoded.pop("offset_mapping")[0].tolist()
    output = bert_model(**encoded)
    embeddings = output.last_hidden_state.squeeze(0)
    tokens = tokenizer.convert_ids_to_tokens(encoded["input_ids"][0])
    return tokens, embeddings, offsets

def align_tokens_to_bert(doc, tokens, embeddings, offsets):
    token_embeddings = []
    for token in doc:
        token_start = token.idx
        token_end = token.idx + len(token.text)
        matched = [embeddings[i] for i, (start, end) in enumerate(offsets)
                   if start >= token_start and end <= token_end]
        if matched:
            token_embeddings.append(torch.mean(torch.stack(matched), dim=0).tolist())
        else:
            token_embeddings.append(torch.zeros(embeddings.size(-1)).tolist())
    return token_embeddings

def group_tokens_into_entities(token_texts, token_labels, id_to_ner_label):
    entities = []
    i = 0
    while i < len(token_texts):
        label = id_to_ner_label.get(token_labels[i], "O")
        if label != "O":
            start = i
            entity_tokens = [token_texts[i]]
            while i + 1 < len(token_texts) and id_to_ner_label.get(token_labels[i+1], "O") == label:
                i += 1
                entity_tokens.append(token_texts[i])
            end = i + 1
            entity_text = " ".join(entity_tokens)
            entities.append({
                "text": entity_text,
                "label": label,
                "start": start,
                "end": end
            })
        i += 1
    return entities

# Annotate a single file
def annotate_file(file_path, output_path, confidence_threshold=0.6):
    with open(file_path, "r") as f:
        doc_entry = json.load(f)

    text = doc_entry.get("document", doc_entry.get("doc", ""))
    doc = nlp(text)
    token_texts = [token.text for token in doc]

    tokens, embeddings, offsets = get_bert_embeddings(text)
    features = align_tokens_to_bert(doc, tokens, embeddings, offsets)
    edges = [(token.head.i, token.i) for token in doc if token.head.i != token.i]

    node_feats_tensor = torch.tensor(features, dtype=torch.float).to(device)
    ner_ids = [ner_label_map.get("O", 0)] * len(token_texts)
    ner_tensor = torch.tensor(ner_ids, dtype=torch.long).to(device)
    ner_embeds = entity_embedder(ner_tensor)

    x = torch.cat([node_feats_tensor, ner_embeds], dim=1)
    edge_index = torch.tensor(edges, dtype=torch.long).t().contiguous().to(device) if edges else torch.empty((2, 0), dtype=torch.long).to(device)

    with torch.no_grad():
        x_reps = model.gcn1(x, edge_index).relu()
        x_reps = model.gcn2(x_reps, edge_index).relu()
        ner_logits = model.ner_classifier(x_reps)
        predicted_ner_ids = ner_logits.argmax(dim=1).cpu().tolist()

    predicted_entities = group_tokens_into_entities(token_texts, predicted_ner_ids, id_to_ner_label)

    candidate_pairs = [(e1["start"], e2["start"]) for i, e1 in enumerate(predicted_entities)
                       for j, e2 in enumerate(predicted_entities) if i != j]

    predicted_triples = []
    if candidate_pairs:
        pair_reprs = [torch.cat([x_reps[h], x_reps[t]], dim=0) for h, t in candidate_pairs]
        re_input = torch.stack(pair_reprs)
        with torch.no_grad():
            re_logits = model.re_classifier(re_input)
            probs = F.softmax(re_logits, dim=1)
            confidences, re_pred_ids = probs.max(dim=1)

        for idx, (head_idx, tail_idx) in enumerate(candidate_pairs):
            rel_id = re_pred_ids[idx].item()
            conf = confidences[idx].item()
            rel_label = relation_id_to_label.get(rel_id, "Unknown")
            h_ent = next((e for e in predicted_entities if e["start"] == head_idx), None)
            t_ent = next((e for e in predicted_entities if e["start"] == tail_idx), None)

            if h_ent and t_ent:
                if rel_label != "NoRelation" and conf >= confidence_threshold:
                    predicted_triples.append({
                        "head_text": h_ent["text"],
                        "tail_text": t_ent["text"],
                        "label": rel_label
                    })

    annotated_output = {
        "document": text,
        "predicted_entities": predicted_entities,
        "predicted_triples": predicted_triples,
        "NER-label_set": doc_entry.get("NER-label_set", []),
        "RE_label_set": doc_entry.get("RE_label_set", []),
        "id": doc_entry.get("id", "")
    }

    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    with open(output_path, "w") as f_out:
        json.dump(annotated_output, f_out, indent=4)

    print(f"Saved: {output_path}")
    return annotated_output

# Loop over all subfolders
root_input = "Your_folder_Path_Here"  # Change this to your input folder path
root_output = "Your_folder_Path_Here"  # Change this to your input folder path

for subdir in os.listdir(root_input):
    input_folder = os.path.join(root_input, subdir)
    output_folder = os.path.join(root_output, subdir)

    if not os.path.isdir(input_folder):
        continue

    for file_name in os.listdir(input_folder):
        if file_name.endswith(".json"):
            input_path = os.path.join(input_folder, file_name)
            output_path = os.path.join(output_folder, file_name)
            annotate_file(input_path, output_path)
# Out:
# Using device: cuda
# Saved: /scratch/vsetpal/results/test/Academic_disciplines/Anthropocene_Working_Group.json
# Saved: /scratch/vsetpal/results/test/Academic_disciplines/Applied_history.json
# Saved: /scratch/vsetpal/results/test/Academic_disciplines/Bolognese_bell_ringing.json
# Saved: /scratch/vsetpal/results/test/Academic_disciplines/Cylinder_Audio_Archive.json
# Saved: /scratch/vsetpal/results/test/Academic_disciplines/Drug_education.json
# Saved: /scratch/vsetpal/results/test/Academic_disciplines/Environmental_studies.json
# Saved: /scratch/vsetpal/results/test/Academic_disciplines/Essay_on_a_Course_of_Liberal_Education_for_Civil_and_Active_Life.json
# Saved: /scratch/vsetpal/results/test/Academic_disciplines/Legal_archaeology.json
# Saved: /scratch/vsetpal/results/test/Academic_disciplines/Literary_nonsense.json
# Saved: /scratch/vsetpal/results/test/Academic_disciplines/Master_of_Environmental_Management.json
# Saved: /scratch/vsetpal/results/test/Academic_disciplines/Philosophy_of_design.json
# Saved: /scratch/vsetpal/results/test/Academic_disciplines/The_Art_Assignment.json
# Saved: /scratch/vsetpal/results/test/Academic_disciplines/The_Problems_of_Genocide.json
# Saved: /scratch/vsetpal/results/test/Academic_disciplines/The_Sexual_Contract.json
# Saved: /scratch/vsetpal/results/test/Academic_disciplines/Xanadu_Houses.json
# Saved: /scratch/vsetpal/results/test/Academic_disciplines/Yessiey_Award.json
# Saved: /scratch/vsetpal/results/test/Business/Application_for_employment.json
# Saved: /scratch/vsetpal/results/test/Business/Blame_in_organizations.json
# Saved: /scratch/vsetpal/results/test/Business/Business_architecture.json
# Saved: /scratch/vsetpal/results/test/Business/Communities_of_innovation.json
# Saved: /scratch/vsetpal/results/test/Business/Company.json
# Saved: /scratch/vsetpal/results/test/Business/Desktop_outsourcing.json
# Saved: /scratch/vsetpal/results/test/Business/Global_Entrepreneurship_Week.json
# Saved: /scratch/vsetpal/results/test/Business/News_values.json
# Saved: /scratch/vsetpal/results/test/Business/Road_warrior_(computing).json
# Saved: /scratch/vsetpal/results/test/Business/Vanpool.json
# Saved: /scratch/vsetpal/results/test/Communication/Automatic_curb_sender.json
# Saved: /scratch/vsetpal/results/test/Communication/Biocommunication_(science).json
# Saved: /scratch/vsetpal/results/test/Communication/China_Internet_Network_Information_Center.json
# Saved: /scratch/vsetpal/results/test/Communication/Environmental_communication.json
# Saved: /scratch/vsetpal/results/test/Communication/Facial_Action_Coding_System.json
# Saved: /scratch/vsetpal/results/test/Communication/Global_information_system.json
# Saved: /scratch/vsetpal/results/test/Communication/History_of_the_concept_of_creativity.json
# Saved: /scratch/vsetpal/results/test/Communication/Regulatory_focus_theory.json
# Saved: /scratch/vsetpal/results/test/Communication/Safety_sign.json
# Saved: /scratch/vsetpal/results/test/Communication/Video_feedback.json
# Saved: /scratch/vsetpal/results/test/Culture/Artificial_plants.json
# Saved: /scratch/vsetpal/results/test/Culture/Born_Sexy_Yesterday.json
# Saved: /scratch/vsetpal/results/test/Culture/Civilization_state.json
# Saved: /scratch/vsetpal/results/test/Culture/Clothing_physiology.json
# Saved: /scratch/vsetpal/results/test/Culture/Consensus_reality.json
# Saved: /scratch/vsetpal/results/test/Culture/John_Hopkins_(political_activist).json
# Saved: /scratch/vsetpal/results/test/Culture/Pet_culture.json
# Saved: /scratch/vsetpal/results/test/Culture/Repurposing.json
# Saved: /scratch/vsetpal/results/test/Culture/The_Triple_Package.json
# Saved: /scratch/vsetpal/results/test/Culture/Xeer.json
# Saved: /scratch/vsetpal/results/test/Economy/Bare_minimum_Monday.json
# Saved: /scratch/vsetpal/results/test/Economy/Central_bank_independence.json
# Saved: /scratch/vsetpal/results/test/Economy/Consumer_economy.json
# Saved: /scratch/vsetpal/results/test/Economy/Consumer_education.json
# Saved: /scratch/vsetpal/results/test/Economy/Data_culture.json
# Saved: /scratch/vsetpal/results/test/Economy/Economic_consulting.json
# Saved: /scratch/vsetpal/results/test/Economy/Economy.json
# Saved: /scratch/vsetpal/results/test/Economy/Law_of_supply.json
# Saved: /scratch/vsetpal/results/test/Economy/Necrocapitalism.json
# Saved: /scratch/vsetpal/results/test/Economy/New_economy.json
# Saved: /scratch/vsetpal/results/test/Economy/Primary_sector_of_the_economy.json
# Saved: /scratch/vsetpal/results/test/Economy/Registered_office.json
# Saved: /scratch/vsetpal/results/test/Economy/Sabbath_economics.json
# Saved: /scratch/vsetpal/results/test/Economy/Silent_trade.json
# Saved: /scratch/vsetpal/results/test/Education/Beehive_Design_Collective.json
# Saved: /scratch/vsetpal/results/test/Education/Campus_climate.json
# Saved: /scratch/vsetpal/results/test/Education/Classification_of_Instructional_Programs.json
# Saved: /scratch/vsetpal/results/test/Education/Content_similarity_detection.json
# Saved: /scratch/vsetpal/results/test/Education/Field_trip.json
# Saved: /scratch/vsetpal/results/test/Education/Further_and_Higher_Education_Act_1992.json
# Saved: /scratch/vsetpal/results/test/Education/Hospitality_management_studies.json
# Saved: /scratch/vsetpal/results/test/Education/SESI_Mathematics.json
# Saved: /scratch/vsetpal/results/test/Education/Sophomore.json
# Saved: /scratch/vsetpal/results/test/Education/Validation_of_foreign_studies_and_degrees.json
# Saved: /scratch/vsetpal/results/test/Energy/Advanced_thermal_recycling_system.json
# Saved: /scratch/vsetpal/results/test/Energy/Anne_Korin.json
# Saved: /scratch/vsetpal/results/test/Energy/Association_for_Decentralised_Energy.json
# Saved: /scratch/vsetpal/results/test/Energy/Electric_power_industry.json
# Saved: /scratch/vsetpal/results/test/Energy/Energy_management_software.json
# Saved: /scratch/vsetpal/results/test/Energy/ExxonMobil_Beaumont_Refinery.json
# Saved: /scratch/vsetpal/results/test/Energy/Maksim_Sonin.json
# Saved: /scratch/vsetpal/results/test/Energy/Planetary_civilization.json
# Saved: /scratch/vsetpal/results/test/Energy/Thomas_W._Walde.json
# Saved: /scratch/vsetpal/results/test/Energy/Uganda_Energy_Credit_Capitalisation_Company.json
# Saved: /scratch/vsetpal/results/test/Engineering/ARP4761.json
# Saved: /scratch/vsetpal/results/test/Engineering/Amasa_Stone_Bishop.json
# Saved: /scratch/vsetpal/results/test/Engineering/Bug_(engineering).json
# Saved: /scratch/vsetpal/results/test/Engineering/Engineering_technologist.json
# Saved: /scratch/vsetpal/results/test/Engineering/Gravimetric_blender.json
# Saved: /scratch/vsetpal/results/test/Engineering/History_of_engineering.json
# Saved: /scratch/vsetpal/results/test/Engineering/History_of_women_in_engineering_in_the_United_Kingdom.json
# Saved: /scratch/vsetpal/results/test/Engineering/Mineral_Products_Association.json
# Saved: /scratch/vsetpal/results/test/Engineering/Pressure_Equipment_Directive_(EU).json
# Saved: /scratch/vsetpal/results/test/Engineering/Resilience_week.json
# Saved: /scratch/vsetpal/results/test/Engineering/Social_construction_of_technology.json
# Saved: /scratch/vsetpal/results/test/Engineering/Tests_of_Engineering_Aptitude,_Mathematics,_and_Science.json
# Saved: /scratch/vsetpal/results/test/Engineering/Washington_Accord_(credentials).json
# Saved: /scratch/vsetpal/results/test/Entertainment/Anvil_firing.json
# Saved: /scratch/vsetpal/results/test/Entertainment/Aqua_drama.json
# Saved: /scratch/vsetpal/results/test/Entertainment/Delfines_Hotel_&_Convention_Center.json
# Saved: /scratch/vsetpal/results/test/Entertainment/Dumb_Ways_to_Die.json
# Saved: /scratch/vsetpal/results/test/Entertainment/Elegiac_comedy.json
# Saved: /scratch/vsetpal/results/test/Entertainment/Metagame.json
# Saved: /scratch/vsetpal/results/test/Entertainment/Musical_canine_freestyle.json
# Saved: /scratch/vsetpal/results/test/Entertainment/Nonchalance.json
# Saved: /scratch/vsetpal/results/test/Entertainment/Rene_van_Helsdingen.json
# Saved: /scratch/vsetpal/results/test/Entertainment/Rule_63.json
# Saved: /scratch/vsetpal/results/test/Entertainment/Varsity_Spirit.json
# Saved: /scratch/vsetpal/results/test/Entertainment/White_label.json
# Saved: /scratch/vsetpal/results/test/Food_and_drink/Custard.json
# Saved: /scratch/vsetpal/results/test/Food_and_drink/Dairy_in_the_New_Garden.json
# Saved: /scratch/vsetpal/results/test/Food_and_drink/Drinking.json
# Saved: /scratch/vsetpal/results/test/Food_and_drink/Energy_gel.json
# Saved: /scratch/vsetpal/results/test/Food_and_drink/Food_engineering.json
# Saved: /scratch/vsetpal/results/test/Food_and_drink/Irreechaa.json
# Saved: /scratch/vsetpal/results/test/Food_and_drink/Liquor.json
# Saved: /scratch/vsetpal/results/test/Food_and_drink/Night_of_the_Radishes.json
# Saved: /scratch/vsetpal/results/test/Food_and_drink/Pagophagia.json
# Saved: /scratch/vsetpal/results/test/Food_and_drink/Wilderness-acquired_diarrhea.json
# Saved: /scratch/vsetpal/results/test/Geography/Age_of_Sail.json
# Saved: /scratch/vsetpal/results/test/Geography/Churbaierische_Atlas.json
# Saved: /scratch/vsetpal/results/test/Geography/Five_themes_of_geography.json
# Saved: /scratch/vsetpal/results/test/Geography/Four_traditions_of_geography.json
# Saved: /scratch/vsetpal/results/test/Geography/Geography_Cup.json
# Saved: /scratch/vsetpal/results/test/Geography/Jebel_Akhdar_(Libya).json
# Saved: /scratch/vsetpal/results/test/Geography/Land_systems.json
# Saved: /scratch/vsetpal/results/test/Geography/Rosgen_Stream_Classification.json
# Saved: /scratch/vsetpal/results/test/Government/Continuity_of_government.json
# Saved: /scratch/vsetpal/results/test/Government/Fall_of_the_Derg_regime.json
# Saved: /scratch/vsetpal/results/test/Government/Fullmetal_Alchemist_(film).json
# Saved: /scratch/vsetpal/results/test/Government/Gemma_Ubasart.json
# Saved: /scratch/vsetpal/results/test/Government/Government_agency.json
# Saved: /scratch/vsetpal/results/test/Government/Official_communications_in_imperial_China.json
# Saved: /scratch/vsetpal/results/test/Government/Quality_of_Nationality_Index.json
# Saved: /scratch/vsetpal/results/test/Government/Substitute_(elections).json
# Saved: /scratch/vsetpal/results/test/Government/Treaty_of_Verdun.json
# Saved: /scratch/vsetpal/results/test/Health/Anxiety_buffer_disruption_theory.json
# Saved: /scratch/vsetpal/results/test/Health/Bioenvironmental_Engineering.json
# Saved: /scratch/vsetpal/results/test/Health/Homeschooling_during_the_COVID-19_pandemic.json
# Saved: /scratch/vsetpal/results/test/Health/Kate_Rew.json
# Saved: /scratch/vsetpal/results/test/Health/Open-air_treatment.json
# Saved: /scratch/vsetpal/results/test/Health/Patient_management_software.json
# Saved: /scratch/vsetpal/results/test/Health/Smell_as_evidence_of_disease.json
# Saved: /scratch/vsetpal/results/test/Health/Value-based_health_care.json
# Saved: /scratch/vsetpal/results/test/History/Archival_research.json
# Saved: /scratch/vsetpal/results/test/History/Cosmogony.json
# Saved: /scratch/vsetpal/results/test/History/Cultural_history.json
# Saved: /scratch/vsetpal/results/test/History/Dawid_Moryc_Apfelbaum.json
# Saved: /scratch/vsetpal/results/test/History/History_of_Tat_people.json
# Saved: /scratch/vsetpal/results/test/History/Hugh_Llewellyn_Keenleyside.json
# Saved: /scratch/vsetpal/results/test/History/International_Students_of_History_Association.json
# Saved: /scratch/vsetpal/results/test/History/List_of_preserved_historic_blast_furnaces.json
# Saved: /scratch/vsetpal/results/test/History/National_History_Day.json
# Saved: /scratch/vsetpal/results/test/History/North_American_Society_for_Oceanic_History.json
# Saved: /scratch/vsetpal/results/test/Human_behavior/Affect_infusion_model.json
# Saved: /scratch/vsetpal/results/test/Human_behavior/Behavioral_change_support_system.json
# Saved: /scratch/vsetpal/results/test/Human_behavior/Binge_eating.json
# Saved: /scratch/vsetpal/results/test/Human_behavior/Creative_consumer.json
# Saved: /scratch/vsetpal/results/test/Human_behavior/Crowd_collapses_and_crushes.json
# Saved: /scratch/vsetpal/results/test/Human_behavior/Deviance_regulation_theory.json
# Saved: /scratch/vsetpal/results/test/Human_behavior/Discrete_trial_training.json
# Saved: /scratch/vsetpal/results/test/Human_behavior/Fight-or-flight_response.json
# Saved: /scratch/vsetpal/results/test/Human_behavior/Oblique_Strategies.json
# Saved: /scratch/vsetpal/results/test/Human_behavior/Regifting.json
# Saved: /scratch/vsetpal/results/test/Human_behavior/Stockholm_syndrome.json
# Saved: /scratch/vsetpal/results/test/Human_behavior/Tears.json
# Saved: /scratch/vsetpal/results/test/Human_behavior/Work–family_conflict.json
# Saved: /scratch/vsetpal/results/test/Humanities/Bells_on_Sunday.json
# Saved: /scratch/vsetpal/results/test/Humanities/Book_desert.json
# Saved: /scratch/vsetpal/results/test/Humanities/Cretan_Lie.json
# Saved: /scratch/vsetpal/results/test/Humanities/Development_anthropology.json
# Saved: /scratch/vsetpal/results/test/Humanities/Digital_Humanities_conference.json
# Saved: /scratch/vsetpal/results/test/Humanities/Eskimology.json
# Saved: /scratch/vsetpal/results/test/Humanities/GLAM_(cultural_heritage).json
# Saved: /scratch/vsetpal/results/test/Humanities/Gender_and_politics.json
# Saved: /scratch/vsetpal/results/test/Humanities/Nature_writing.json
# Saved: /scratch/vsetpal/results/test/Humanities/Social_practice.json
# Saved: /scratch/vsetpal/results/test/Humanities/Uncertainty_management_theory.json
# Saved: /scratch/vsetpal/results/test/Information/Adversarial_stylometry.json
# Saved: /scratch/vsetpal/results/test/Information/Animal_rights_by_country_or_territory.json
# Saved: /scratch/vsetpal/results/test/Information/Belgrade_IT_sector.json
# Saved: /scratch/vsetpal/results/test/Information/Coinmarketcap.json
# Saved: /scratch/vsetpal/results/test/Information/E-GMS.json
# Saved: /scratch/vsetpal/results/test/Information/Fact_sheet.json
# Saved: /scratch/vsetpal/results/test/Information/Geospatial_topology.json
# Saved: /scratch/vsetpal/results/test/Information/Ghost_shoes.json
# Saved: /scratch/vsetpal/results/test/Information/Information_Centre_on_NATO_in_Armenia.json
# Saved: /scratch/vsetpal/results/test/Information/Othernet.json
# Saved: /scratch/vsetpal/results/test/Information/Tip_sheet.json
# Saved: /scratch/vsetpal/results/test/Information/Virtual_data_room.json
# Saved: /scratch/vsetpal/results/test/Information/White_House_visitor_logs.json
# Saved: /scratch/vsetpal/results/test/Internet/Anti-social_Media_Bill_(Nigeria).json
# Saved: /scratch/vsetpal/results/test/Internet/Cem_Korkmaz.json
# Saved: /scratch/vsetpal/results/test/Internet/Hyperdata.json
# Saved: /scratch/vsetpal/results/test/Internet/Internet_GIS.json
# Saved: /scratch/vsetpal/results/test/Internet/Internet_in_Laos.json
# Saved: /scratch/vsetpal/results/test/Internet/Online_encyclopedia.json
# Saved: /scratch/vsetpal/results/test/Internet/Online_optimization.json
# Saved: /scratch/vsetpal/results/test/Internet/OrionVM.json
# Saved: /scratch/vsetpal/results/test/Internet/Route_panorama.json
# Saved: /scratch/vsetpal/results/test/Internet/ZA_Central_Registry.json
# Saved: /scratch/vsetpal/results/test/Knowledge/Cognitive_closure_(philosophy).json
# Saved: /scratch/vsetpal/results/test/Knowledge/Community_of_inquiry.json
# Saved: /scratch/vsetpal/results/test/Knowledge/Consumerization_of_information_technology.json
# Saved: /scratch/vsetpal/results/test/Knowledge/Ed_Goodgold.json
# Saved: /scratch/vsetpal/results/test/Knowledge/Electronic_lab_notebook.json
# Saved: /scratch/vsetpal/results/test/Knowledge/Episteme.json
# Saved: /scratch/vsetpal/results/test/Knowledge/Free-floating_intellectuals.json
# Saved: /scratch/vsetpal/results/test/Knowledge/Hermathena_(composite_of_Hermes_and_Athena).json
# Saved: /scratch/vsetpal/results/test/Knowledge/Hikmah.json
# Saved: /scratch/vsetpal/results/test/Knowledge/Intellectual_capital_management.json
# Saved: /scratch/vsetpal/results/test/Knowledge/Knowledge_Economic_Index.json
# Saved: /scratch/vsetpal/results/test/Knowledge/Knowledge_broker.json
# Saved: /scratch/vsetpal/results/test/Knowledge/Leisure_studies.json
# Saved: /scratch/vsetpal/results/test/Knowledge/Relative_age_effect.json
# Saved: /scratch/vsetpal/results/test/Knowledge/Social_work_management.json
# Saved: /scratch/vsetpal/results/test/Knowledge/Social–emotional_learning.json
# Saved: /scratch/vsetpal/results/test/Language/Agbirigba.json
# Saved: /scratch/vsetpal/results/test/Language/Balaibalan.json
# Saved: /scratch/vsetpal/results/test/Language/Bot_Colony.json
# Saved: /scratch/vsetpal/results/test/Language/Chinese_Poetry_Congress.json
# Saved: /scratch/vsetpal/results/test/Language/Comparative_Semitics.json
# Saved: /scratch/vsetpal/results/test/Language/Directorate_of_Language_Planning_and_Implementation.json
# Saved: /scratch/vsetpal/results/test/Language/Linguistic_distance.json
# Saved: /scratch/vsetpal/results/test/Language/Patter.json
# Saved: /scratch/vsetpal/results/test/Language/Radical_interpretation.json
# Saved: /scratch/vsetpal/results/test/Language/Unicode_font.json
# Saved: /scratch/vsetpal/results/test/Law/Carceral_feminism.json
# Saved: /scratch/vsetpal/results/test/Law/Continuing_legal_education.json
# Saved: /scratch/vsetpal/results/test/Law/European_Judicial_Network.json
# Saved: /scratch/vsetpal/results/test/Law/Judicial_populism.json
# Saved: /scratch/vsetpal/results/test/Law/Law_French.json
# Saved: /scratch/vsetpal/results/test/Law/Legal_risk.json
# Saved: /scratch/vsetpal/results/test/Law/Legal_status_of_psilocybin_mushrooms.json
# Saved: /scratch/vsetpal/results/test/Law/New_York_Anti-Secession_Ordinance.json
# Saved: /scratch/vsetpal/results/test/Law/The_Justice_of_Trajan_and_Herkinbald.json
# Saved: /scratch/vsetpal/results/test/Law/Trigger_law.json
# Saved: /scratch/vsetpal/results/test/Life/Anthropopithecus.json
# Saved: /scratch/vsetpal/results/test/Life/Formose_reaction.json
# Saved: /scratch/vsetpal/results/test/Life/Incorruptibility.json
# Saved: /scratch/vsetpal/results/test/Life/Infections_associated_with_diseases.json
# Saved: /scratch/vsetpal/results/test/Life/Nanobe.json
# Saved: /scratch/vsetpal/results/test/Life/Non-cellular_life.json
# Saved: /scratch/vsetpal/results/test/Life/Organism.json
# Saved: /scratch/vsetpal/results/test/Life/Oxygen_evolution.json
# Saved: /scratch/vsetpal/results/test/Life/Pioneer_plaque.json
# Saved: /scratch/vsetpal/results/test/Life/Survivorship_bias.json
# Saved: /scratch/vsetpal/results/test/Life/Tree_of_life_(biology).json
# Saved: /scratch/vsetpal/results/test/Mathematics/Akira_Yoshizawa.json
# Saved: /scratch/vsetpal/results/test/Mathematics/Ethics_in_mathematics.json
# Saved: /scratch/vsetpal/results/test/Mathematics/George_Gheverghese_Joseph.json
# Saved: /scratch/vsetpal/results/test/Mathematics/Mathematical_diagram.json
# Saved: /scratch/vsetpal/results/test/Mathematics/Mathematician.json
# Saved: /scratch/vsetpal/results/test/Military/Army.json
# Saved: /scratch/vsetpal/results/test/Military/Conduct_prejudicial_to_good_order_and_discipline.json
# Saved: /scratch/vsetpal/results/test/Military/Disarmament.json
# Saved: /scratch/vsetpal/results/test/Military/History_Channel.json
# Saved: /scratch/vsetpal/results/test/Military/Impact_of_the_COVID-19_pandemic_on_the_military.json
# Saved: /scratch/vsetpal/results/test/Military/Justus_Lipsius.json
# Saved: /scratch/vsetpal/results/test/Military/Military–entertainment_complex.json
# Saved: /scratch/vsetpal/results/test/Military/Railway_troops.json
# Saved: /scratch/vsetpal/results/test/Military/Training_Within_Industry.json
# Saved: /scratch/vsetpal/results/test/Nature/Bast_fibre.json
# Saved: /scratch/vsetpal/results/test/Nature/Dicerandrol_C.json
# Saved: /scratch/vsetpal/results/test/Nature/Green_flash.json
# Saved: /scratch/vsetpal/results/test/Nature/Homeosis.json
# Saved: /scratch/vsetpal/results/test/Nature/Jaramillo_reversal.json
# Saved: /scratch/vsetpal/results/test/Nature/Lofoten_Vortex.json
# Saved: /scratch/vsetpal/results/test/Nature/Mfinda.json
# Saved: /scratch/vsetpal/results/test/Nature/Rangeland_management.json
# Saved: /scratch/vsetpal/results/test/Nature/Swamp_Legend.json
# Saved: /scratch/vsetpal/results/test/People/Bibliography_of_Abul_Hasan_Ali_Hasani_Nadwi.json
# Saved: /scratch/vsetpal/results/test/People/Coat_of_arms_of_the_Prince_of_Wales.json
# Saved: /scratch/vsetpal/results/test/People/Dilorom_Yuldosheva.json
# Saved: /scratch/vsetpal/results/test/People/Favorite_son.json
# Saved: /scratch/vsetpal/results/test/People/Grammar_Nazi.json
# Saved: /scratch/vsetpal/results/test/People/Jesús_García.json
# Saved: /scratch/vsetpal/results/test/People/Master–slave_(technology).json
# Saved: /scratch/vsetpal/results/test/People/People.json
# Saved: /scratch/vsetpal/results/test/People/Person.json
# Saved: /scratch/vsetpal/results/test/People/Section_Eleven_of_the_Constitution_of_South_Africa.json
# Saved: /scratch/vsetpal/results/test/Philosophy/Cryptoterrestrial_hypothesis.json
# Saved: /scratch/vsetpal/results/test/Philosophy/Harald_Lesch.json
# Saved: /scratch/vsetpal/results/test/Philosophy/John_Locke_Lectures.json
# Saved: /scratch/vsetpal/results/test/Philosophy/Karen_Detlefsen.json
# Saved: /scratch/vsetpal/results/test/Philosophy/Naive_realism.json
# Saved: /scratch/vsetpal/results/test/Philosophy/Philosophy.json
# Saved: /scratch/vsetpal/results/test/Philosophy/Virtuality_(philosophy).json
# Saved: /scratch/vsetpal/results/test/Politics/Favorite_son.json
# Saved: /scratch/vsetpal/results/test/Politics/Golden_age_of_Jewish_culture_in_Spain.json
# Saved: /scratch/vsetpal/results/test/Politics/Grapus.json
# Saved: /scratch/vsetpal/results/test/Politics/Latino_vote.json
# Saved: /scratch/vsetpal/results/test/Politics/Peruvian_Public_Ministry_controversy.json
# Saved: /scratch/vsetpal/results/test/Politics/Policy_learning.json
# Saved: /scratch/vsetpal/results/test/Politics/Political_consulting.json
# Saved: /scratch/vsetpal/results/test/Politics/Politics_of_outer_space.json
# Saved: /scratch/vsetpal/results/test/Politics/Social_Credit_Party_of_Great_Britain_and_Northern_Ireland.json
# Saved: /scratch/vsetpal/results/test/Politics/Town_hall_meeting.json
# Saved: /scratch/vsetpal/results/test/Religion/Christianity_and_animal_rights.json
# Saved: /scratch/vsetpal/results/test/Religion/Counter-apologetics.json
# Saved: /scratch/vsetpal/results/test/Religion/El_Tío.json
# Saved: /scratch/vsetpal/results/test/Religion/Flushing_Remonstrance.json
# Saved: /scratch/vsetpal/results/test/Religion/Gaia_philosophy.json
# Saved: /scratch/vsetpal/results/test/Religion/Joshua_Project.json
# Saved: /scratch/vsetpal/results/test/Religion/Religion_in_space.json
# Saved: /scratch/vsetpal/results/test/Religion/Religious_identity.json
# Saved: /scratch/vsetpal/results/test/Religion/Ritual_behavior_in_animals.json
# Saved: /scratch/vsetpal/results/test/Religion/Siladhara_Order.json
# Saved: /scratch/vsetpal/results/test/Science/AllTrials.json
# Saved: /scratch/vsetpal/results/test/Science/Classification_of_the_sciences_(Peirce).json
# Saved: /scratch/vsetpal/results/test/Science/Geographic_information_science.json
# Saved: /scratch/vsetpal/results/test/Science/Life-cycle_greenhouse_gas_emissions_of_energy_sources.json
# Saved: /scratch/vsetpal/results/test/Science/Open-notebook_science.json
# Saved: /scratch/vsetpal/results/test/Science/Roatan_Institute_for_Marine_Sciences.json
# Saved: /scratch/vsetpal/results/test/Science/Science_in_Action_(book).json
# Saved: /scratch/vsetpal/results/test/Science/Scientist.json
# Saved: /scratch/vsetpal/results/test/Science/Sonnet_to_Science.json
# Saved: /scratch/vsetpal/results/test/Society/Aging_offender.json
# Saved: /scratch/vsetpal/results/test/Society/Confessional_society.json
# Saved: /scratch/vsetpal/results/test/Society/Conflict_theories.json
# Saved: /scratch/vsetpal/results/test/Society/Figure_and_ground_(media).json
# Saved: /scratch/vsetpal/results/test/Society/Harvest_Festival_(United_Kingdom).json
# Saved: /scratch/vsetpal/results/test/Society/Music_Declares_Emergency.json
# Saved: /scratch/vsetpal/results/test/Society/Public_humanities.json
# Saved: /scratch/vsetpal/results/test/Society/Social_conflict_theory.json
# Saved: /scratch/vsetpal/results/test/Society/Social_structure_of_Romania.json
# Saved: /scratch/vsetpal/results/test/Society/Superficiality.json
# Saved: /scratch/vsetpal/results/test/Society/Vienna_Institute_of_Demography.json
# Saved: /scratch/vsetpal/results/test/Sports/2024_Orienteering_World_Cup.json
# Saved: /scratch/vsetpal/results/test/Sports/Blood_rule.json
# Saved: /scratch/vsetpal/results/test/Sports/Combined_track_and_field_events.json
# Saved: /scratch/vsetpal/results/test/Sports/Ground_billiards.json
# Saved: /scratch/vsetpal/results/test/Sports/Lamex_Omara_Apitta.json
# Saved: /scratch/vsetpal/results/test/Sports/Revival_(sports_team).json
# Saved: /scratch/vsetpal/results/test/Sports/Sporting_colours.json
# Saved: /scratch/vsetpal/results/test/Sports/The_Foundation_for_Global_Sports_Development.json
# Saved: /scratch/vsetpal/results/test/Sports/The_Sporting_Spirit.json
# Saved: /scratch/vsetpal/results/test/Technology/Creative_technology.json
# Saved: /scratch/vsetpal/results/test/Technology/Developer_relations.json
# Saved: /scratch/vsetpal/results/test/Technology/Food_model.json
# Saved: /scratch/vsetpal/results/test/Technology/Geomatics.json
# Saved: /scratch/vsetpal/results/test/Technology/History_of_timekeeping_devices_in_Egypt.json
# Saved: /scratch/vsetpal/results/test/Technology/Wei-Ying_Ma.json
# Saved: /scratch/vsetpal/results/test/Universe/Cosmology.json
# Saved: /scratch/vsetpal/results/test/Universe/Global_brain.json
# Saved: /scratch/vsetpal/results/test/Universe/Hardness.json
# Saved: /scratch/vsetpal/results/test/Universe/International_communication.json
# Saved: /scratch/vsetpal/results/test/Universe/Negative_energy.json

# %%
import os
import json
from tabulate import tabulate

def evaluate_annotated_file(annotated_json_path):
    with open(annotated_json_path, "r") as f:
        data = json.load(f)

    gold_ner_labels = set(data.get("NER-label_set", []))
    predicted_ner_labels = {ent["label"] for ent in data.get("predicted_entities", [])}
    tp_ner = len(gold_ner_labels & predicted_ner_labels)
    fp_ner = len(predicted_ner_labels - gold_ner_labels)
    fn_ner = len(gold_ner_labels - predicted_ner_labels)
    precision_ner = tp_ner / (tp_ner + fp_ner + 1e-8)
    recall_ner = tp_ner / (tp_ner + fn_ner + 1e-8)
    f1_ner = 2 * precision_ner * recall_ner / (precision_ner + recall_ner + 1e-8)

    gold_re_labels = set(data.get("RE_label_set", []))
    predicted_re_labels = {trip["label"] for trip in data.get("predicted_triples", [])}
    tp_re = len(gold_re_labels & predicted_re_labels)
    fp_re = len(predicted_re_labels - gold_re_labels)
    fn_re = len(gold_re_labels - predicted_re_labels)
    precision_re = tp_re / (tp_re + fp_re + 1e-8)
    recall_re = tp_re / (tp_re + fn_re + 1e-8)
    f1_re = 2 * precision_re * recall_re / (precision_re + recall_re + 1e-8)

    precision_combined = (precision_ner + precision_re) / 2
    recall_combined = (recall_ner + recall_re) / 2
    f1_combined = (f1_ner + f1_re) / 2

    return precision_combined, recall_combined, f1_combined

def evaluate_all_domains(root_folder_path):
    domain_results = []

    for dirpath, dirnames, filenames in os.walk(root_folder_path):
        json_files = [f for f in filenames if f.endswith(".json")]
        if not json_files:
            continue

        total_precision = total_recall = total_f1 = 0
        count = 0

        for fname in json_files:
            fpath = os.path.join(dirpath, fname)
            try:
                p, r, f1 = evaluate_annotated_file(fpath)
                total_precision += p
                total_recall += r
                total_f1 += f1
                count += 1
            except Exception as e:
                print()

        if count > 0:
            avg_precision = total_precision / count
            avg_recall = total_recall / count
            avg_f1 = total_f1 / count

            # Extract domain name as last folder name
            domain_name = os.path.basename(dirpath)
            domain_results.append([domain_name, f"{avg_precision:.4f}", f"{avg_recall:.4f}", f"{avg_f1:.4f}"])

    # Print all as table
    if domain_results:
        print("Evaluation Summary Across Domains")
        print(tabulate(domain_results, headers=["Domain", "Precision", "Recall", "F1 Score"], tablefmt="pretty"))
    else:
        print("No annotated JSON files found.")

# Run across all folders inside /scratch/vsetpal/results
evaluate_all_domains("Your_folder_Path_Here")  # Change this to your folder path
# Out:
# Evaluation Summary Across Domains
# +----------------------+-----------+--------+----------+
# |        Domain        | Precision | Recall | F1 Score |
# +----------------------+-----------+--------+----------+
# | Academic_disciplines |  0.7522   | 0.0882 |  0.1530  |
# |       Business       |  0.6244   | 0.0899 |  0.1523  |
# |    Communication     |  0.7561   | 0.1692 |  0.2499  |
# |       Culture        |  0.8594   | 0.1013 |  0.1770  |
# |       Economy        |  0.7764   | 0.1076 |  0.1796  |
# |      Education       |  0.8071   | 0.1144 |  0.1896  |
# |        Energy        |  0.6812   | 0.0644 |  0.1137  |
# |     Engineering      |  0.7003   | 0.1070 |  0.1741  |
# |    Entertainment     |  0.8136   | 0.1449 |  0.2373  |
# |    Food_and_drink    |  0.7033   | 0.1113 |  0.1824  |
# |      Geography       |  0.7226   | 0.1093 |  0.1791  |
# |      Government      |  0.8080   | 0.1014 |  0.1760  |
# |        Health        |  0.7875   | 0.1182 |  0.1954  |
# |       History        |  0.8002   | 0.1555 |  0.2486  |
# |    Human_behavior    |  0.8396   | 0.2230 |  0.3263  |
# |      Humanities      |  0.7015   | 0.1155 |  0.1861  |
# |     Information      |  0.7147   | 0.0951 |  0.1635  |
# |       Internet       |  0.7267   | 0.0806 |  0.1418  |
# |      Knowledge       |  0.9013   | 0.0895 |  0.1594  |
# |       Language       |  0.8393   | 0.1137 |  0.1939  |
# |         Law          |  0.6632   | 0.1150 |  0.1905  |
# |         Life         |  0.8631   | 0.1127 |  0.1951  |
# |     Mathematics      |  0.5883   | 0.0868 |  0.1415  |
# |       Military       |  0.5886   | 0.1134 |  0.1769  |
# |        Nature        |  0.6898   | 0.0981 |  0.1649  |
# |        People        |  0.7148   | 0.1005 |  0.1684  |
# |      Philosophy      |  0.6863   | 0.0957 |  0.1569  |
# |       Politics       |  0.8806   | 0.1485 |  0.2439  |
# |       Religion       |  0.8574   | 0.1016 |  0.1749  |
# |       Science        |  0.7262   | 0.1023 |  0.1708  |
# |       Society        |  0.8579   | 0.0987 |  0.1705  |
# |        Sports        |  0.5602   | 0.0833 |  0.1364  |
# |      Technology      |  0.5440   | 0.0793 |  0.1356  |
# |       Universe       |  0.8051   | 0.1741 |  0.2506  |
# +----------------------+-----------+--------+----------+
